# %%
# %config Completer.use_jedi = False

# %% [markdown]
# # Aula 9 - HTML e webscraping
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Web Front-end: HTML
# - 2) Webscraping

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 1) Web Front-end: HTML
#
# O desenvolvimento web é normalmente dividido em duas componentes: o **front-end** e o **back-end**.
#
# - front-end e refere à página que aparece no navegador do usuário. É a "fachada";
# - back-end é o que está por trás do site no servidor: comunicação, acesso a banco de dados etc.
#
# Enquanto no back-end qualquer linguagem pode ser usada, no front estamos limitados ao tripé **HTML, CSS e JavaScript**.
#
# - HTML é o "esqueleto" do site. É ele que irá posicionar diferentes elementos, como textos, figuras, vídeos entre outros na tela.
#
# - CSS serve para darmos estilo ao site. Podemos definir classes (e nelas definir comportamentos como cor, fonte e animações) para aplicar ao HTML.
#
# - JavaScript serve para aplicar lógica no próprio site, podendo rodar aplicações e deixar o site mais dinâmico.
#
# Para nossas aplicações de webscrapping, estaremos interessados apenas no HTML.

# %% [markdown]
# HTML é a sigla para **HyperText Markup Language**.
#
# Os "comandos" HTML são chamados de **tags**, e servem para marcar **pedaços do texto**, separando-os entre cabeçalho, corpo, tabelas, etc.
#
# As **tags HTML** são comandos iniciados em `<` e terminados em `>`.
#
# A maioria das tags vem em pares: utilizamos uma `<tag>`, colocamos algum conteúdo que desejamos que seja afetado por ela, e em seguida fechamos com  `</tag>`.
#
# Um documento HTML costuma abrir e fechar com as tags `<html>` e `</html>`.
#
# Em seguida, ele se subdivide em **head** e **body**.
#
# A tag `<head>` é o cabeçalho.
#
# > Nela colocamos informações úteis para o navegador interpretar o restante do documento, como padrões de estilo, links base, scripts etc.
#
# A tag `<body>` é aonde entra todo o conteúdo: textos, imagens, links...
#
# Um exemplo de código HTML para uma página bem simples (cole no bloco de notas):
#
# ```html
# <html>
#     <head>
#         <title>Meu primeiro site!</title>
#     </head>
#
#     <body>
#         <h1>Um site de exemplo</h1>
#         <h2>Site de exemplo pra entendermos HTML.</h2>
#         <p>Este é um site feio e bobo para vermos como HTML funciona.</p>
#         <p>Se você quer aprender HTML de verdade, clique <a href="https://letscode-academy.com/cursos/web-frontend-react">aqui</a>.</p>
#     </body>
# </html>
# ```

# %% [markdown]
# Podemos acessar o código-fonte HTML de qualquer site, de maneira bem simples!
#
# Podemos simplesmente clicar em algum lugar da página **com o botão direito**, e depois selecionar **exibir código-fonte**, ou algo do tipo (varia de navegador pra navegador).

# %% [markdown]
# Há também algumas ferramentas um pouco mais avançadas, que são de grande auxilio aos desenvolvedores, como o **inspecionador** ou **inspetor de elemento**
#
# Em navegadores como Chrome e Firefox atalhos como **ctrl+shift+i** ou **F12** funcionam.

# %%
# !pip install requests

# %%
import requests

resposta = requests.get('https://letscode.com.br/')

# %%
print('Código de Status')
print(resposta.status_code)
print('-'*32)
print('Cabeçalho | header')
print(resposta.headers)
print('-'*32)
print('Conteudo')
print(resposta.text)
# Out:
# Código de Status
# 200
# --------------------------------
# Cabeçalho | header
# {'Date': 'Wed, 21 Jul 2021 22:02:43 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx/1.18.0', 'X-Powered-By': 'Next.js', 'ETag': '"2f1e4-BCD5tvhJo9HDndf2bUQuqynphoY"', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}
# --------------------------------
# Conteudo
# <!DOCTYPE html><html lang="pt-BR"><head><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="stylesheet" data-href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700,800,900&amp;display=swap" data-optimized-fonts="true"/><title>Let&#x27;s Code | Cursos de Programação</title><meta name="title" property="og:title" content="Let&#x27;s Code | Cursos de Programação"/><meta name="type" property="og:type" content="website"/><meta name="description" property="og:description" content="Cursos de programação presenciais e online em diversas linguagens. Teste grátis nossa plataforma."/><meta property="og:image" content="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/2020/siteLink.webp"/><meta name="facebook-domain-verification" content="t5kwc6pngnapypj4hb9tea9175jero"/><meta property="og:site_name" content="Let&#x27;s Code"/><meta property="fb:admins" content="1041575599256742"/><meta property="og:url" content="https://www.letscode.com.br/"/><meta name="next-head-count" content="14"/><link rel="preload" href="/_next/static/css/c9cfe64be795bdfbd342.css" as="style"/><link rel="stylesheet" href="/_next/static/css/c9cfe64be795bdfbd342.css" data-n-g=""/><link rel="preload" href="/_next/static/css/665eecc29acf6a610c2d.css" as="style"/><link rel="stylesheet" href="/_next/static/css/665eecc29acf6a610c2d.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-e7a279300235e161e32a.js"></script><script defer="" src="/_next/static/chunks/58.8c3d26db2d823bc93199.js"></script><script defer="" src="/_next/static/chunks/899.dc7dea62dba8414f66b7.js"></script><script defer="" src="/_next/static/chunks/914.6964afa34770eb66baec.js"></script><script src="/_next/static/chunks/webpack-33688023c89c246ece1c.js" defer=""></script><script src="/_next/static/chunks/framework-b5f3c897a40b4b93d7e6.js" defer=""></script><script src="/_next/static/chunks/main-18e5535ffc85f4a7d113.js" defer=""></script><script src="/_next/static/chunks/pages/_app-2fab4aa7b52c055adc6c.js" defer=""></script><script src="/_next/static/chunks/ea88be26-0a0afb72237add43f7a9.js" defer=""></script><script src="/_next/static/chunks/902-5e844057a461f75382ea.js" defer=""></script><script src="/_next/static/chunks/260-b8b4d5e3e9c09b59581a.js" defer=""></script><script src="/_next/static/chunks/1-cf1e458cd7e1ed7dd09e.js" defer=""></script><script src="/_next/static/chunks/356-9fc421f5939c8349b743.js" defer=""></script><script src="/_next/static/chunks/593-a4749b500b48a3b0ba86.js" defer=""></script><script src="/_next/static/chunks/pages/index-e597dca0770ced873de7.js" defer=""></script><script src="/_next/static/lrcWmlZM4-d7PFIPSBTqr/_buildManifest.js" defer=""></script><script src="/_next/static/lrcWmlZM4-d7PFIPSBTqr/_ssgManifest.js" defer=""></script><style data-styled="" data-styled-version="5.3.0">.doOaWk .navbar{min-height:75px;border:1px solid transparent;-webkit-transition:all 0.5s ease-out;-moz-transition:all 0.5s ease-out;-o-transition:all 0.5s ease-out;-webkit-transition:all 0.5s ease-out;transition:all 0.5s ease-out;padding:0 10px;}/*!sc*/
# .doOaWk .arrow-up{border:solid #fff;border-width:0 3px 3px 0;display:inline-block;position:relative;top:4px;width:18px;height:18px;-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);}/*!sc*/
# .doOaWk .navbar:hover{background-color:#0b1923;}/*!sc*/
# .doOaWk .multiple-dropdown-label1{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:10px;border-bottom-left-radius:6px;border-bottom-right-radius:6px;}/*!sc*/
# .doOaWk .multiple-dropdown-label1 > svg{font-size:20px;-webkit-transform:rotate(-90deg);-ms-transform:rotate(-90deg);transform:rotate(-90deg);margin-right:5px;}/*!sc*/
# .doOaWk .multiple-dropdown-label1:hover{background-color:#162f40;}/*!sc*/
# .doOaWk .multiple-dropdown-label1:hover .multiple-dropdown-options-container1{display:block;}/*!sc*/
# .doOaWk .multiple-dropdown-label1.dark:hover{background-color:#070707;color:#00fafd;}/*!sc*/
# .doOaWk .multiple-dropdown-label1.pi:hover{background-color:#f7b823;color:#000;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container2{position:absolute;left:0%;width:203px;top:0;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container3{background-color:#11222f;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;z-index:0;border-bottom-left-radius:6px;border-bottom-right-radius:6px;position:absolute;left:-112%;top:0;width:228px;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container3 > a{width:100%;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container1{display:none;}/*!sc*/
# .doOaWk .multiple-dropdown-options-title{font-weight:600;opacity:0.3;margin:5px auto;padding:10px 10px 5px;width:100%;font-size:14px;border-bottom:1px solid #1e3849;color:#fff;}/*!sc*/
# .doOaWk .navbar.scrolled{background-color:#0b1923;}/*!sc*/
# .doOaWk .navbar-item{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;}/*!sc*/
# .doOaWk .navbar-item,.doOaWk .navbar-link{color:#4a4a4a;display:block;line-height:1.5;padding:0.5rem 0.75rem;position:relative;}/*!sc*/
# .doOaWk #navbar-logo{line-height:2.9;}/*!sc*/
# .doOaWk .item-img > div > div{width:0px;}/*!sc*/
# .doOaWk .navbar-img{-webkit-filter:brightness(1);filter:brightness(1);height:auto !important;width:auto !important;position:relative !important;max-height:1.75rem !important;min-width:unset !important;}/*!sc*/
# .doOaWk img{height:auto;max-width:100%;}/*!sc*/
# .doOaWk .navbar-brand{float:left;height:50px;padding:0 15px;font-size:18px;line-height:20px;}/*!sc*/
# .doOaWk .navbar-item.has-dropdown{padding:0.5rem 0.75rem;}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-brand,.doOaWk .navbar-item{-webkit-align-items:normal !important;-webkit-box-align:normal !important;-ms-flex-align:normal !important;align-items:normal !important;}.doOaWk .navbar,.doOaWk .navbar-end,.doOaWk .navbar-menu,.doOaWk .navbar-start{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}.doOaWk .navbar-menu .navbar-item{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;}.doOaWk .navbar-menu .navbar-link{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;}.doOaWk .navbar-dropdown{left:0;}}/*!sc*/
# .doOaWk .navbar-menu{padding:0px 30px 0px 40px;height:37px;-webkit-box-flex:unset;-webkit-flex-grow:unset;-ms-flex-positive:unset;flex-grow:unset;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;display:none;}/*!sc*/
# .doOaWk .navbar.is-fixed-bottom,.doOaWk .navbar.is-fixed-top{left:0;position:fixed;right:0;z-index:30;}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-menu a.navbar-item:hover,.doOaWk .navbar-menu .navbar-item:hover{background:none;color:#fff;}.doOaWk .navbar-menu a.navbar-item:focus,.doOaWk .navbar-menu .navbar-item:focus{background:none;color:#fff;}.doOaWk .navbar-dropdown-mobile{display:none;}.doOaWk .arrow-dropdown{display:none;}}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item{font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:0.5rem 0.8rem;padding-right:2.5rem;-webkit-transition:0.1s;transition:0.1s;text-align:left;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item:hover,.doOaWk .navbar-dropdown a.navbar-item:focus{color:#fff;background-color:#162f40;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown.pi a.navbar-item:hover{color:#000;background-color:#f7b823;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown.pi a.navbar-item:focus{background-color:#f7b823;color:#000;}/*!sc*/
# .doOaWk .navbar-dropdown.dark a.navbar-item:hover{background-color:#070707;color:#00fafd;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item:focus{background-color:#162f40;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item,.doOaWk .navbar-menu .navbar-item{background:none;position:relative;color:#fff;-webkit-text-decoration:none;text-decoration:none;font-weight:300;font-size:14px;cursor:pointer;border-bottom-left-radius:6px;border-bottom-right-radius:6px;}/*!sc*/
# .doOaWk .navbar-end > .navbar-item{padding-top:28px;padding-bottom:28px;}/*!sc*/
# .doOaWk .navbar-end .nav-item-name{border-bottom:1px solid transparent;padding:4px 0;-webkit-transition:all 0.4s;transition:all 0.4s;}/*!sc*/
# .doOaWk .navbar-end .nav-item-name:hover,.doOaWk .navbar-end .nav-item-name:focus{border-bottom:1px solid #edd647;-webkit-transition:all 0.4s;transition:all 0.4s;}/*!sc*/
# .doOaWk .navbar-dropdown.close,.doOaWk .navbar-dropdown.close a.nav-item-name{content:'';position:absolute;height:0;-webkit-transition:0.6s;transition:0.6s;}/*!sc*/
# .doOaWk .navbar .navbar-dropdown a.navbar-item:before{content:'';position:absolute;width:60%;margin:0 20%;height:0px;bottom:0;font-size:0;left:0;background-color:transparent !important;-webkit-transition:0.6s;transition:0.6s;}/*!sc*/
# .doOaWk .navbar .is-fixed-top .navbar-menu{border-radius:10px;text-align:center;padding:10px;position:relative;z-index:1;margin:10px;}/*!sc*/
# .doOaWk .navbar-item.has-dropdown{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .doOaWk .navbar-dropdown{padding:0;-webkit-transition:all 500ms;transition:all 500ms;-o-transition:all 500ms;-moz-transition:all 500ms;-webkit-transition:all 500ms;display:block;-webkit-transform:scaleY(0);-ms-transform:scaleY(0);transform:scaleY(0);-webkit-transform-origin:top;-ms-transform-origin:top;transform-origin:top;font-weight:350;margin-top:-6px;}/*!sc*/
# .doOaWk .navbar-item:hover .navbar-dropdown:not(.close){-webkit-transform:scaleY(1);-ms-transform:scaleY(1);transform:scaleY(1);background-color:#11222f;}/*!sc*/
# .doOaWk .arrow.white{border:solid currentColor;border-width:0 1px 1px 0;padding:3px;position:relative;}/*!sc*/
# .doOaWk .arrow.white.up{-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);top:2px;right:6px;}/*!sc*/
# .doOaWk .arrow.white.down{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);-webkit-transform:rotate(45deg);top:-1px;right:6px;}/*!sc*/
# .doOaWk .arrow.white.left{-webkit-transform:rotate(135deg);-ms-transform:rotate(135deg);transform:rotate(135deg);-webkit-transform:rotate(135deg);top:0px;margin-right:8px;margin-left:6px;border-width:0 2px 2px 0;}/*!sc*/
# .doOaWk .arrow.black{border:solid currentColor;border-width:0 1px 1px 0;padding:3px;position:relative;}/*!sc*/
# .doOaWk .arrow.black.up{-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);top:2px;right:6px;}/*!sc*/
# .doOaWk .arrow.black.down{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);-webkit-transform:rotate(45deg);top:-1px;right:6px;}/*!sc*/
# .doOaWk .navbar-dropdown-container.pi{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar-dropdown-container.pi > div > a{color:#fff !important;}/*!sc*/
# .doOaWk .navbar.pi:hover{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar.scrolled.pi{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar.scrolled.dark{background:linear-gradient(to right,#070707,#121212);}/*!sc*/
# .doOaWk .navbar.dark:hover{background:linear-gradient(to right,#070707,#121212);}/*!sc*/
# .doOaWk .navbar-img.dark{-webkit-filter:brightness(0) invert();filter:brightness(0) invert();}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.active.dark:before,.doOaWk .navbar-menu .navbar-item.dark.active:before{background-color:transparent;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.dark:before,.doOaWk .navbar-menu span.navbar-item.dark:before{background:transparent;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.dark:hover:before,.doOaWk .navbar-menu span.navbar-item.dark:hover:before{background:#00fafd;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item.dark:before,.doOaWk .navbar-dropdown a.navbar-item:before{background:none;}/*!sc*/
# .doOaWk .navbar-dropdown.dark{border-color:#00fafd;}/*!sc*/
# .doOaWk .navbar-dropdown-container.dark{background:linear-gradient(to left,#070707,#121212);}/*!sc*/
# .doOaWk .navbar-burger{color:#f7d42f;cursor:pointer;display:block;height:3.25rem;position:relative;width:3.25rem;margin-left:auto;outline:none;margin-right:15px;}/*!sc*/
# .doOaWk .navbar-burger:hover{background-color:rgba(0,0,0,0.05);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:first-child{-webkit-transform:translateY(5px) rotate(45deg);-moz-transform:translateY(5px) rotate(45deg);-webkit-transform:translateY(5px) rotate(45deg);-ms-transform:translateY(5px) rotate(45deg);transform:translateY(5px) rotate(45deg);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:nth-child(3){-webkit-transform:translateY(-5px) rotate(-45deg);-moz-transform:translateY(-5px) rotate(-45deg);-webkit-transform:translateY(-5px) rotate(-45deg);-ms-transform:translateY(-5px) rotate(-45deg);transform:translateY(-5px) rotate(-45deg);}/*!sc*/
# .doOaWk .navbar-burger span:first-child{top:-moz-calc(50% - 6px);top:calc(50% - 6px);}/*!sc*/
# .doOaWk .navbar-burger span:nth-child(2){top:-moz-calc(50% - 1px);top:calc(50% - 1px);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:nth-child(2){opacity:0;}/*!sc*/
# .doOaWk .navbar-burger span:nth-child(3){top:-moz-calc(50% + 4px);top:calc(50% + 4px);}/*!sc*/
# .doOaWk .navbar-burger span{background-color:currentColor;display:block;height:1px;left:-moz-calc(50% - 8px);left:calc(50% - 8px);position:absolute;-webkit-transform-origin:center;-moz-transform-origin:center;-webkit-transform-origin:center;-ms-transform-origin:center;transform-origin:center;-webkit-transition-duration:86ms;-moz-transition-duration:86ms;-webkit-transition-duration:86ms;transition-duration:86ms;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;transition-property:background-color,opacity,-webkit-transform;-moz-transition-property:background-color,opacity,transform,-moz-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,transform;transition-property:background-color,opacity,transform;-webkit-transition-property:background-color,opacity,-webkit-transform,-webkit-transform,-moz-transform;-webkit-transition-property:background-color,opacity,transform,-webkit-transform,-moz-transform;transition-property:background-color,opacity,transform,-webkit-transform,-moz-transform;-webkit-transition-timing-function:ease-out;-moz-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;width:16px;}/*!sc*/
# .doOaWk span{font-style:inherit;font-weight:inherit;}/*!sc*/
# .doOaWk .dark .navbar-burger{color:white;}/*!sc*/
# .doOaWk .navbar-brand{padding:0 15px !important;}/*!sc*/
# @media only screen and (max-width:1023px){.doOaWk .navbar-dropdown-desktop{display:none;}.doOaWk .navbar{min-height:50px;}.doOaWk .navbar-menu a.navbar-item.dark,.doOaWk .navbar-menu .navbar-item.dark{font-size:16px;color:#fff;font-weight:500;}.doOaWk .navbar-item.item-img{padding-left:0;}.doOaWk .navbar-menu a.navbar-item,.doOaWk .navbar-menu .navbar-item{font-size:16px;color:#000;font-weight:300;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-right:12.8px;}.doOaWk .dark.modal-code .modal-close{background-color:white;}.doOaWk .dark.modal-code .modal-close:before,.doOaWk .dark.modal-code .modal-close:after{background-color:black;}.doOaWk .navbar{padding:0;}.doOaWk .navbar-menu{height:auto;}.doOaWk .navbar-brand{width:100%;-webkit-transition:background-color 0.5s ease-in-out;transition:background-color 0.5s ease-in-out;}.doOaWk .navbar.is-fixed-top .navbar-menu{border-radius:10px;text-align:center;padding:10px;position:relative;z-index:1;margin:10px;}.doOaWk .navbar-end > .navbar-item{padding-top:0.4rem;padding-bottom:0.4rem;}.doOaWk .navbar-end > .navbar-item:not(:last-child){border-bottom:1px solid #8c8c8c;}.doOaWk .navbar-menu.is-active.dark{background-color:#000;}.doOaWk .nav-item-name{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.doOaWk .nav-item-name svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.doOaWk .navbar-end .nav-item-name:hover,.doOaWk .navbar-end .nav-item-name:focus{border-bottom:none;-webkit-transition:none;transition:none;}.doOaWk .navbar-item:hover .navbar-dropdown:not(.close){background-color:transparent;}.doOaWk .navbar-dropdown{-webkit-transform:none;-ms-transform:none;transform:none;}.doOaWk .dropdown-title{background-color:#1a2d3c;color:white;border-radius:5px;margin:10px 0;padding:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:14px;}.doOaWk .dropdown-title svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);margin-right:5px;}.doOaWk .section-container-mobile{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:20px;margin-bottom:10px;border-bottom:1px solid #8c8c8c;font-size:14px;}.doOaWk .section-container-mobile.dark{border-bottom:1px solid white;}}/*!sc*/
# @media (max-width:320px){.doOaWk .dropdown-title{font-size:12px;}}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-dropdown{border-top:none;background-color:#fff;border-bottom-left-radius:6px;border-bottom-right-radius:6px;font-size:0.875rem;left:-30px;min-width:100%;position:absolute;top:105%;z-index:20;}}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar,.doOaWk .navbar-end,.doOaWk .navbar-menu,.doOaWk .navbar-start{-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.doOaWk .navbar-burger{display:none;}}/*!sc*/
# @media screen and (max-width:1023px){.doOaWk .navbar-menu.is-active{display:block;}.doOaWk .navbar-menu{background-color:#fff;-moz-box-shadow:0 8px 16px rgba(10,10,10,0.1);box-shadow:0 8px 16px rgba(10,10,10,0.1);padding:0.5rem 0;}.doOaWk .navbar.is-fixed-top-touch .navbar-menu,.doOaWk .navbar.is-fixed-top .navbar-menu{-webkit-overflow-scrolling:touch;max-height:-moz-calc(100vh - 3.25rem);max-height:calc(100vh - 3.25rem);overflow:auto;}.doOaWk .navbar-menu{background-color:#fff;-moz-box-shadow:0 8px 16px rgba(10,10,10,0.1);box-shadow:0 8px 16px rgba(10,10,10,0.1);padding:0.5rem 0;}}/*!sc*/
# data-styled.g1[id="styles__Container-tke1hi-0"]{content:"doOaWk,"}/*!sc*/
# .bgWhoP .header-bottom{position:fixed;z-index:50;bottom:0;pointer-events:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .bgWhoP .header-bottom-links{margin:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;pointer-events:none;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .bgWhoP .whatsLink{height:50px;width:50px;z-index:50;pointer-events:all;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;box-shadow:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#009746;border-radius:50%;position:relative;}/*!sc*/
# .bgWhoP .scrollTop{height:50px;width:50px;box-shadow:none;z-index:50;pointer-events:all;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;cursor:pointer;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-radius:50%;background:#162d4b;border:2px solid #f7d42f;position:relative;}/*!sc*/
# .bgWhoP .scrollTop svg{font-size:40px;color:#fff;position:absolute;left:50%;top:calc(50% - 2px);-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# @media only screen and (max-width:1023px){.bgWhoP .header-bottom.active{bottom:40px;}.bgWhoP .scrollTop,.bgWhoP .whatsLink{height:40px;width:40px;bottom:6px;}.bgWhoP .scrollTop div,.bgWhoP .whatsLink div{width:30px;height:30px;}}/*!sc*/
# @media only screen and (max-width:512px){.bgWhoP .header-bottom.active{bottom:68px;}}/*!sc*/
# data-styled.g2[id="styles__Container-t3m083-0"]{content:"bgWhoP,"}/*!sc*/
# .iNTbyI a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;color:white;}/*!sc*/
# .iNTbyI .site-footer{background-color:#0b1923;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;color:#fff;font-size:12px;width:100%;position:relative;padding:30px 100px 15px 80px;}/*!sc*/
# .iNTbyI .site-footer.dark{background-color:#222121 !important;}/*!sc*/
# .iNTbyI .site-footer.extended{padding-bottom:80px;}/*!sc*/
# .iNTbyI .footer-contato{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-left:2rem;}/*!sc*/
# .iNTbyI .footer-contato svg{color:#fff;font-size:1.25rem;}/*!sc*/
# .iNTbyI .footer-contato a + a svg{margin-left:1rem;}/*!sc*/
# .iNTbyI .footer-container-phone{width:200px;position:relative;right:-40%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .iNTbyI .footer-container-address{cursor:pointer;width:250px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fff;}/*!sc*/
# .iNTbyI .footer-container-address:hover{color:#4343ff;}/*!sc*/
# .iNTbyI .footer-text{font-size:16px;font-weight:400;text-align:left;padding-left:10px;}/*!sc*/
# .iNTbyI .footer-text-small{font-size:12px;}/*!sc*/
# .iNTbyI .react-logo-wrapper{height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .iNTbyI .react-logo-wrapper > svg{margin-left:10px;}/*!sc*/
# .iNTbyI .footer-logo{width:150px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0 auto;}/*!sc*/
# .iNTbyI .footer-logo-container{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media (max-width:1024px){.iNTbyI .footer-logo{display:none;}}/*!sc*/
# @media (max-width:768px){.iNTbyI .footer-container-address:hover{color:#fff;}}/*!sc*/
# @media only screen and (max-width:425px){.iNTbyI .site-footer{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;}.iNTbyI .footer-container-phone{position:initial;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.iNTbyI .footer-container-address{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 0 23px;margin-bottom:20px;}}/*!sc*/
# data-styled.g4[id="styles__Container-sc-85gh8u-0"]{content:"iNTbyI,"}/*!sc*/
# .exaHbn .quiz-footer{position:fixed;bottom:0;width:100%;background:#0b1923;color:#fff;text-align:center;padding:10px 0px 10px;line-height:24px;font-weight:400;-webkit-letter-spacing:0.1px;-moz-letter-spacing:0.1px;-ms-letter-spacing:0.1px;letter-spacing:0.1px;-webkit-text-decoration:none;text-decoration:none;z-index:30;}/*!sc*/
# .exaHbn .quiz-footer.dark{background:#222121;}/*!sc*/
# .exaHbn .quiz-link{color:#fff;}/*!sc*/
# .exaHbn #mdiv{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;cursor:pointer;}/*!sc*/
# .exaHbn .mdiv{height:10px;width:2px;background-color:#fff;-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);z-index:1;left:24px;top:0px;position:relative;}/*!sc*/
# .exaHbn .md{height:10px;width:2px;background-color:#fff;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);z-index:2;}/*!sc*/
# .exaHbn .quiz-footer-text-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media only screen and (min-width:1024px){.exaHbn .quiz-link:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fac43c;}}/*!sc*/
# @media only screen and (max-width:1023px){.exaHbn .quiz-footer{padding:10px 0px 10px;}.exaHbn .quiz-link{-webkit-text-decoration:underline;text-decoration:underline;}.exaHbn .call-upper{display:none;}.exaHbn .quiz-footer-text-container{width:60%;margin:0 auto;}}/*!sc*/
# data-styled.g5[id="styles__Container-nzozqa-0"]{content:"exaHbn,"}/*!sc*/
# .duKImY .typography.h1{font-size:110px;}/*!sc*/
# .duKImY .typography.h2{font-size:96px;}/*!sc*/
# .duKImY .typography.h3{font-size:68px;}/*!sc*/
# .duKImY .typography.h4{font-size:60px;}/*!sc*/
# .duKImY .typography.title1{font-size:42px;}/*!sc*/
# .duKImY .typography.title2{font-size:34px;}/*!sc*/
# .duKImY .typography.subtitle1{font-size:26px;}/*!sc*/
# .duKImY .typography.subtitle2{font-size:20px;}/*!sc*/
# .duKImY .typography.body1{font-size:16px;}/*!sc*/
# .duKImY .typography.body2{font-size:14px;}/*!sc*/
# .duKImY .typography.caption1{font-size:12px;}/*!sc*/
# .duKImY .typography.caption2{font-size:10px;}/*!sc*/
# .duKImY .typography.button{font-size:16px;}/*!sc*/
# @media (max-width:768px){.duKImY .typography.h1{font-size:96px;}.duKImY .typography.h2{font-size:68px;}.duKImY .typography.h3{font-size:60px;}.duKImY .typography.h4{font-size:42px;}.duKImY .typography.title1{font-size:32px;}.duKImY .typography.title2{font-size:26px;}.duKImY .typography.subtitle1{font-size:20px;}.duKImY .typography.subtitle2{font-size:16px;}.duKImY .typography.body1{font-size:14px;}.duKImY .typography.body2{font-size:12px;}.duKImY .typography.caption1{font-size:10px;}.duKImY .typography.caption2{font-size:8px;}.duKImY .typography.button{font-size:14px;}}/*!sc*/
# data-styled.g6[id="styles__Container-sc-1510a04-0"]{content:"duKImY,"}/*!sc*/
# .kvXAYG{width:100%;}/*!sc*/
# .kvXAYG .slide-container{position:relative;margin:0 auto;}/*!sc*/
# .kvXAYG .slide-container.active{cursor:-webkit-grabbing;cursor:-moz-grabbing;cursor:grabbing;}/*!sc*/
# .kvXAYG .slideshow{margin:0 auto;overflow:hidden;}/*!sc*/
# .kvXAYG .slideshowSlider{white-space:nowrap;-webkit-transition:-webkit-transform 0.0s ease-in-out;-webkit-transition:transform 0.0s ease-in-out;transition:transform 0.0s ease-in-out;-webkit-perspective:1000;-webkit-backface-visibility:hidden;-webkit-transform:translateZ(0);-ms-transform:translateZ(0);transform:translateZ(0);will-change:transform;}/*!sc*/
# .kvXAYG .slide{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;border-radius:40px;white-space:normal;}/*!sc*/
# .kvXAYG .slide img{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-moz-user-select:none;-khtml-user-select:none;-webkit-user-select:none;-o-user-select:none;}/*!sc*/
# .kvXAYG .slide-wrapper{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .kvXAYG .slide-content{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kvXAYG .slideshowDots{text-align:center;width:90%;margin:auto;}/*!sc*/
# .kvXAYG .slideshowDot{cursor:pointer;height:4px;width:6px;margin:0 0.125rem;background-color:#c4c4c4;border-radius:8px;display:inline-block;-webkit-transition:background-color 1s ease-out,width 0.6s ease-out;-webkit-transition:background-color 1s ease-out,width 0.6s ease-out;transition:background-color 1s ease-out,width 0.6s ease-out;}/*!sc*/
# .kvXAYG .slideshowDot.active{background-color:#374952;width:10px;}/*!sc*/
# .kvXAYG .slideshowDot.hidden{display:none;}/*!sc*/
# .kvXAYG .arrowImage{width:30px;height:30px;position:absolute;cursor:pointer;z-index:2;top:50%;}/*!sc*/
# .kvXAYG .arrowImage.prev{left:0px;}/*!sc*/
# .kvXAYG .arrowImage.next{right:0px;}/*!sc*/
# @media (max-width:475px){.kvXAYG .arrowImage{width:20px;height:20px;}}/*!sc*/
# data-styled.g9[id="styles__Container-jqng2s-0"]{content:"kvXAYG,"}/*!sc*/
# .fnlVyd .input-container{height:100%;color:#000;}/*!sc*/
# .fnlVyd .validation-icons{position:absolute;right:2px;top:4px;}/*!sc*/
# .fnlVyd .input__container{width:100%;position:relative;height:40px;}/*!sc*/
# .fnlVyd .input__invalid_message{position:absolute;top:27px;margin-left:10px;font-size:14px;color:red;}/*!sc*/
# .fnlVyd .input-holder input{outline-color:transparent;font-family:'Montserrat',sans-serif;}/*!sc*/
# .fnlVyd .input-holder{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media (min-width:700px) and (max-width:810px){.fnlVyd{margin:auto 8px auto 40px !important;}}/*!sc*/
# @media only screen and (max-width:768px){.fnlVyd .input-holder{margin:10px 0;}.fnlVyd .input-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.fnlVyd .sm-icon{margin-right:2vw;}.fnlVyd .sm-count{color:#00000050;position:absolute;bottom:-3vh;width:100%;text-align:center;}.fnlVyd .sm-icon-wrapper{margin:auto 8px auto 16px;}.fnlVyd .check,.fnlVyd .notCheck{right:5%;}.fnlVyd .sm-icon{margin:auto 16px auto auto;}.fnlVyd .input__invalid_message{margin-left:2px;margin-top:5px;}}/*!sc*/
# @media only screen and (min-width:768px){.fnlVyd .sm-count{margin-top:auto 0;font-size:10pt;}}/*!sc*/
# data-styled.g15[id="styles__Container-sc-36shcs-0"]{content:"fnlVyd,"}/*!sc*/
# .BrsWO body{line-height:1.42857143;color:#333;}/*!sc*/
# .BrsWO b,.BrsWO strong{font-weight:700;}/*!sc*/
# .BrsWO section{position:relative;}/*!sc*/
# .BrsWO i:hover{color:#aeaeae;}/*!sc*/
# .BrsWO section#slider > *{padding-left:0px;}/*!sc*/
# .BrsWO .flex{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .homeCursos a{margin-top:10px;-webkit-text-decoration:none;text-decoration:none;color:#212529;}/*!sc*/
# .BrsWO .center{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .BrsWO .homeCursos{height:100%;max-width:calc(100% - 380px);padding:0 0;}/*!sc*/
# .BrsWO .trailSwitch{text-align:center;content-align:middle;}/*!sc*/
# .BrsWO .trailOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .trailOptionContainer{margin:0 auto;}/*!sc*/
# .BrsWO .trailOptionIcon{position:relative;object-fit:contain;height:50px;width:50px;cursor:pointer;}/*!sc*/
# .BrsWO .trailHeaderTextDesc{text-align:center;margin-bottom:10px;padding:10px;margin-top:30px;}/*!sc*/
# @media (min-width:2001px){.BrsWO .trailOptionIcon{height:100px;width:100px;}.BrsWO .trailOptionContainer{padding-bottom:10px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (min-width:1601px) and (max-width:2001px){.BrsWO .trailOptionIcon{height:96px;width:96px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (min-width:1025px) and (max-width:1600px){.BrsWO .trailOptionIcon{height:70px;width:70px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (max-width:1024px){.BrsWO .trailOptionIcon{width:60px;height:60px;}}/*!sc*/
# @media (max-width:425px){.BrsWO .trailOptionIcon{width:50px;height:50px;}}/*!sc*/
# @media only screen and (min-width:768px) and (max-width:1100px){.BrsWO .homeCursos{max-width:calc(100% - 200px);}}/*!sc*/
# .BrsWO #section__cursos{padding-top:20px;background:#f6f6f6;width:100vw;padding-bottom:60px;}/*!sc*/
# .BrsWO .columns{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .to-right{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;padding:40px 20px 10px 20px;padding-bottom:10px;}/*!sc*/
# .BrsWO .to-left{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:40px 20px 10px 20px;padding-bottom:10px;}/*!sc*/
# .BrsWO a:hover{-webkit-text-decoration:none !important;text-decoration:none !important;}/*!sc*/
# .BrsWO .title__sobre{color:#fed500;}/*!sc*/
# .BrsWO .trail_type{width:50%;padding-left:10%;font-weight:300;}/*!sc*/
# .BrsWO .barriguinha{position:absolute;width:auto;height:20px;bottom:-16px;z-index:20;left:5%;}/*!sc*/
# .BrsWO .filter{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .BrsWO .courses-filter{width:60%;position:relative;}/*!sc*/
# .BrsWO .courses-filter div.filter-courses{width:100%;background-color:#fff;border-radius:4px;border:0;box-shadow:0px 0px 4px #707070;height:2.2rem;-webkit-appearance:none;position:relative;}/*!sc*/
# .BrsWO .courses-filter svg{position:absolute;right:0.5rem;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);}/*!sc*/
# .BrsWO #section__cursos .search-course-text{padding:0.45rem;color:#555;}/*!sc*/
# .BrsWO .courses-column{min-width:160px;}/*!sc*/
# .BrsWO .singleColumn{width:100% !important;}/*!sc*/
# .BrsWO .courses-column:nth-child(2),.BrsWO .courses-column:nth-child(4){margin:0 0.7rem;}/*!sc*/
# .BrsWO .column-header{border-bottom:1px solid #132e4c;border-top:1px solid #132e4c;}/*!sc*/
# .BrsWO .courses-options{position:absolute;top:2.2rem;right:0;background-color:#f6f6f6;color:#132e4c;box-shadow:0px 0px 10px #707070;border-radius:4px;padding:0.7rem;z-index:10;border-bottom:7px solid #fed254;}/*!sc*/
# .BrsWO .trailSpacing{margin-top:15px;border-top:1px solid #132e4c;padding-top:15px;}/*!sc*/
# .BrsWO .courses-options .column-title{font-size:14px;font-weight:700;margin-bottom:0;width:150px;}/*!sc*/
# .BrsWO .courses-options .column-duration{font-size:14px;font-weight:600;margin:1rem auto;padding:0.2rem;}/*!sc*/
# .BrsWO .courses-options .courses-list{margin-top:1rem;}/*!sc*/
# .BrsWO .courses-options .courses-list li{font-size:0.8rem;padding:0.2rem 0rem;}/*!sc*/
# .BrsWO .courses-options .courses-list li a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO .courses-column{padding-bottom:3vh;}.BrsWO #sobre{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-top:5vh;padding-bottom:0vh;}.BrsWO .courses-column:nth-child(2),.BrsWO .courses-column:nth-child(4){margin:0;}.BrsWO #section__cursos{padding-bottom:20px;}.BrsWO .trail_type{text-align:center;margin:0 auto 20px;padding:0;}.BrsWO .to-right,.BrsWO .to-left{padding:0;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# .BrsWO .cursosHeaderInfo{margin:30px auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .BrsWO .columns{margin:0;}/*!sc*/
# .BrsWO .columns.right{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# .BrsWO .gifCard .gif{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO .cursosHeaderInfo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-bottom:5vh;}}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO #conteudo-programatico{margin-top:0;}.BrsWO .courses-options{width:100%;}}/*!sc*/
# @media only screen and (min-width:769px) and (max-width:936px){.BrsWO .homeCursos a{width:38vw;}}/*!sc*/
# data-styled.g24[id="homeContainer__Container-cwo9us-0"]{content:"BrsWO,"}/*!sc*/
# .gFdQpP .site-map{background-color:white;padding:40px 0;font-size:10pt;color:#162d4b;}/*!sc*/
# .gFdQpP .footer-group-title{width:13.34vw;font-size:14px !important;font-weight:bold;margin:10px 0px 2px;color:#162d4b;padding-bottom:5px;border-bottom:1px solid #162d4b;}/*!sc*/
# .gFdQpP .footer-group-subtitle{font-size:12px !important;font-weight:bold;color:#162d4b;margin:7px 0px 0px;}/*!sc*/
# .gFdQpP .footer-group-link{width:13.34vw;color:#162d4b !important;-webkit-text-decoration:none;text-decoration:none;font-size:12px !important;text-transform:capitalize;}/*!sc*/
# .gFdQpP .site-map-content{width:60vw;height:190pt;margin:0px auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:space-between;-ms-flex-line-pack:space-between;align-content:space-between;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .gFdQpP .site-map-content > div{height:100%;}/*!sc*/
# .gFdQpP .site-map.dark{background-color:#353535;color:#fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-title{color:#fff;border-bottom:1px solid #fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-subtitle{color:#fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-link{color:#fff !important;}/*!sc*/
# .gFdQpP .site-footer.fixed{position:fixed;bottom:0;}/*!sc*/
# .gFdQpP .site-footer.dark{background-color:black;}/*!sc*/
# @media only screen and (max-width:844px){.gFdQpP .site-map{display:none;}}/*!sc*/
# data-styled.g25[id="styles__Container-xnhrx0-0"]{content:"gFdQpP,"}/*!sc*/
# .hiydsf .st0{opacity:1;fill:#dedede;}/*!sc*/
# .hiydsf .headerCamada_1 .st1{fill:#ffffff;}/*!sc*/
# .hiydsf .homeHeader{height:90vh;min-height:680px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100vw;background-color:#43566a;background-size:115%;background-repeat:no-repeat;background-position:center bottom;}/*!sc*/
# .hiydsf .headerCamada_1{width:100vw;height:auto;position:absolute;bottom:-70px;z-index:1;}/*!sc*/
# .hiydsf .hero-container{width:80%;height:55%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;z-index:2;}/*!sc*/
# .hiydsf .headerTextContainer{width:50%;padding-right:40px;}/*!sc*/
# .hiydsf .lottieContainer > div{width:100% !important;height:100% !important;}/*!sc*/
# .hiydsf .headerTitle{max-width:299px;color:#fff;margin-top:20px;font-weight:300;white-space:nowrap;}/*!sc*/
# .hiydsf .homeImage{width:50%;height:100%;position:relative;float:right;top:-30px;}/*!sc*/
# .hiydsf .btn__header{padding:0.5rem 1rem !important;background:#f5d01f !important;border-radius:5rem !important;color:#000 !important;-webkit-transition:all 0.5s ease-in-out !important;transition:all 0.5s ease-in-out !important;margin:unset !important;margin-top:30px !important;font-weight:400 !important;height:40px !important;}/*!sc*/
# .hiydsf .btn__header:focus{outline:none;}/*!sc*/
# @media (min-width:2001px){.hiydsf .headerCamada_1{bottom:-70px;}.hiydsf .headerTitle{font-size:20px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (min-width:1440px) and (max-width:2000px){.hiydsf .headerCamada_1{bottom:-70px;}.hiydsf .headerTitle{font-size:20px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (min-width:1025px) and (max-width:1439px){.hiydsf .headerCamada_1{bottom:-30px;}.hiydsf .headerTitle{font-size:18px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (max-width:1024px){.hiydsf .homeImage{display:none;}}/*!sc*/
# @media (min-width:769px) and (max-width:1024px){.hiydsf .headerCamada_1{bottom:-50px;}.hiydsf .homeHeader{height:unset;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;}.hiydsf .headerTitle{font-size:16px;margin:0 auto;margin-top:30px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# @media (min-width:426px) and (max-width:768px){.hiydsf .homeHeader{height:unset;}.hiydsf .headerCamada_1{bottom:-20px;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;width:70%;}.hiydsf .headerTitle{font-size:14px;margin:0 auto;margin-top:30px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# @media (max-width:425px){.hiydsf .homeHeader{height:unset;}.hiydsf .headerCamada_1{bottom:-8px;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;width:100%;}.hiydsf .headerTitle{font-size:12px;margin:0 auto;margin-top:50px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# data-styled.g26[id="headerContainer__Container-lvlhxg-0"]{content:"hiydsf,"}/*!sc*/
# .hmKeqD body{line-height:1.42857143;}/*!sc*/
# .hmKeqD .courses_cards__container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:75%;margin:0 auto 30px;}/*!sc*/
# .hmKeqD .courses_cards__container__title{width:80%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-weight:300;text-align:center;}/*!sc*/
# .hmKeqD .margin-45-center{margin:45px auto;}/*!sc*/
# .hmKeqD .card__link{-webkit-text-decoration:none;text-decoration:none;color:#3d3d3d;cursor:pointer;border:0 !important;-webkit-transition:-webkit-transform 1s;-webkit-transition:transform 1s;transition:transform 1s;-webkit-transition:transform 1s;width:50%;position:relative;}/*!sc*/
# .hmKeqD .card__link:hover,.hmKeqD .card__link:focus{-webkit-transform:translate(5px,5px);-ms-transform:translate(5px,5px);transform:translate(5px,5px);}/*!sc*/
# .hmKeqD .card{height:230px;background:#ffffff;margin-bottom:30px;margin:10px;box-shadow:2px 2px 15px rgba(0,0,0,0.5);-webkit-transition:box-shadow 1s;transition:box-shadow 1s;padding:20px;border-radius:10px 10px 10px 10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;text-align:center;}/*!sc*/
# .hmKeqD .card:hover,.hmKeqD .card:focus{-webkit-transition:box-shadow 1s;transition:box-shadow 1s;box-shadow:0px 0px 0px rgba(0,0,0,0);}/*!sc*/
# ...
# data-styled.g29[id="styles__Container-sc-13f0rp5-0"]{content:"hcVXtY,"}/*!sc*/
# .iUARkz .expandOpened{-webkit-transition:all 0.5s;transition:all 0.5s;-webkit-animation-name:sliceUp;animation-name:sliceUp;font-size:16px;}/*!sc*/
# .iUARkz .arrow{width:0;height:0;border-right:6px solid transparent;border-top:6px solid currentColor;border-left:6px solid transparent;-webkit-transition:all 0.5s ease-in-out;transition:all 0.5s ease-in-out;}/*!sc*/
# .iUARkz .expandClosed{padding-top:0 !important;padding-bottom:0 !important;border-width:0;margin:0 !important;font-size:0 !important;-webkit-animation-name:sliceDown;animation-name:sliceDown;-webkit-transition:all 0.5s;transition:all 0.5s;}/*!sc*/
# @-webkit-keyframes sliceUp{0%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}20%{-webkit-transform:scale(0.2);-ms-transform:scale(0.2);transform:scale(0.2);font-size:50%;}40%{font-size:100%;-webkit-transform:scale(0.4);-ms-transform:scale(0.4);transform:scale(0.4);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# @keyframes sliceUp{0%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}20%{-webkit-transform:scale(0.2);-ms-transform:scale(0.2);transform:scale(0.2);font-size:50%;}40%{font-size:100%;-webkit-transform:scale(0.4);-ms-transform:scale(0.4);transform:scale(0.4);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}/*!sc*/
# @-webkit-keyframes sliceDown{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}20%{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);font-size:50%;}40%{font-size:0;-webkit-transform:scale(0.4);-ms-transform:scale(0.4);transform:scale(0.4);}100%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}}/*!sc*/
# @keyframes sliceDown{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}20%{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);font-size:50%;}40%{font-size:0;-webkit-transform:scale(0.4);-ms-transform:scale(0.4);transform:scale(0.4);}100%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}}/*!sc*/
# data-styled.g30[id="styles__Container-sc-3r6whd-0"]{content:"iUARkz,"}/*!sc*/
# .bzsGnc{margin-left:15px;margin-right:15px;width:80px;}/*!sc*/
# .bzsGnc .rangeslider-horizontal{height:20px;border-radius:30px;box-shadow:unset;}/*!sc*/
# .bzsGnc .rangeslider__fill{border-radius:30px;box-shadow:unset;}/*!sc*/
# .bzsGnc .rangeslider__handle{height:20px;width:20px;}/*!sc*/
# .bzsGnc .rangeslider__handle:after{display:none;}/*!sc*/
# .bzsGnc .id0{background-color:#235070;}/*!sc*/
# .bzsGnc .id0 .rangeslider__fill{background-color:#235070;width:0px !important;}/*!sc*/
# .bzsGnc .id0 .rangeslider__handle{box-shadow:0 1px 3px #235070,0 -1px 3px #235070;}/*!sc*/
# .bzsGnc .id0 .rangeslider__handle:focus{outline:none;}/*!sc*/
# .bzsGnc .id1{background-color:#b8b8b8;}/*!sc*/
# .bzsGnc .id1 .rangeslider__fill{background-color:#b8b8b8;}/*!sc*/
# .bzsGnc .id1 .rangeslider__handle{box-shadow:0 1px 3px #b8b8b8,0 -1px 3px #b8b8b8;}/*!sc*/
# .bzsGnc .id1 .rangeslider__handle:focus{outline:none;}/*!sc*/
# .bzsGnc .id2{background-color:#f7b823 !important;}/*!sc*/
# .bzsGnc .id2 .rangeslider__fill{background-color:#f7b823;}/*!sc*/
# .bzsGnc .id2 .rangeslider__handle{box-shadow:0 1px 3px #f7b823,0 -1px 3px #f7b823;}/*!sc*/
# .bzsGnc .id2 .rangeslider__handle:focus{outline:none;}/*!sc*/
# @media (min-width:2001px){.bzsGnc{margin-left:26px;margin-right:26px;width:120px;}.bzsGnc .rangeslider-horizontal{height:42px;top:10px !important;}.bzsGnc .rangeslider__handle{height:38px;width:38px;}}/*!sc*/
# @media (max-width:2000px){.bzsGnc{margin-left:26px;margin-right:26px;width:100px;}.bzsGnc .rangeslider-horizontal{height:32px;top:14px !important;}.bzsGnc .rangeslider__handle{height:28px;width:28px;}}/*!sc*/
# @media (max-width:1600px){.bzsGnc{width:80px;}.bzsGnc .rangeslider-horizontal{height:30px;top:4px !important;}.bzsGnc .rangeslider__handle{height:26px;width:26px;}}/*!sc*/
# @media (max-width:1024px){.bzsGnc{margin-left:16px;margin-right:16px;}.bzsGnc .rangeslider-horizontal{top:-4px !important;}}/*!sc*/
# @media (max-width:425px){.bzsGnc .rangeslider-horizontal{top:-9px !important;}}/*!sc*/
# data-styled.g31[id="styles__Container-sc-1avcwfo-0"]{content:"bzsGnc,"}/*!sc*/
# .ckaEDu .homeSobre{background:#162d4b;width:100%;color:white;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:90vh;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;overflow:hidden;}/*!sc*/
# .ckaEDu .section__photos{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:35%;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}/*!sc*/
# .ckaEDu .section__description{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;height:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:20%;font-weight:500;}/*!sc*/
# .ckaEDu .sobre__text{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-weight:400;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;margin-bottom:0.8rem;}/*!sc*/
# .ckaEDu .sobre__text p{display:inline-block;direction:ltr;font-size:16px;line-height:25px;color:#fff;}/*!sc*/
# .ckaEDu .sobre-video{width:100%;position:absolute;object-fit:cover;height:90vh;}/*!sc*/
# .ckaEDu .social__icons{z-index:30;}/*!sc*/
# .ckaEDu .insta-icon{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;z-index:30;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fff !important;margin-bottom:6px;}/*!sc*/
# .ckaEDu .insta-icon div{margin-right:1vh !important;padding-bottom:0;}/*!sc*/
# .ckaEDu .slideshow{overflow:unset !important;top:8px;position:relative;}/*!sc*/
# .ckaEDu .slide-content{margin-left:0;position:relative;-webkit-filter:grayscale(100%);filter:grayscale(100%);-webkit-transition:all 1s;transition:all 1s;-webkit-transform-origin:bottom;-ms-transform-origin:bottom;transform-origin:bottom;width:100%;}/*!sc*/
# .ckaEDu .slide-content:hover{overflow:visible;z-index:5;position:relative;width:auto;-webkit-transform:scale(1.4);-ms-transform:scale(1.4);transform:scale(1.4);-webkit-filter:grayscale(0%);filter:grayscale(0%);width:100%;}/*!sc*/
# .ckaEDu .slide-content > div{width:100%;pointer-events:none;}/*!sc*/
# .ckaEDu .fade-background{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;position:absolute;top:0;right:0;z-index:0;background:linear-gradient(rgba(0,0,0,0.7),rgba(0,0,0,0.5));}/*!sc*/
# .ckaEDu .sobre-photo{width:100% !important;height:100% !important;min-width:unset !important;min-height:unset !important;max-width:unset !important;max-height:unset !important;}/*!sc*/
# @media only screen and (min-width:845px){.ckaEDu .mobile-slider{display:none;}}/*!sc*/
# @media only screen and (max-width:844px){.ckaEDu .sobre-video,.ckaEDu .about-slider-desktop{display:none;}.ckaEDu .fade-background{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}.ckaEDu .homeSobre{height:800px;}.ckaEDu .section__description{width:100%;height:auto;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.ckaEDu .sobre__text{padding:9vw;margin-bottom:0;text-align:center;}.ckaEDu .social__icons{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0 0 9vw 0;padding:0 9vw;gap:1.5rem 0;}.ckaEDu .social__icons > a{font-size:0.7rem;font-weight:500;margin:0 auto;}.ckaEDu .social__icons > .insta-icon{position:relative;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:5;}.ckaEDu .insta-icon{-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;}.ckaEDu .insta-icon,.ckaEDu .insta-icon span{white-space:nowrap;font-size:0.7rem;padding:0.2rem 0;margin-right:4px;font-weight:400;}.ckaEDu .section__photos{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100%;overflow:auto;}.ckaEDu .mobile-slider{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;height:100%;overflow:auto;}.ckaEDu .mobile-slider > div{overflow:auto;}.ckaEDu .mobile-slider > div > div{height:100%;}.ckaEDu .sobre-photo{-webkit-filter:grayscale(100%);filter:grayscale(100%);height:100%;opacity:0.65;}}/*!sc*/
# @media only screen and (min-width:845px){.ckaEDu .fade-background{-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}.ckaEDu .sobre__text{padding-right:15%;}.ckaEDu .section__description{width:23%;}.ckaEDu .sobre-photo{bottom:0;left:0;position:absolute;}}/*!sc*/
# @media (max-width:425px){.ckaEDu .homeSobre{height:700px;}}/*!sc*/
# data-styled.g32[id="aboutContainer__Container-sc-1ffoois-0"]{content:"ckaEDu,"}/*!sc*/
# .hLalRg #slider{width:100%;background:#fff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:2% 2%;z-index:2;}/*!sc*/
# .hLalRg .home__slider{background:#fff;width:80%;margin:0 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-filter:blur(0px);filter:blur(0px);}/*!sc*/
# .hLalRg .slider__img > div{object-fit:scale-down !important;height:60px !important;width:140px !important;padding:0;}/*!sc*/
# .hLalRg .slider__img > div img{height:100% !important;width:100% !important;}/*!sc*/
# .hLalRg .slider__img > div > div{height:100% !important;}/*!sc*/
# .hLalRg .home__slider .slider{background-color:#fff;}/*!sc*/
# @media (min-width:1024px){.hLalRg .partners_mobile_container{display:none;}}/*!sc*/
# @media (max-width:1023px){.hLalRg #slider{padding:0 2% 2%;}.hLalRg .home__slider img{height:48px;}.hLalRg .home-slideshow-desktop{display:none;}.hLalRg .partners_mobile_container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:30px;}.hLalRg .partners_mobile_container > div > div img{height:60px !important;width:120px !important;}}/*!sc*/
# @media (max-width:768px){.hLalRg #slider{padding:0 2% 4%;}.hLalRg .home__slider img{height:50px;}}/*!sc*/
# @media (max-width:425px){.hLalRg .home__slider{width:100%;}.hLalRg #slider{padding:0 5% 9%;}.hLalRg .home__slider img{height:125px;}}/*!sc*/
# data-styled.g33[id="homeSliderContainer__Container-sc-150npjf-0"]{content:"hLalRg,"}/*!sc*/
# </style><style data-href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700,800,900&display=swap">@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTUSjIg1_i6t8kCHKm459WlhzQ.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_ZpC3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:600;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_bZF3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_dJE3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_c5H3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:900;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_epG3gnD-A.woff) format('woff')}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3gTD_vx3rCubqg.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3g3D_vx3rCubqg.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3gbD_vx3rCubqg.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3gfD_vx3rCubqg.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTURjIg1_i6t8kCHKm45_cJD3gnD_vx3rCs.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTUSjIg1_i6t8kCHKm459WZhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v15/JTUSjIg1_i6t8kCHKm459WdhyyTh89ZNpQ.woff2) format('woff2');unicode-rang ...

# %% [markdown]
# Agora que conhecemos um pouco mais sobre HTML, vamos ao nosso objetivo principal: webscraping!

# %% [markdown]
# ___
# ___
# ___

# %% [markdown]
# ## 2) Webscraping
#
# O webscraping significa "raspagem de sites", e é exatamente esse o seu propósito: **extrair informações de um website**, para que estas possam ser utilizadas no Python.
#
# **Para que iríamos querer fazer isso?**
#
# Imagine que você queira coletar dados de um site que não disponibiliza uma API: usar webscraping é uma forma direta de fazer isso!
#
# Ou então, se vc precisa periodicamente tomar informações de um site, de forma automática.

# %% [markdown]
# A biblioteca padrão para webscraping do Python é o `beautiful soup`.
#
# Essa biblioteca é capaz de ler o HTML de um site, e criar um objeto a partir dele.
#
# Com isso, fica fácil acessar alguns elementos do site, como tabelas ou valores!
#
# Vamos aprender a usá-lo!

# %% [markdown]
# __IMPORTANTE: em webscraping, cada caso é um caso!__
#
# Então, é importante aprender o princípio da técnica, e adapta-la para seu caso.
#
# Nesta aula, vamos extrair as informações resumidas sobre cada curso que a Let's Code oferece.
#
# Extrairemos: **título, pré-requisito e link para a página do curso.**
#
# O site é: https://letscode-academy.com/

# %% [markdown]
# A primeira coisa é explorar o site, para descobrir como a informação que queremos extrair está codificada em HTML.
#
# Pelas ferramentas de inspeção de código e elementos em um navegador, observamos que todas elas estão contidas em tags `<a class='card__link'>`
#
# Vamos utilizar o bs4 para encontrar essa estrutura no HTML!
#
# O passo-a-passo é:
#
# - Use a requests para fazer uma requisição ao site, com o método `.get()`;
# - Capte o HTML do site com o atributo `.text`;
# - Instancie a classe `BeautifulSoup` da `bs4`para criar o objeto referente ao HTML;
#     - Os argumentos são o HTML captado do requests e o argumento "html.parser" para a construção do objeto
# - Com issso, o objeto está criado!
#
# ### OBSERVAÇÃO IMPORTANTE:
#
# Com o uso dos frameworks de frontend, há casos (como, por exemplo, do site da Let's Code até, pelo menos, Abril de 2021) em que o HTML não está completo no momento do carregamento da página, de modo a ser acessado imediatamente com a requests, pois parte do HTML é renderizado apenas no navegador. Nestes casos, é necessário usar o webdriver do selenium para que o HTML seja captado!
#
# Por esta ser uma abordagem mais geral, é ela que seguiremos aqui neste Notebook, e recomendamos ser seguida.
#
# No entanto, é importante frisar que **a única alteração** no procedimento é na forma como o HTML é capturado. Daí pra frente, o procedimento é **exatamente o mesmo** (do que seria se o HTML fosse capturado com o requests), com a utilização do bs4 para a criação do objeto sopa, e daí por diante.
#
# Assim, o passo-a-passo acima é alterado para:
#
# - Use o selenium e seu webdriver para fazer a requisição ao site, com o método `get()`;
# - Capte o HTML do site com os métodos `find_element_by_tag_name('body')` e `get_attribute('innerHTML')`;
# - Instancie a classe `BeautifulSoup` da `bs4`para criar o objeto referente ao HTML;
#     - Os argumentos são o HTML captado do requests e o argumento "html.parser" para a construção do objeto
# - Com isso, o objeto está criado!

# %% [markdown]
# **Obs.:** para instalar o selenium siga as orientações na página: https://pypi.org/project/selenium/
#
# Coloque o arquivo do driver baixado em uma pasta e adicione essa pasta ao PATH ou, mais fácil, passe o endereço do driver na hora de instanciar o webdriver, como em:
#
# ```python
# from selenium import webdriver
# driver = webdriver.Chrome('caminho/para/o/driver/chromedriver.exe')
# ```

# %%
# !pip install selenium

# %%
import bs4
import requests
from bs4 import BeautifulSoup

# %%
pagina = requests.get('https://letscode.com.br/').text

# %%
type(pagina)
# Out:
# str

# %%
soup = BeautifulSoup(pagina, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR">
#  <head>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link data-href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700,800,900&amp;display=swap" data-optimized-fonts="true" rel="stylesheet"/>
#   <title>
#    Let's Code | Cursos de Programação
#   </title>
#   <meta content="Let's Code | Cursos de Programação" name="title" property="og:title"/>
#   <meta content="website" name="type" property="og:type"/>
#   <meta content="Cursos de programação presenciais e online em diversas linguagens. Teste grátis nossa plataforma." name="description" property="og:description"/>
#   <meta content="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/2020/siteLink.webp" property="og:image"/>
#   <meta content="t5kwc6pngnapypj4hb9tea9175jero" name="facebook-domain-verification"/>
#   <meta content="Let's Code" property="og:site_name"/>
#   <meta content="1041575599256742" property="fb:admins"/>
#   <meta content="https://www.letscode.com.br/" property="og:url"/>
#   <meta content="14" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/c9cfe64be795bdfbd342.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/c9cfe64be795bdfbd342.css" rel="stylesheet"/>
#   <link as="style" href="/_next/static/css/665eecc29acf6a610c2d.css" rel="preload"/>
#   <link data-n-p="" href="/_next/static/css/665eecc29acf6a610c2d.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-e7a279300235e161e32a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/58.8c3d26db2d823bc93199.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/899.dc7dea62dba8414f66b7.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/914.6964afa34770eb66baec.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-285f8fdb86df5305d037.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-b5f3c897a40b4b93d7e6.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-18e5535ffc85f4a7d113.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-2fab4aa7b52c055adc6c.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/ea88be26-0a0afb72237add43f7a9.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/902-5e844057a461f75382ea.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/260-b8b4d5e3e9c09b59581a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/1-cf1e458cd7e1ed7dd09e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/356-9fc421f5939c8349b743.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/593-a4749b500b48a3b0ba86.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/index-e597dca0770ced873de7.js">
#   </script>
#   <script defer="" src="/_next/static/I_EDgVdhbkind1jdpHsgG/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/I_EDgVdhbkind1jdpHsgG/_ssgManifest.js">
#   </script>
#   <style data-styled="" data-styled-version="5.3.0">
#    .doOaWk .navbar{min-height:75px;border:1px solid transparent;-webkit-transition:all 0.5s ease-out;-moz-transition:all 0.5s ease-out;-o-transition:all 0.5s ease-out;-webkit-transition:all 0.5s ease-out;transition:all 0.5s ease-out;padding:0 10px;}/*!sc*/
# .doOaWk .arrow-up{border:solid #fff;border-width:0 3px 3px 0;display:inline-block;position:relative;top:4px;width:18px;height:18px;-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);}/*!sc*/
# .doOaWk .navbar:hover{background-color:#0b1923;}/*!sc*/
# .doOaWk .multiple-dropdown-label1{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:10px;border-bottom-left-radius:6px;border-bottom-right-radius:6px;}/*!sc*/
# .doOaWk .multiple-dropdown-label1 > svg{font-size:20px;-webkit-transform:rotate(-90deg);-ms-transform:rotate(-90deg);transform:rotate(-90deg);margin-right:5px;}/*!sc*/
# .doOaWk .multiple-dropdown-label1:hover{background-color:#162f40;}/*!sc*/
# .doOaWk .multiple-dropdown-label1:hover .multiple-dropdown-options-container1{display:block;}/*!sc*/
# .doOaWk .multiple-dropdown-label1.dark:hover{background-color:#070707;color:#00fafd;}/*!sc*/
# .doOaWk .multiple-dropdown-label1.pi:hover{background-color:#f7b823;color:#000;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container2{position:absolute;left:0%;width:203px;top:0;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container3{background-color:#11222f;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;z-index:0;border-bottom-left-radius:6px;border-bottom-right-radius:6px;position:absolute;left:-112%;top:0;width:228px;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container3 > a{width:100%;}/*!sc*/
# .doOaWk .multiple-dropdown-options-container1{display:none;}/*!sc*/
# .doOaWk .multiple-dropdown-options-title{font-weight:600;opacity:0.3;margin:5px auto;padding:10px 10px 5px;width:100%;font-size:14px;border-bottom:1px solid #1e3849;color:#fff;}/*!sc*/
# .doOaWk .navbar.scrolled{background-color:#0b1923;}/*!sc*/
# .doOaWk .navbar-item{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;}/*!sc*/
# .doOaWk .navbar-item,.doOaWk .navbar-link{color:#4a4a4a;display:block;line-height:1.5;padding:0.5rem 0.75rem;position:relative;}/*!sc*/
# .doOaWk #navbar-logo{line-height:2.9;}/*!sc*/
# .doOaWk .item-img > div > div{width:0px;}/*!sc*/
# .doOaWk .navbar-img{-webkit-filter:brightness(1);filter:brightness(1);height:auto !important;width:auto !important;position:relative !important;max-height:1.75rem !important;min-width:unset !important;}/*!sc*/
# .doOaWk img{height:auto;max-width:100%;}/*!sc*/
# .doOaWk .navbar-brand{float:left;height:50px;padding:0 15px;font-size:18px;line-height:20px;}/*!sc*/
# .doOaWk .navbar-item.has-dropdown{padding:0.5rem 0.75rem;}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-brand,.doOaWk .navbar-item{-webkit-align-items:normal !important;-webkit-box-align:normal !important;-ms-flex-align:normal !important;align-items:normal !important;}.doOaWk .navbar,.doOaWk .navbar-end,.doOaWk .navbar-menu,.doOaWk .navbar-start{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}.doOaWk .navbar-menu .navbar-item{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;}.doOaWk .navbar-menu .navbar-link{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;}.doOaWk .navbar-dropdown{left:0;}}/*!sc*/
# .doOaWk .navbar-menu{padding:0px 30px 0px 40px;height:37px;-webkit-box-flex:unset;-webkit-flex-grow:unset;-ms-flex-positive:unset;flex-grow:unset;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;display:none;}/*!sc*/
# .doOaWk .navbar.is-fixed-bottom,.doOaWk .navbar.is-fixed-top{left:0;position:fixed;right:0;z-index:30;}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-menu a.navbar-item:hover,.doOaWk .navbar-menu .navbar-item:hover{background:none;color:#fff;}.doOaWk .navbar-menu a.navbar-item:focus,.doOaWk .navbar-menu .navbar-item:focus{background:none;color:#fff;}.doOaWk .navbar-dropdown-mobile{display:none;}.doOaWk .arrow-dropdown{display:none;}}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item{font-weight:500;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:0.5rem 0.8rem;padding-right:2.5rem;-webkit-transition:0.1s;transition:0.1s;text-align:left;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item:hover,.doOaWk .navbar-dropdown a.navbar-item:focus{color:#fff;background-color:#162f40;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown.pi a.navbar-item:hover{color:#000;background-color:#f7b823;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown.pi a.navbar-item:focus{background-color:#f7b823;color:#000;}/*!sc*/
# .doOaWk .navbar-dropdown.dark a.navbar-item:hover{background-color:#070707;color:#00fafd;-webkit-transition:0.1s;transition:0.1s;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item:focus{background-color:#162f40;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item,.doOaWk .navbar-menu .navbar-item{background:none;position:relative;color:#fff;-webkit-text-decoration:none;text-decoration:none;font-weight:300;font-size:14px;cursor:pointer;border-bottom-left-radius:6px;border-bottom-right-radius:6px;}/*!sc*/
# .doOaWk .navbar-end > .navbar-item{padding-top:28px;padding-bottom:28px;}/*!sc*/
# .doOaWk .navbar-end .nav-item-name{border-bottom:1px solid transparent;padding:4px 0;-webkit-transition:all 0.4s;transition:all 0.4s;}/*!sc*/
# .doOaWk .navbar-end .nav-item-name:hover,.doOaWk .navbar-end .nav-item-name:focus{border-bottom:1px solid #edd647;-webkit-transition:all 0.4s;transition:all 0.4s;}/*!sc*/
# .doOaWk .navbar-dropdown.close,.doOaWk .navbar-dropdown.close a.nav-item-name{content:'';position:absolute;height:0;-webkit-transition:0.6s;transition:0.6s;}/*!sc*/
# .doOaWk .navbar .navbar-dropdown a.navbar-item:before{content:'';position:absolute;width:60%;margin:0 20%;height:0px;bottom:0;font-size:0;left:0;background-color:transparent !important;-webkit-transition:0.6s;transition:0.6s;}/*!sc*/
# .doOaWk .navbar .is-fixed-top .navbar-menu{border-radius:10px;text-align:center;padding:10px;position:relative;z-index:1;margin:10px;}/*!sc*/
# .doOaWk .navbar-item.has-dropdown{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .doOaWk .navbar-dropdown{padding:0;-webkit-transition:all 500ms;transition:all 500ms;-o-transition:all 500ms;-moz-transition:all 500ms;-webkit-transition:all 500ms;display:block;-webkit-transform:scaleY(0);-ms-transform:scaleY(0);transform:scaleY(0);-webkit-transform-origin:top;-ms-transform-origin:top;transform-origin:top;font-weight:350;margin-top:-6px;}/*!sc*/
# .doOaWk .navbar-item:hover .navbar-dropdown:not(.close){-webkit-transform:scaleY(1);-ms-transform:scaleY(1);transform:scaleY(1);background-color:#11222f;}/*!sc*/
# .doOaWk .arrow.white{border:solid currentColor;border-width:0 1px 1px 0;padding:3px;position:relative;}/*!sc*/
# .doOaWk .arrow.white.up{-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);top:2px;right:6px;}/*!sc*/
# .doOaWk .arrow.white.down{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);-webkit-transform:rotate(45deg);top:-1px;right:6px;}/*!sc*/
# .doOaWk .arrow.white.left{-webkit-transform:rotate(135deg);-ms-transform:rotate(135deg);transform:rotate(135deg);-webkit-transform:rotate(135deg);top:0px;margin-right:8px;margin-left:6px;border-width:0 2px 2px 0;}/*!sc*/
# .doOaWk .arrow.black{border:solid currentColor;border-width:0 1px 1px 0;padding:3px;position:relative;}/*!sc*/
# .doOaWk .arrow.black.up{-webkit-transform:rotate(-135deg);-ms-transform:rotate(-135deg);transform:rotate(-135deg);-webkit-transform:rotate(-135deg);top:2px;right:6px;}/*!sc*/
# .doOaWk .arrow.black.down{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);-webkit-transform:rotate(45deg);top:-1px;right:6px;}/*!sc*/
# .doOaWk .navbar-dropdown-container.pi{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar-dropdown-container.pi > div > a{color:#fff !important;}/*!sc*/
# .doOaWk .navbar.pi:hover{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar.scrolled.pi{background-color:#1d1d1b;}/*!sc*/
# .doOaWk .navbar.scrolled.dark{background:linear-gradient(to right,#070707,#121212);}/*!sc*/
# .doOaWk .navbar.dark:hover{background:linear-gradient(to right,#070707,#121212);}/*!sc*/
# .doOaWk .navbar-img.dark{-webkit-filter:brightness(0) invert();filter:brightness(0) invert();}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.active.dark:before,.doOaWk .navbar-menu .navbar-item.dark.active:before{background-color:transparent;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.dark:before,.doOaWk .navbar-menu span.navbar-item.dark:before{background:transparent;}/*!sc*/
# .doOaWk .navbar-menu a.navbar-item.dark:hover:before,.doOaWk .navbar-menu span.navbar-item.dark:hover:before{background:#00fafd;}/*!sc*/
# .doOaWk .navbar-dropdown a.navbar-item.dark:before,.doOaWk .navbar-dropdown a.navbar-item:before{background:none;}/*!sc*/
# .doOaWk .navbar-dropdown.dark{border-color:#00fafd;}/*!sc*/
# .doOaWk .navbar-dropdown-container.dark{background:linear-gradient(to left,#070707,#121212);}/*!sc*/
# .doOaWk .navbar-burger{color:#f7d42f;cursor:pointer;display:block;height:3.25rem;position:relative;width:3.25rem;margin-left:auto;outline:none;margin-right:15px;}/*!sc*/
# .doOaWk .navbar-burger:hover{background-color:rgba(0,0,0,0.05);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:first-child{-webkit-transform:translateY(5px) rotate(45deg);-moz-transform:translateY(5px) rotate(45deg);-webkit-transform:translateY(5px) rotate(45deg);-ms-transform:translateY(5px) rotate(45deg);transform:translateY(5px) rotate(45deg);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:nth-child(3){-webkit-transform:translateY(-5px) rotate(-45deg);-moz-transform:translateY(-5px) rotate(-45deg);-webkit-transform:translateY(-5px) rotate(-45deg);-ms-transform:translateY(-5px) rotate(-45deg);transform:translateY(-5px) rotate(-45deg);}/*!sc*/
# .doOaWk .navbar-burger span:first-child{top:-moz-calc(50% - 6px);top:calc(50% - 6px);}/*!sc*/
# .doOaWk .navbar-burger span:nth-child(2){top:-moz-calc(50% - 1px);top:calc(50% - 1px);}/*!sc*/
# .doOaWk .navbar-burger.is-active span:nth-child(2){opacity:0;}/*!sc*/
# .doOaWk .navbar-burger span:nth-child(3){top:-moz-calc(50% + 4px);top:calc(50% + 4px);}/*!sc*/
# .doOaWk .navbar-burger span{background-color:currentColor;display:block;height:1px;left:-moz-calc(50% - 8px);left:calc(50% - 8px);position:absolute;-webkit-transform-origin:center;-moz-transform-origin:center;-webkit-transform-origin:center;-ms-transform-origin:center;transform-origin:center;-webkit-transition-duration:86ms;-moz-transition-duration:86ms;-webkit-transition-duration:86ms;transition-duration:86ms;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;transition-property:background-color,opacity,-webkit-transform;-moz-transition-property:background-color,opacity,transform,-moz-transform;-webkit-transition-property:background-color,opacity,-webkit-transform;-webkit-transition-property:background-color,opacity,transform;transition-property:background-color,opacity,transform;-webkit-transition-property:background-color,opacity,-webkit-transform,-webkit-transform,-moz-transform;-webkit-transition-property:background-color,opacity,transform,-webkit-transform,-moz-transform;transition-property:background-color,opacity,transform,-webkit-transform,-moz-transform;-webkit-transition-timing-function:ease-out;-moz-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;width:16px;}/*!sc*/
# .doOaWk span{font-style:inherit;font-weight:inherit;}/*!sc*/
# .doOaWk .dark .navbar-burger{color:white;}/*!sc*/
# .doOaWk .navbar-brand{padding:0 15px !important;}/*!sc*/
# @media only screen and (max-width:1023px){.doOaWk .navbar-dropdown-desktop{display:none;}.doOaWk .navbar{min-height:50px;}.doOaWk .navbar-menu a.navbar-item.dark,.doOaWk .navbar-menu .navbar-item.dark{font-size:16px;color:#fff;font-weight:500;}.doOaWk .navbar-item.item-img{padding-left:0;}.doOaWk .navbar-menu a.navbar-item,.doOaWk .navbar-menu .navbar-item{font-size:16px;color:#000;font-weight:300;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-right:12.8px;}.doOaWk .dark.modal-code .modal-close{background-color:white;}.doOaWk .dark.modal-code .modal-close:before,.doOaWk .dark.modal-code .modal-close:after{background-color:black;}.doOaWk .navbar{padding:0;}.doOaWk .navbar-menu{height:auto;}.doOaWk .navbar-brand{width:100%;-webkit-transition:background-color 0.5s ease-in-out;transition:background-color 0.5s ease-in-out;}.doOaWk .navbar.is-fixed-top .navbar-menu{border-radius:10px;text-align:center;padding:10px;position:relative;z-index:1;margin:10px;}.doOaWk .navbar-end > .navbar-item{padding-top:0.4rem;padding-bottom:0.4rem;}.doOaWk .navbar-end > .navbar-item:not(:last-child){border-bottom:1px solid #8c8c8c;}.doOaWk .navbar-menu.is-active.dark{background-color:#000;}.doOaWk .nav-item-name{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.doOaWk .nav-item-name svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.doOaWk .navbar-end .nav-item-name:hover,.doOaWk .navbar-end .nav-item-name:focus{border-bottom:none;-webkit-transition:none;transition:none;}.doOaWk .navbar-item:hover .navbar-dropdown:not(.close){background-color:transparent;}.doOaWk .navbar-dropdown{-webkit-transform:none;-ms-transform:none;transform:none;}.doOaWk .dropdown-title{background-color:#1a2d3c;color:white;border-radius:5px;margin:10px 0;padding:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-size:14px;}.doOaWk .dropdown-title svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);margin-right:5px;}.doOaWk .section-container-mobile{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:20px;margin-bottom:10px;border-bottom:1px solid #8c8c8c;font-size:14px;}.doOaWk .section-container-mobile.dark{border-bottom:1px solid white;}}/*!sc*/
# @media (max-width:320px){.doOaWk .dropdown-title{font-size:12px;}}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar-dropdown{border-top:none;background-color:#fff;border-bottom-left-radius:6px;border-bottom-right-radius:6px;font-size:0.875rem;left:-30px;min-width:100%;position:absolute;top:105%;z-index:20;}}/*!sc*/
# @media screen and (min-width:1024px){.doOaWk .navbar,.doOaWk .navbar-end,.doOaWk .navbar-menu,.doOaWk .navbar-start{-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.doOaWk .navbar-burger{display:none;}}/*!sc*/
# @media screen and (max-width:1023px){.doOaWk .navbar-menu.is-active{display:block;}.doOaWk .navbar-menu{background-color:#fff;-moz-box-shadow:0 8px 16px rgba(10,10,10,0.1);box-shadow:0 8px 16px rgba(10,10,10,0.1);padding:0.5rem 0;}.doOaWk .navbar.is-fixed-top-touch .navbar-menu,.doOaWk .navbar.is-fixed-top .navbar-menu{-webkit-overflow-scrolling:touch;max-height:-moz-calc(100vh - 3.25rem);max-height:calc(100vh - 3.25rem);overflow:auto;}.doOaWk .navbar-menu{background-color:#fff;-moz-box-shadow:0 8px 16px rgba(10,10,10,0.1);box-shadow:0 8px 16px rgba(10,10,10,0.1);padding:0.5rem 0;}}/*!sc*/
# data-styled.g1[id="styles__Container-tke1hi-0"]{content:"doOaWk,"}/*!sc*/
# .bgWhoP .header-bottom{position:fixed;z-index:50;bottom:0;pointer-events:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .bgWhoP .header-bottom-links{margin:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;pointer-events:none;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .bgWhoP .whatsLink{height:50px;width:50px;z-index:50;pointer-events:all;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;box-shadow:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:#009746;border-radius:50%;position:relative;}/*!sc*/
# .bgWhoP .scrollTop{height:50px;width:50px;box-shadow:none;z-index:50;pointer-events:all;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;cursor:pointer;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-radius:50%;background:#162d4b;border:2px solid #f7d42f;position:relative;}/*!sc*/
# .bgWhoP .scrollTop svg{font-size:40px;color:#fff;position:absolute;left:50%;top:calc(50% - 2px);-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# @media only screen and (max-width:1023px){.bgWhoP .header-bottom.active{bottom:40px;}.bgWhoP .scrollTop,.bgWhoP .whatsLink{height:40px;width:40px;bottom:6px;}.bgWhoP .scrollTop div,.bgWhoP .whatsLink div{width:30px;height:30px;}}/*!sc*/
# @media only screen and (max-width:512px){.bgWhoP .header-bottom.active{bottom:68px;}}/*!sc*/
# data-styled.g2[id="styles__Container-t3m083-0"]{content:"bgWhoP,"}/*!sc*/
# .iNTbyI a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;color:white;}/*!sc*/
# .iNTbyI .site-footer{background-color:#0b1923;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;color:#fff;font-size:12px;width:100%;position:relative;padding:30px 100px 15px 80px;}/*!sc*/
# .iNTbyI .site-footer.dark{background-color:#222121 !important;}/*!sc*/
# .iNTbyI .site-footer.extended{padding-bottom:80px;}/*!sc*/
# .iNTbyI .footer-contato{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-left:2rem;}/*!sc*/
# .iNTbyI .footer-contato svg{color:#fff;font-size:1.25rem;}/*!sc*/
# .iNTbyI .footer-contato a + a svg{margin-left:1rem;}/*!sc*/
# .iNTbyI .footer-container-phone{width:200px;position:relative;right:-40%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .iNTbyI .footer-container-address{cursor:pointer;width:250px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#fff;}/*!sc*/
# .iNTbyI .footer-container-address:hover{color:#4343ff;}/*!sc*/
# .iNTbyI .footer-text{font-size:16px;font-weight:400;text-align:left;padding-left:10px;}/*!sc*/
# .iNTbyI .footer-text-small{font-size:12px;}/*!sc*/
# .iNTbyI .react-logo-wrapper{height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .iNTbyI .react-logo-wrapper > svg{margin-left:10px;}/*!sc*/
# .iNTbyI .footer-logo{width:150px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0 auto;}/*!sc*/
# .iNTbyI .footer-logo-container{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media (max-width:1024px){.iNTbyI .footer-logo{display:none;}}/*!sc*/
# @media (max-width:768px){.iNTbyI .footer-container-address:hover{color:#fff;}}/*!sc*/
# @media only screen and (max-width:425px){.iNTbyI .site-footer{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;}.iNTbyI .footer-container-phone{position:initial;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.iNTbyI .footer-container-address{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 0 23px;margin-bottom:20px;}}/*!sc*/
# data-styled.g4[id="styles__Container-sc-85gh8u-0"]{content:"iNTbyI,"}/*!sc*/
# .exaHbn .quiz-footer{position:fixed;bottom:0;width:100%;background:#0b1923;color:#fff;text-align:center;padding:10px 0px 10px;line-height:24px;font-weight:400;-webkit-letter-spacing:0.1px;-moz-letter-spacing:0.1px;-ms-letter-spacing:0.1px;letter-spacing:0.1px;-webkit-text-decoration:none;text-decoration:none;z-index:30;}/*!sc*/
# .exaHbn .quiz-footer.dark{background:#222121;}/*!sc*/
# .exaHbn .quiz-link{color:#fff;}/*!sc*/
# .exaHbn #mdiv{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;cursor:pointer;}/*!sc*/
# .exaHbn .mdiv{height:10px;width:2px;background-color:#fff;-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);z-index:1;left:24px;top:0px;position:relative;}/*!sc*/
# .exaHbn .md{height:10px;width:2px;background-color:#fff;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);z-index:2;}/*!sc*/
# .exaHbn .quiz-footer-text-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media only screen and (min-width:1024px){.exaHbn .quiz-link:hover{-webkit-text-decoration:underline;text-decoration:underline;color:#fac43c;}}/*!sc*/
# @media only screen and (max-width:1023px){.exaHbn .quiz-footer{padding:10px 0px 10px;}.exaHbn .quiz-link{-webkit-text-decoration:underline;text-decoration:underline;}.exaHbn .call-upper{display:none;}.exaHbn .quiz-footer-text-container{width:60%;margin:0 auto;}}/*!sc*/
# data-styled.g5[id="styles__Container-nzozqa-0"]{content:"exaHbn,"}/*!sc*/
# .duKImY .typography.h1{font-size:110px;}/*!sc*/
# .duKImY .typography.h2{font-size:96px;}/*!sc*/
# .duKImY .typography.h3{font-size:68px;}/*!sc*/
# .duKImY .typography.h4{font-size:60px;}/*!sc*/
# .duKImY .typography.title1{font-size:42px;}/*!sc*/
# .duKImY .typography.title2{font-size:34px;}/*!sc*/
# .duKImY .typography.subtitle1{font-size:26px;}/*!sc*/
# .duKImY .typography.subtitle2{font-size:20px;}/*!sc*/
# .duKImY .typography.body1{font-size:16px;}/*!sc*/
# .duKImY .typography.body2{font-size:14px;}/*!sc*/
# .duKImY .typography.caption1{font-size:12px;}/*!sc*/
# .duKImY .typography.caption2{font-size:10px;}/*!sc*/
# .duKImY .typography.button{font-size:16px;}/*!sc*/
# @media (max-width:768px){.duKImY .typography.h1{font-size:96px;}.duKImY .typography.h2{font-size:68px;}.duKImY .typography.h3{font-size:60px;}.duKImY .typography.h4{font-size:42px;}.duKImY .typography.title1{font-size:32px;}.duKImY .typography.title2{font-size:26px;}.duKImY .typography.subtitle1{font-size:20px;}.duKImY .typography.subtitle2{font-size:16px;}.duKImY .typography.body1{font-size:14px;}.duKImY .typography.body2{font-size:12px;}.duKImY .typography.caption1{font-size:10px;}.duKImY .typography.caption2{font-size:8px;}.duKImY .typography.button{font-size:14px;}}/*!sc*/
# data-styled.g6[id="styles__Container-sc-1510a04-0"]{content:"duKImY,"}/*!sc*/
# .kvXAYG{width:100%;}/*!sc*/
# .kvXAYG .slide-container{position:relative;margin:0 auto;}/*!sc*/
# .kvXAYG .slide-container.active{cursor:-webkit-grabbing;cursor:-moz-grabbing;cursor:grabbing;}/*!sc*/
# .kvXAYG .slideshow{margin:0 auto;overflow:hidden;}/*!sc*/
# .kvXAYG .slideshowSlider{white-space:nowrap;-webkit-transition:-webkit-transform 0.0s ease-in-out;-webkit-transition:transform 0.0s ease-in-out;transition:transform 0.0s ease-in-out;-webkit-perspective:1000;-webkit-backface-visibility:hidden;-webkit-transform:translateZ(0);-ms-transform:translateZ(0);transform:translateZ(0);will-change:transform;}/*!sc*/
# .kvXAYG .slide{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;border-radius:40px;white-space:normal;}/*!sc*/
# .kvXAYG .slide img{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-moz-user-select:none;-khtml-user-select:none;-webkit-user-select:none;-o-user-select:none;}/*!sc*/
# .kvXAYG .slide-wrapper{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .kvXAYG .slide-content{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kvXAYG .slideshowDots{text-align:center;width:90%;margin:auto;}/*!sc*/
# .kvXAYG .slideshowDot{cursor:pointer;height:4px;width:6px;margin:0 0.125rem;background-color:#c4c4c4;border-radius:8px;display:inline-block;-webkit-transition:background-color 1s ease-out,width 0.6s ease-out;-webkit-transition:background-color 1s ease-out,width 0.6s ease-out;transition:background-color 1s ease-out,width 0.6s ease-out;}/*!sc*/
# .kvXAYG .slideshowDot.active{background-color:#374952;width:10px;}/*!sc*/
# .kvXAYG .slideshowDot.hidden{display:none;}/*!sc*/
# .kvXAYG .arrowImage{width:30px;height:30px;position:absolute;cursor:pointer;z-index:2;top:50%;}/*!sc*/
# .kvXAYG .arrowImage.prev{left:0px;}/*!sc*/
# .kvXAYG .arrowImage.next{right:0px;}/*!sc*/
# @media (max-width:475px){.kvXAYG .arrowImage{width:20px;height:20px;}}/*!sc*/
# data-styled.g9[id="styles__Container-jqng2s-0"]{content:"kvXAYG,"}/*!sc*/
# .fnlVyd .input-container{height:100%;color:#000;}/*!sc*/
# .fnlVyd .validation-icons{position:absolute;right:2px;top:4px;}/*!sc*/
# .fnlVyd .input__container{width:100%;position:relative;height:40px;}/*!sc*/
# .fnlVyd .input__invalid_message{position:absolute;top:27px;margin-left:10px;font-size:14px;color:red;}/*!sc*/
# .fnlVyd .input-holder input{outline-color:transparent;font-family:'Montserrat',sans-serif;}/*!sc*/
# .fnlVyd .input-holder{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media (min-width:700px) and (max-width:810px){.fnlVyd{margin:auto 8px auto 40px !important;}}/*!sc*/
# @media only screen and (max-width:768px){.fnlVyd .input-holder{margin:10px 0;}.fnlVyd .input-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.fnlVyd .sm-icon{margin-right:2vw;}.fnlVyd .sm-count{color:#00000050;position:absolute;bottom:-3vh;width:100%;text-align:center;}.fnlVyd .sm-icon-wrapper{margin:auto 8px auto 16px;}.fnlVyd .check,.fnlVyd .notCheck{right:5%;}.fnlVyd .sm-icon{margin:auto 16px auto auto;}.fnlVyd .input__invalid_message{margin-left:2px;margin-top:5px;}}/*!sc*/
# @media only screen and (min-width:768px){.fnlVyd .sm-count{margin-top:auto 0;font-size:10pt;}}/*!sc*/
# data-styled.g15[id="styles__Container-sc-36shcs-0"]{content:"fnlVyd,"}/*!sc*/
# .BrsWO body{line-height:1.42857143;color:#333;}/*!sc*/
# .BrsWO b,.BrsWO strong{font-weight:700;}/*!sc*/
# .BrsWO section{position:relative;}/*!sc*/
# .BrsWO i:hover{color:#aeaeae;}/*!sc*/
# .BrsWO section#slider > *{padding-left:0px;}/*!sc*/
# .BrsWO .flex{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .homeCursos a{margin-top:10px;-webkit-text-decoration:none;text-decoration:none;color:#212529;}/*!sc*/
# .BrsWO .center{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .BrsWO .homeCursos{height:100%;max-width:calc(100% - 380px);padding:0 0;}/*!sc*/
# .BrsWO .trailSwitch{text-align:center;content-align:middle;}/*!sc*/
# .BrsWO .trailOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .trailOptionContainer{margin:0 auto;}/*!sc*/
# .BrsWO .trailOptionIcon{position:relative;object-fit:contain;height:50px;width:50px;cursor:pointer;}/*!sc*/
# .BrsWO .trailHeaderTextDesc{text-align:center;margin-bottom:10px;padding:10px;margin-top:30px;}/*!sc*/
# @media (min-width:2001px){.BrsWO .trailOptionIcon{height:100px;width:100px;}.BrsWO .trailOptionContainer{padding-bottom:10px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (min-width:1601px) and (max-width:2001px){.BrsWO .trailOptionIcon{height:96px;width:96px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (min-width:1025px) and (max-width:1600px){.BrsWO .trailOptionIcon{height:70px;width:70px;}.BrsWO .trailHeaderTextDesc{margin-top:60px;}}/*!sc*/
# @media (max-width:1024px){.BrsWO .trailOptionIcon{width:60px;height:60px;}}/*!sc*/
# @media (max-width:425px){.BrsWO .trailOptionIcon{width:50px;height:50px;}}/*!sc*/
# @media only screen and (min-width:768px) and (max-width:1100px){.BrsWO .homeCursos{max-width:calc(100% - 200px);}}/*!sc*/
# .BrsWO #section__cursos{padding-top:20px;background:#f6f6f6;width:100vw;padding-bottom:60px;}/*!sc*/
# .BrsWO .columns{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .BrsWO .to-right{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;padding:40px 20px 10px 20px;padding-bottom:10px;}/*!sc*/
# .BrsWO .to-left{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:40px 20px 10px 20px;padding-bottom:10px;}/*!sc*/
# .BrsWO a:hover{-webkit-text-decoration:none !important;text-decoration:none !important;}/*!sc*/
# .BrsWO .title__sobre{color:#fed500;}/*!sc*/
# .BrsWO .trail_type{width:50%;padding-left:10%;font-weight:300;}/*!sc*/
# .BrsWO .barriguinha{position:absolute;width:auto;height:20px;bottom:-16px;z-index:20;left:5%;}/*!sc*/
# .BrsWO .filter{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .BrsWO .courses-filter{width:60%;position:relative;}/*!sc*/
# .BrsWO .courses-filter div.filter-courses{width:100%;background-color:#fff;border-radius:4px;border:0;box-shadow:0px 0px 4px #707070;height:2.2rem;-webkit-appearance:none;position:relative;}/*!sc*/
# .BrsWO .courses-filter svg{position:absolute;right:0.5rem;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);}/*!sc*/
# .BrsWO #section__cursos .search-course-text{padding:0.45rem;color:#555;}/*!sc*/
# .BrsWO .courses-column{min-width:160px;}/*!sc*/
# .BrsWO .singleColumn{width:100% !important;}/*!sc*/
# .BrsWO .courses-column:nth-child(2),.BrsWO .courses-column:nth-child(4){margin:0 0.7rem;}/*!sc*/
# .BrsWO .column-header{border-bottom:1px solid #132e4c;border-top:1px solid #132e4c;}/*!sc*/
# .BrsWO .courses-options{position:absolute;top:2.2rem;right:0;background-color:#f6f6f6;color:#132e4c;box-shadow:0px 0px 10px #707070;border-radius:4px;padding:0.7rem;z-index:10;border-bottom:7px solid #fed254;}/*!sc*/
# .BrsWO .trailSpacing{margin-top:15px;border-top:1px solid #132e4c;padding-top:15px;}/*!sc*/
# .BrsWO .courses-options .column-title{font-size:14px;font-weight:700;margin-bottom:0;width:150px;}/*!sc*/
# .BrsWO .courses-options .column-duration{font-size:14px;font-weight:600;margin:1rem auto;padding:0.2rem;}/*!sc*/
# .BrsWO .courses-options .courses-list{margin-top:1rem;}/*!sc*/
# .BrsWO .courses-options .courses-list li{font-size:0.8rem;padding:0.2rem 0rem;}/*!sc*/
# .BrsWO .courses-options .courses-list li a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO .courses-column{padding-bottom:3vh;}.BrsWO #sobre{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-top:5vh;padding-bottom:0vh;}.BrsWO .courses-column:nth-child(2),.BrsWO .courses-column:nth-child(4){margin:0;}.BrsWO #section__cursos{padding-bottom:20px;}.BrsWO .trail_type{text-align:center;margin:0 auto 20px;padding:0;}.BrsWO .to-right,.BrsWO .to-left{padding:0;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# .BrsWO .cursosHeaderInfo{margin:30px auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .BrsWO .columns{margin:0;}/*!sc*/
# .BrsWO .columns.right{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# .BrsWO .gifCard .gif{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO .cursosHeaderInfo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-bottom:5vh;}}/*!sc*/
# @media only screen and (max-width:768px){.BrsWO #conteudo-programatico{margin-top:0;}.BrsWO .courses-options{width:100%;}}/*!sc*/
# @media only screen and (min-width:769px) and (max-width:936px){.BrsWO .homeCursos a{width:38vw;}}/*!sc*/
# data-styled.g24[id="homeContainer__Container-cwo9us-0"]{content:"BrsWO,"}/*!sc*/
# .gFdQpP .site-map{background-color:white;padding:40px 0;font-size:10pt;color:#162d4b;}/*!sc*/
# .gFdQpP .footer-group-title{width:13.34vw;font-size:14px !important;font-weight:bold;margin:10px 0px 2px;color:#162d4b;padding-bottom:5px;border-bottom:1px solid #162d4b;}/*!sc*/
# .gFdQpP .footer-group-subtitle{font-size:12px !important;font-weight:bold;color:#162d4b;margin:7px 0px 0px;}/*!sc*/
# .gFdQpP .footer-group-link{width:13.34vw;color:#162d4b !important;-webkit-text-decoration:none;text-decoration:none;font-size:12px !important;text-transform:capitalize;}/*!sc*/
# .gFdQpP .site-map-content{width:60vw;height:190pt;margin:0px auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:space-between;-ms-flex-line-pack:space-between;align-content:space-between;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .gFdQpP .site-map-content > div{height:100%;}/*!sc*/
# .gFdQpP .site-map.dark{background-color:#353535;color:#fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-title{color:#fff;border-bottom:1px solid #fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-subtitle{color:#fff;}/*!sc*/
# .gFdQpP .site-map.dark .footer-group-link{color:#fff !important;}/*!sc*/
# .gFdQpP .site-footer.fixed{position:fixed;bottom:0;}/*!sc*/
# .gFdQpP .site-footer.dark{background-color:black;}/*!sc*/
# @media only screen and (max-width:844px){.gFdQpP .site-map{display:none;}}/*!sc*/
# data-styled.g25[id="styles__Container-xnhrx0-0"]{content:"gFdQpP,"}/*!sc*/
# .hiydsf .st0{opacity:1;fill:#dedede;}/*!sc*/
# .hiydsf .headerCamada_1 .st1{fill:#ffffff;}/*!sc*/
# .hiydsf .homeHeader{height:90vh;min-height:680px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100vw;background-color:#43566a;background-size:115%;background-repeat:no-repeat;background-position:center bottom;}/*!sc*/
# .hiydsf .headerCamada_1{width:100vw;height:auto;position:absolute;bottom:-70px;z-index:1;}/*!sc*/
# .hiydsf .hero-container{width:80%;height:55%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;z-index:2;}/*!sc*/
# .hiydsf .headerTextContainer{width:50%;padding-right:40px;}/*!sc*/
# .hiydsf .lottieContainer > div{width:100% !important;height:100% !important;}/*!sc*/
# .hiydsf .headerTitle{max-width:299px;color:#fff;margin-top:20px;font-weight:300;white-space:nowrap;}/*!sc*/
# .hiydsf .homeImage{width:50%;height:100%;position:relative;float:right;top:-30px;}/*!sc*/
# .hiydsf .btn__header{padding:0.5rem 1rem !important;background:#f5d01f !important;border-radius:5rem !important;color:#000 !important;-webkit-transition:all 0.5s ease-in-out !important;transition:all 0.5s ease-in-out !important;margin:unset !important;margin-top:30px !important;font-weight:400 !important;height:40px !important;}/*!sc*/
# .hiydsf .btn__header:focus{outline:none;}/*!sc*/
# @media (min-width:2001px){.hiydsf .headerCamada_1{bottom:-70px;}.hiydsf .headerTitle{font-size:20px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (min-width:1440px) and (max-width:2000px){.hiydsf .headerCamada_1{bottom:-70px;}.hiydsf .headerTitle{font-size:20px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (min-width:1025px) and (max-width:1439px){.hiydsf .headerCamada_1{bottom:-30px;}.hiydsf .headerTitle{font-size:18px;}.hiydsf .homeImage{right:-30px;}}/*!sc*/
# @media (max-width:1024px){.hiydsf .homeImage{display:none;}}/*!sc*/
# @media (min-width:769px) and (max-width:1024px){.hiydsf .headerCamada_1{bottom:-50px;}.hiydsf .homeHeader{height:unset;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;}.hiydsf .headerTitle{font-size:16px;margin:0 auto;margin-top:30px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# @media (min-width:426px) and (max-width:768px){.hiydsf .homeHeader{height:unset;}.hiydsf .headerCamada_1{bottom:-20px;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;width:70%;}.hiydsf .headerTitle{font-size:14px;margin:0 auto;margin-top:30px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# @media (max-width:425px){.hiydsf .homeHeader{height:unset;}.hiydsf .headerCamada_1{bottom:-8px;}.hiydsf .headerTextContainer{margin:0 auto;padding:0px;width:100%;}.hiydsf .headerTitle{font-size:12px;margin:0 auto;margin-top:50px;position:unset;text-align:center;}.hiydsf .btn__header{margin:0 auto !important;margin-top:30px !important;}}/*!sc*/
# data-styled.g26[id="headerContainer__Container-lvlhxg-0"]{content:"hiydsf,"}/*!sc*/
# .hmKeqD body{line-height:1.42857143;}/*!sc*/
# .hmKeqD .courses_cards__container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:75%;margin:0 auto 30px;}/*!sc*/
# .hmKeqD .courses_cards__container__title{width:80%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-weight:300;text-align:center;}/*!sc*/
# .hmKeqD .margin-45-center{margin:45px auto;}/*!sc*/
# .hmKeqD .card__link{-webkit-text-decoration:none;text-decoration:none;color:#3d3d3d;cursor:pointer;border:0 !important;-webkit-transition:-webkit-transform 1s;-webkit-transition:transform 1s;transition:transform 1s;-webkit-transition:transform 1s;width:50%;position:relative;}/*!sc*/
# .hmKeqD .card__link:hover,.hmKeqD .card__link:focus{-webkit-transform:translate(5px,5px);-ms-transform:translate(5px,5px);transform:translate(5px,5px);}/*!sc*/
# .hmKeqD .card{height:230px;background:#ffffff;margin-bottom:30px;margin:10px;box-shadow:2px 2px 15px rgba(0,0,0,0.5);-webkit-transition:box-shadow 1s;transition:box-shadow 1s;padding:20px;border-radius:10px 10px 10px 10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;text-align:center;}/*!sc*/
# .hmKeqD .card:hover,.hmKeqD .card:focus{-webkit-transition:box-shadow 1s;transition:box-shadow 1s;box-shadow:0px 0px 0px rgba(0,0,0,0);}/*!sc*/
# .hmKeqD .card.card__trail{height:180px;}/*!sc*/
# .hmKeqD .trail__both{position:relative;}/*!sc*/
# ...
#           </noscript>
#           <img alt="Infraestrutura - 8" class="sobre-photo" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#          </div>
#          <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#           <div style="box-sizing:border-box;display:block;max-width:100%">
#            <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#           </div>
#           <noscript>
#            <img alt="Infraestrutura - 9" class="sobre-photo" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto9.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto9.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto9.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#           </noscript>
#           <img alt="Infraestrutura - 9" class="sobre-photo" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#          </div>
#          <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#           <div style="box-sizing:border-box;display:block;max-width:100%">
#            <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#           </div>
#           <noscript>
#            <img alt="Infraestrutura - 10" class="sobre-photo" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto10.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto10.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto10.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#           </noscript>
#           <img alt="Infraestrutura - 10" class="sobre-photo" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#          </div>
#          <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#           <div style="box-sizing:border-box;display:block;max-width:100%">
#            <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#           </div>
#           <noscript>
#            <img alt="Infraestrutura - 11" class="sobre-photo" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto11.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto11.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Misc/AboutSlider/aboutPhoto11.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#           </noscript>
#           <img alt="Infraestrutura - 11" class="sobre-photo" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill"/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div class="styles__Container-xnhrx0-0 gFdQpP">
#      <div class="site-map">
#       <div class="site-map-content">
#        <div>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-title">
#           Trilha Python &amp; Dados
#          </div>
#         </div>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-subtitle">
#           Degree
#          </div>
#         </div>
#         <a href="/degree/ds">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            data science
#           </div>
#          </div>
#         </a>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-subtitle">
#           Upskilling
#          </div>
#         </div>
#         <a href="/cursos/python-adulto">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            python
#           </div>
#          </div>
#         </a>
#         <a href="/cursos/ds-ia">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            data science &amp; I.A
#           </div>
#          </div>
#         </a>
#         <a href="/cursos/python-finance">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            python for finance
#           </div>
#          </div>
#         </a>
#         <a href="/cursos/banco-de-dados">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Banco de Dados
#           </div>
#          </div>
#         </a>
#         <a href="/curso-online/python-basics">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Online Python Basics
#           </div>
#          </div>
#         </a>
#         <a href="/curso-online/python-teens">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Python Teens
#           </div>
#          </div>
#         </a>
#        </div>
#        <div>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-title">
#           Trilha Web Full Stack
#          </div>
#         </div>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-subtitle">
#           Degree
#          </div>
#         </div>
#         <a href="/degree/web">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            web full stack
#           </div>
#          </div>
#         </a>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-subtitle">
#           Upskilling
#          </div>
#         </div>
#         <a href="/cursos/web-frontend-react">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Web Front-End &amp; React
#           </div>
#          </div>
#         </a>
#         <a href="/cursos/java">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            java
#           </div>
#          </div>
#         </a>
#         <a href="/curso-online/web-and-react">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Online Web &amp; React
#           </div>
#          </div>
#         </a>
#        </div>
#        <div>
#         <div class="styles__Container-sc-1510a04-0 duKImY">
#          <div class="typography body1 footer-group-title">
#           Institucional
#          </div>
#         </div>
#         <a href="/certificado">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Certificados
#           </div>
#          </div>
#         </a>
#         <a href="/nosso-time">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Nosso Time
#           </div>
#          </div>
#         </a>
#         <a href="/blog">
#          <div class="styles__Container-sc-1510a04-0 duKImY">
#           <div class="typography body1 footer-group-link">
#            Blog
#           </div>
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="styles__Container-sc-85gh8u-0 iNTbyI">
#     <footer class="site-footer extended">
#      <a class="footer-container-address" href="https://goo.gl/maps/CB3zVwyTvKfMfZTG8" rel="noreferrer" target="_blank">
#       <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#        <div style="box-sizing:border-box;display:block;max-width:100%">
#         <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#        </div>
#        <noscript>
#         <img alt="Ícone de localização geográfica" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#        </noscript>
#        <img alt="Ícone de localização geográfica" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </div>
#       <b class="footer-text">
#        Av. Faria Lima, 1306 - 4º Andar - Pinheiros, SP
#       </b>
#      </a>
#      <div class="footer-logo">
#       <div class="footer-logo-container">
#        <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#         <div style="box-sizing:border-box;display:block;max-width:100%">
#          <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#         </div>
#         <noscript>
#          <img alt="Logo da Let's Code" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#         </noscript>
#         <img alt="Logo da Let's Code" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#        </div>
#        <div class="react-logo-wrapper">
#         <b class="footer-text footer-text-small" style="margin-right:6px">
#          Feito em React
#         </b>
#         <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#          <div style="box-sizing:border-box;display:block;max-width:100%">
#           <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#          </div>
#          <noscript>
#           <img alt="Ícone do React" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#          </noscript>
#          <img alt="Ícone do React" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="footer-contato" style="margin:0px">
#      </div>
#      <div>
#       <div class="footer-container-phone">
#        <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#         <div style="box-sizing:border-box;display:block;max-width:100%">
#          <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#         </div>
#         <noscript>
#          <img alt="Ícone de telefone" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#         </noscript>
#         <img alt="Ícone de telefone" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#        </div>
#        <b class="footer-text">
#         11 2609-3807
#        </b>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div class="styles__Container-nzozqa-0 exaHbn">
#     <div class="quiz-footer">
#      <div class="quiz-footer-text-container">
#       <a class="quiz-link" href="/descubra-sua-trilha-ideal" target="_blank">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1">
#          <div class="call-upper">
#           Em dúvida de qual trilha seguir?
#          </div>
#          Faça nosso quiz e descubra sua trilha ideal!
#         </div>
#        </div>
#       </a>
#       <div id="mdiv">
#        <div class="mdiv">
#         <div class="md">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{}},"page":"/","query":{},"buildId":"I_EDgVdhbkind1jdpHsgG","nextExport":true,"autoExport":true,"isFallback":false,"dynamicIds":[48520,35058,54899,22914],"scriptLoader":[]}
#   </script>
#  </body>
# </html>

# %%
soup.find_all('div')[4]
# Out:
# <div class="navbar-brand"><a class="navbar-item item-img" href="/" id="navbar-logo"><div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0"><div style="box-sizing:border-box;display:block;max-width:100%"><img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/></div><noscript><img alt="Home Let's Code" aria-label="Home Let's Code" class="navbar-img" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></noscript><img alt="Home Let's Code" aria-label="Home Let's Code" class="navbar-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></div></a></div>

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('./chromedriver')  # o arquivo do chromedrive está na mesma pasta do notebook
driver.get('https://letscode.com.br/')  # entrando na pagina
# time.sleep(1.5)

# %%
element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML')

# %%
type(resposta)
# Out:
# str

# %%
site = bs4.BeautifulSoup(resposta, 'html.parser')
len(site.find_all('a', class_="card__link"))

# %%
print(site.prettify())
# Out:
# <noscript>
#  <iframe height="0" id="tag-manager" src="https://www.googletagmanager.com/ns.html?id=GTM-PQZB6GR&gt;m_auth=&gt;m_preview=&gt;m_cookies_win=x" style="display:none;visibility:hidden" width="0">
#  </iframe>
# </noscript>
# <div id="__next">
#  <div class="styles__Container-tke1hi-0 doOaWk">
#   <div class="navbar is-fixed-top">
#    <div>
#     <div class="navbar-brand">
#      <a class="navbar-item item-img" href="/" id="navbar-logo">
#       <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#        <div style="box-sizing:border-box;display:block;max-width:100%">
#         <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#        </div>
#        <img alt="Home Let's Code" aria-label="Home Let's Code" class="navbar-img scrolled" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoLcPng.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </div>
#      </a>
#     </div>
#     <div aria-label="Botão para abrir o menu do site" class="navbar-burger" role="button" tabindex="0">
#      <span>
#      </span>
#      <span>
#      </span>
#      <span>
#      </span>
#     </div>
#    </div>
#    <div class="navbar-menu">
#     <div class="navbar-end">
#      <a class="navbar-item active" href="/">
#       <span class="nav-item-name">
#        Home
#       </span>
#      </a>
#      <a class="navbar-item" href="/lets-code-zero">
#       <span class="nav-item-name">
#        Zero $
#       </span>
#      </a>
#      <a class="navbar-item" href="/nosso-time">
#       <span class="nav-item-name">
#        Nosso Time
#       </span>
#      </a>
#      <div class="navbar-item">
#       <span class="nav-item-name">
#        <i class="arrow black arrow-dropdown up">
#        </i>
#        <!-- -->
#        Cursos
#       </span>
#       <span class="navbar-dropdown">
#        <div class="navbar-dropdown-desktop">
#         <div class="navbar-dropdown-container">
#          <div class="multiple-dropdown-label1">
#           <i class="arrow white left">
#           </i>
#           Python &amp; Dados
#           <div class="multiple-dropdown-options-container1">
#            <div class="multiple-dropdown-options-container2">
#             <div class="multiple-dropdown-options-container3 navbar-dropdown-container">
#              <span class="multiple-dropdown-options-title">
#               Degree
#              </span>
#              <a class="navbar-item" href="/degree/ds">
#               Data Science
#              </a>
#              <span class="multiple-dropdown-options-title">
#               Upskilling
#              </span>
#              <a class="navbar-item" href="/cursos/python-adulto">
#               Python
#              </a>
#              <a class="navbar-item" href="/cursos/ds-ia">
#               Data Science &amp; I.A
#              </a>
#              <a class="navbar-item" href="/cursos/python-finance">
#               Python For Finance
#              </a>
#              <a class="navbar-item" href="/cursos/banco-de-dados">
#               Banco De Dados
#              </a>
#              <a class="navbar-item" href="/curso-online/python-basics">
#               Online Python Basics
#              </a>
#              <a class="navbar-item" href="/curso-online/python-teens">
#               Python Teens
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="navbar-dropdown-container">
#          <div class="multiple-dropdown-label1">
#           <i class="arrow white left">
#           </i>
#           Web Full Stack
#           <div class="multiple-dropdown-options-container1">
#            <div class="multiple-dropdown-options-container2">
#             <div class="multiple-dropdown-options-container3 navbar-dropdown-container">
#              <span class="multiple-dropdown-options-title">
#               Degree
#              </span>
#              <a class="navbar-item" href="/degree/web">
#               Web Full Stack
#              </a>
#              <span class="multiple-dropdown-options-title">
#               Upskilling
#              </span>
#              <a class="navbar-item" href="/cursos/web-frontend-react">
#               Web Front-End &amp; React
#              </a>
#              <a class="navbar-item" href="/cursos/java">
#               Java
#              </a>
#              <a class="navbar-item" href="/curso-online/web-and-react">
#               Online Web &amp; React
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navbar-dropdown-mobile">
#         <div class="navbar-dropdown-container">
#          <div class="dropdown-title">
#           <i class="arrow white up">
#           </i>
#           Python &amp; Dados
#          </div>
#         </div>
#         <div class="navbar-dropdown-container">
#          <div class="dropdown-title">
#           <i class="arrow white up">
#           </i>
#           Web Full Stack
#          </div>
#         </div>
#        </div>
#       </span>
#      </div>
#      <a class="navbar-item" href="/blog">
#       <span class="nav-item-name">
#        Blog
#       </span>
#      </a>
#      <a class="navbar-item" href="/certificado">
#       <span class="nav-item-name">
#        Certificados
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="styles__Container-t3m083-0 bgWhoP">
#    <div class="header-bottom active">
#     <div class="header-bottom-links">
#      <div class="scrollTop">
#       <i class="arrow-up">
#       </i>
#      </div>
#      <a alt="Converse conosco pelo WhatsApp" class="whatsLink" href="https://wa.me/5511933387373?text=Olá,%20gostaria%20de%20saber%20mais%20informações%20sobre%20os%20cursos%20da%20Let's%20Code." rel="noopener noreferrer" target="_blank">
#       <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#        <div style="box-sizing:border-box;display:block;max-width:100%">
#         <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#        </div>
#        <img alt="Ícone do WhatsApp" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/whatsAppIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/whatsAppIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/whatsAppIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </div>
#      </a>
#     </div>
#     <div class="styles__Container-sc-1lny31g-0 dAAzes">
#      <div class="cookie-accept">
#       <div class="container">
#        <div class="row">
#         <p class="cookie-text">
#          Ao navegar pelo nosso site, você concorda com a nossa
#          <br/>
#          <a href="/privacidade">
#           política de privacidade.
#          </a>
#         </p>
#         <button class="btn cookie-ok" type="button">
#          Ok, entendi.
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="homeContainer__Container-cwo9us-0 BrsWO">
#   <div class="headerContainer__Container-lvlhxg-0 hiydsf">
#    <div class="courseContainer__Container-sc-38zdqz-0 hmKeqD">
#     <section class="homeHeader" id="header">
#      <svg class="headerCamada_1" enable-background="new 0 0 1905.5 620" version="1.1" viewbox="34 -247 1905.5 626" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#       <path class="st0" d="M1925.64,0v291.89H0v-13.21c0,0,280.36,18.03,650.83-84.44c370.47-102.47,407.23-103.27,552.25-76.32 c145.02,26.95,404.43,59.43,573.96-25.24C1845.52,58.49,1893.16,26.27,1925.64,0z">
#       </path>
#      </svg>
#      <svg class="headerCamada_1" enable-background="new 0 0 1905.5 612" version="1.1" viewbox="60 -240 1905.5 612" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#       <path class="st1" d="M24.49,282.91c0,0,280.36,18.03,650.83-84.44C1045.79,96,1082.55,95.21,1227.57,122.16 c145.02,26.95,404.43,59.43,573.96-25.24C1873.74,60.86,1922.77,27,1955.29,0h15.82v338.91H0">
#       </path>
#      </svg>
#      <div class="hero-container">
#       <div class="headerTextContainer">
#        <div class="lottieContainer">
#         <div>
#          <svg height="300" preserveaspectratio="xMidYMid meet" style="width: 100%; height: 100%; transform: translate3d(0px, 0px, 0px);" viewbox="0 0 500 300" width="500" xmlns="http://www.w3.org/2000/svg">
#           <defs>
#            <clippath id="__lottie_element_8">
#             <rect height="300" width="500" x="0" y="0">
#             </rect>
#            </clippath>
#            <clippath id="__lottie_element_11">
#             <path clip-rule="nonzero" d=" M237.33200073242188,-91.51799774169922 C237.33200073242188,-91.51799774169922 -229,-91.51799774169922 -229,-91.51799774169922 C-229,-91.51799774169922 -228.6540069580078,124.98200225830078 -228.6540069580078,124.98200225830078 C-228.6540069580078,124.98200225830078 237.67799377441406,124.98200225830078 237.67799377441406,124.98200225830078 C237.67799377441406,124.98200225830078 237.33200073242188,-91.51799774169922 237.33200073242188,-91.51799774169922" fill="#ffffff" fill-opacity="1">
#             </path>
#             <path clip-rule="nonzero" d=" M245.89199829101562,137.7239990234375 C245.89199829101562,137.7239990234375 -238.68299865722656,137.7239990234375 -238.68299865722656,137.7239990234375 C-238.68299865722656,137.7239990234375 -238.68299865722656,237.7239990234375 -238.68299865722656,237.7239990234375 C-238.68299865722656,237.7239990234375 245.89199829101562,237.7239990234375 245.89199829101562,237.7239990234375 C245.89199829101562,237.7239990234375 245.89199829101562,137.7239990234375 245.89199829101562,137.7239990234375" fill="#ffffff" fill-opacity="1">
#             </path>
#            </clippath>
#           </defs>
#           <g clip-path="url(#__lottie_element_8)">
# de verdade._" clip-path="url(#__lottie_element_11)" fill="rgb(255,255,255)" font-family="Montserrat" font-size="80" font-style="normal" font-weight="200" opacity="1" style="display: block;" transform="matrix(1,0,0,1,247.68299865722656,77.125)">
#             <path d=" M52.85,0 C52.85,0 54.7,0 54.7,0 C54.7,0 28.52,-56.4 28.52,-56.4 C28.52,-56.4 26.91,-56.4 26.91,-56.4 C26.91,-56.4 0.72,0 0.72,0 C0.72,0 2.58,0 2.58,0 C2.58,0 10.47,-17 10.47,-17 C10.47,-17 44.96,-17 44.96,-17 C44.96,-17 52.85,0 52.85,0z M11.2,-18.53 C11.2,-18.53 27.72,-54.22 27.72,-54.22 C27.72,-54.22 44.23,-18.53 44.23,-18.53 C44.23,-18.53 11.2,-18.53 11.2,-18.53z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-199.0399932861328,0)">
#             </path>
#             <path d=" M29.49,-41.89 C20.79,-41.89 13.7,-36.82 10.88,-28.92 C10.88,-28.92 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,15.63 9.26,15.63 C9.26,15.63 10.88,15.63 10.88,15.63 C10.88,15.63 10.88,-12.65 10.88,-12.65 C13.7,-4.83 20.79,0.24 29.49,0.24 C40.93,0.24 49.71,-8.46 49.71,-20.79 C49.71,-33.11 40.93,-41.89 29.49,-41.89z M29.49,-1.29 C18.85,-1.29 10.88,-9.27 10.88,-20.79 C10.88,-32.31 18.85,-40.36 29.49,-40.36 C40.12,-40.36 48.1,-32.31 48.1,-20.79 C48.1,-9.27 40.12,-1.29 29.49,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-144.8000030517578,0)">
#             </path>
#             <path d=" M10.88,-30.86 C10.88,-30.86 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.4 10.88,-22.4 C10.88,-33.44 16.76,-40.28 26.75,-40.28 C26.75,-40.28 27.23,-40.28 27.23,-40.28 C27.23,-40.28 27.23,-41.89 27.23,-41.89 C18.85,-41.89 13.21,-37.87 10.88,-30.86z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-91.92000579833984,0)">
#             </path>
#             <path d=" M42.94,-21.27 C42.94,-33.35 34.56,-41.89 23.61,-41.89 C12.57,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 25.14,0.24 C31.1,0.24 36.74,-2.09 40.44,-6.61 C40.44,-6.61 39.32,-7.73 39.32,-7.73 C36.01,-3.38 30.7,-1.29 25.14,-1.29 C14.1,-1.29 5.88,-9.35 5.88,-20.87 C5.88,-20.87 42.94,-20.87 42.94,-20.87 C42.94,-20.87 42.94,-21.27 42.94,-21.27z M23.61,-40.36 C33.43,-40.36 40.85,-32.71 41.41,-22.4 C41.41,-22.4 5.88,-22.4 5.88,-22.4 C6.45,-32.71 13.78,-40.36 23.61,-40.36z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-62.880001068115234,0)">
#             </path>
#             <path d=" M28.36,-41.89 C19.5,-41.89 13.37,-37.46 10.88,-30.53 C10.88,-30.53 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.64 10.88,-22.64 C10.88,-33.19 17.48,-40.36 28.44,-40.36 C37.87,-40.36 43.43,-34.89 43.43,-24.57 C43.43,-24.57 43.43,0 43.43,0 C43.43,0 45.04,0 45.04,0 C45.04,0 45.04,-24.57 45.04,-24.57 C45.04,-35.85 38.59,-41.89 28.36,-41.89z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-16.719995498657227,0)">
#             </path>
#             <path d=" M43.18,-59.78 C43.18,-59.78 43.18,-29 43.18,-29 C40.36,-36.82 33.27,-41.89 24.57,-41.89 C13.13,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 24.57,0.24 C33.27,0.24 40.36,-4.83 43.18,-12.73 C43.18,-12.73 43.18,0 43.18,0 C43.18,0 44.8,0 44.8,0 C44.8,0 44.8,-59.78 44.8,-59.78 C44.8,-59.78 43.18,-59.78 43.18,-59.78z M24.57,-1.29 C13.94,-1.29 5.96,-9.35 5.96,-20.87 C5.96,-32.39 13.94,-40.36 24.57,-40.36 C35.21,-40.36 43.18,-32.39 43.18,-20.87 C43.18,-9.35 35.21,-1.29 24.57,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,35.91999435424805,0)">
#             </path>
#             <path d=" M22.56,-41.89 C16.27,-41.89 10.31,-39.48 6.36,-35.69 C6.36,-35.69 7.49,-34.56 7.49,-34.56 C11.12,-38.03 16.44,-40.36 22.64,-40.36 C31.26,-40.36 35.85,-35.93 35.85,-27.23 C35.85,-27.23 35.85,-22.64 35.85,-22.64 C35.85,-22.64 20.06,-22.64 20.06,-22.64 C8.94,-22.64 5.24,-17.4 5.24,-11.44 C5.24,-4.43 10.64,0.24 19.98,0.24 C27.8,0.24 33.19,-3.3 35.85,-8.86 C35.85,-8.86 35.85,0 35.85,0 C35.85,0 37.46,0 37.46,0 C37.46,0 37.46,-27.31 37.46,-27.31 C37.46,-36.82 32.23,-41.89 22.56,-41.89z M19.98,-1.29 C11.68,-1.29 6.85,-5.24 6.85,-11.52 C6.85,-17.08 10.55,-21.11 19.98,-21.11 C19.98,-21.11 35.85,-21.11 35.85,-21.11 C35.85,-21.11 35.85,-11.92 35.85,-11.92 C33.11,-5.16 28.04,-1.29 19.98,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,88.80000305175781,0)">
#             </path>
#             <path d="" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,133.91998291015625,0)">
#             </path>
#             <path d=" M22.56,-41.89 C16.27,-41.89 10.31,-39.48 6.36,-35.69 C6.36,-35.69 7.49,-34.56 7.49,-34.56 C11.12,-38.03 16.44,-40.36 22.64,-40.36 C31.26,-40.36 35.85,-35.93 35.85,-27.23 C35.85,-27.23 35.85,-22.64 35.85,-22.64 C35.85,-22.64 20.06,-22.64 20.06,-22.64 C8.94,-22.64 5.24,-17.4 5.24,-11.44 C5.24,-4.43 10.64,0.24 19.98,0.24 C27.8,0.24 33.19,-3.3 35.85,-8.86 C35.85,-8.86 35.85,0 35.85,0 C35.85,0 37.46,0 37.46,0 C37.46,0 37.46,-27.31 37.46,-27.31 C37.46,-36.82 32.23,-41.89 22.56,-41.89z M19.98,-1.29 C11.68,-1.29 6.85,-5.24 6.85,-11.52 C6.85,-17.08 10.55,-21.11 19.98,-21.11 C19.98,-21.11 35.85,-21.11 35.85,-21.11 C35.85,-21.11 35.85,-11.92 35.85,-11.92 C33.11,-5.16 28.04,-1.29 19.98,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,153.12002563476562,0)">
#             </path>
#             <path d="" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;">
#             </path>
#             <path d=" M29.49,-41.89 C20.79,-41.89 13.7,-36.82 10.88,-28.92 C10.88,-28.92 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,15.63 9.26,15.63 C9.26,15.63 10.88,15.63 10.88,15.63 C10.88,15.63 10.88,-12.65 10.88,-12.65 C13.7,-4.83 20.79,0.24 29.49,0.24 C40.93,0.24 49.71,-8.46 49.71,-20.79 C49.71,-33.11 40.93,-41.89 29.49,-41.89z M29.49,-1.29 C18.85,-1.29 10.88,-9.27 10.88,-20.79 C10.88,-32.31 18.85,-40.36 29.49,-40.36 C40.12,-40.36 48.1,-32.31 48.1,-20.79 C48.1,-9.27 40.12,-1.29 29.49,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-208.52000427246094,103)">
#             </path>
#             <path d=" M10.88,-30.86 C10.88,-30.86 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.4 10.88,-22.4 C10.88,-33.44 16.76,-40.28 26.75,-40.28 C26.75,-40.28 27.23,-40.28 27.23,-40.28 C27.23,-40.28 27.23,-41.89 27.23,-41.89 C18.85,-41.89 13.21,-37.87 10.88,-30.86z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-155.63999938964844,103)">
#             </path>
#             <path d=" M24.57,0.24 C36.17,0.24 44.8,-8.54 44.8,-20.87 C44.8,-33.19 36.17,-41.89 24.57,-41.89 C12.97,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 12.97,0.24 24.57,0.24z M24.57,-1.29 C13.94,-1.29 5.96,-9.35 5.96,-20.87 C5.96,-32.39 13.94,-40.36 24.57,-40.36 C35.21,-40.36 43.18,-32.39 43.18,-20.87 C43.18,-9.35 35.21,-1.29 24.57,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-126.5999984741211,103)">
#             </path>
#             <path d=" M43.67,-41.65 C43.67,-41.65 43.67,-29.49 43.67,-29.49 C40.85,-36.98 33.76,-41.89 24.81,-41.89 C13.13,-41.89 4.35,-33.52 4.35,-21.67 C4.35,-9.83 13.13,-1.37 24.81,-1.37 C33.76,-1.37 40.85,-6.36 43.67,-13.94 C43.67,-13.94 43.67,-3.46 43.67,-3.46 C43.67,8.86 38.03,14.34 26.02,14.34 C19.01,14.34 12.97,12 8.7,7.82 C8.7,7.82 7.57,8.94 7.57,8.94 C11.52,13.29 18.45,15.87 26.02,15.87 C38.91,15.87 45.28,9.75 45.28,-3.71 C45.28,-3.71 45.28,-41.65 45.28,-41.65 C45.28,-41.65 43.67,-41.65 43.67,-41.65z M24.81,-2.9 C13.94,-2.9 5.96,-10.63 5.96,-21.67 C5.96,-32.71 13.94,-40.36 24.81,-40.36 C35.69,-40.36 43.67,-32.71 43.67,-21.67 C43.67,-10.63 35.69,-2.9 24.81,-2.9z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-78.5999984741211,103)">
#             </path>
#             <path d=" M10.88,-30.86 C10.88,-30.86 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.4 10.88,-22.4 C10.88,-33.44 16.76,-40.28 26.75,-40.28 C26.75,-40.28 27.23,-40.28 27.23,-40.28 C27.23,-40.28 27.23,-41.89 27.23,-41.89 C18.85,-41.89 13.21,-37.87 10.88,-30.86z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-25.239999771118164,103)">
#             </path>
#             <path d=" M22.56,-41.89 C16.27,-41.89 10.31,-39.48 6.36,-35.69 C6.36,-35.69 7.49,-34.56 7.49,-34.56 C11.12,-38.03 16.44,-40.36 22.64,-40.36 C31.26,-40.36 35.85,-35.93 35.85,-27.23 C35.85,-27.23 35.85,-22.64 35.85,-22.64 C35.85,-22.64 20.06,-22.64 20.06,-22.64 C8.94,-22.64 5.24,-17.4 5.24,-11.44 C5.24,-4.43 10.64,0.24 19.98,0.24 C27.8,0.24 33.19,-3.3 35.85,-8.86 C35.85,-8.86 35.85,0 35.85,0 C35.85,0 37.46,0 37.46,0 C37.46,0 37.46,-27.31 37.46,-27.31 C37.46,-36.82 32.23,-41.89 22.56,-41.89z M19.98,-1.29 C11.68,-1.29 6.85,-5.24 6.85,-11.52 C6.85,-17.08 10.55,-21.11 19.98,-21.11 C19.98,-21.11 35.85,-21.11 35.85,-21.11 C35.85,-21.11 35.85,-11.92 35.85,-11.92 C33.11,-5.16 28.04,-1.29 19.98,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,3.8000001907348633,103)">
#             </path>
#             <path d=" M61.07,-41.89 C51.97,-41.89 45.76,-36.9 43.67,-29.49 C42.06,-37.62 36.34,-41.89 27.88,-41.89 C19.34,-41.89 13.29,-37.54 10.88,-30.62 C10.88,-30.62 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.64 10.88,-22.64 C10.88,-33.19 17.32,-40.36 27.96,-40.36 C37.06,-40.36 42.46,-34.89 42.46,-24.57 C42.46,-24.57 42.46,0 42.46,0 C42.46,0 44.07,0 44.07,0 C44.07,0 44.07,-22.64 44.07,-22.64 C44.07,-33.19 50.52,-40.36 61.15,-40.36 C70.25,-40.36 75.65,-34.89 75.65,-24.57 C75.65,-24.57 75.65,0 75.65,0 C75.65,0 77.26,0 77.26,0 C77.26,0 77.26,-24.57 77.26,-24.57 C77.26,-35.85 71.06,-41.89 61.07,-41.89z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,48.92000198364258,103)">
#             </path>
#             <path d=" M22.56,-41.89 C16.27,-41.89 10.31,-39.48 6.36,-35.69 C6.36,-35.69 7.49,-34.56 7.49,-34.56 C11.12,-38.03 16.44,-40.36 22.64,-40.36 C31.26,-40.36 35.85,-35.93 35.85,-27.23 C35.85,-27.23 35.85,-22.64 35.85,-22.64 C35.85,-22.64 20.06,-22.64 20.06,-22.64 C8.94,-22.64 5.24,-17.4 5.24,-11.44 C5.24,-4.43 10.64,0.24 19.98,0.24 C27.8,0.24 33.19,-3.3 35.85,-8.86 C35.85,-8.86 35.85,0 35.85,0 C35.85,0 37.46,0 37.46,0 C37.46,0 37.46,-27.31 37.46,-27.31 C37.46,-36.82 32.23,-41.89 22.56,-41.89z M19.98,-1.29 C11.68,-1.29 6.85,-5.24 6.85,-11.52 C6.85,-17.08 10.55,-21.11 19.98,-21.11 C19.98,-21.11 35.85,-21.11 35.85,-21.11 C35.85,-21.11 35.85,-11.92 35.85,-11.92 C33.11,-5.16 28.04,-1.29 19.98,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,133.55999755859375,103)">
#             </path>
#             <path d=" M10.88,-30.86 C10.88,-30.86 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.4 10.88,-22.4 C10.88,-33.44 16.76,-40.28 26.75,-40.28 C26.75,-40.28 27.23,-40.28 27.23,-40.28 C27.23,-40.28 27.23,-41.89 27.23,-41.89 C18.85,-41.89 13.21,-37.87 10.88,-30.86z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,178.67999267578125,103)">
#             </path>
#             <path d="" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;">
#             </path>
#             <path d=" M43.18,-59.78 C43.18,-59.78 43.18,-29 43.18,-29 C40.36,-36.82 33.27,-41.89 24.57,-41.89 C13.13,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 24.57,0.24 C33.27,0.24 40.36,-4.83 43.18,-12.73 C43.18,-12.73 43.18,0 43.18,0 C43.18,0 44.8,0 44.8,0 C44.8,0 44.8,-59.78 44.8,-59.78 C44.8,-59.78 43.18,-59.78 43.18,-59.78z M24.57,-1.29 C13.94,-1.29 5.96,-9.35 5.96,-20.87 C5.96,-32.39 13.94,-40.36 24.57,-40.36 C35.21,-40.36 43.18,-32.39 43.18,-20.87 C43.18,-9.35 35.21,-1.29 24.57,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-242.04000854492188,205)">
#             </path>
#             <path d=" M42.94,-21.27 C42.94,-33.35 34.56,-41.89 23.61,-41.89 C12.57,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 25.14,0.24 C31.1,0.24 36.74,-2.09 40.44,-6.61 C40.44,-6.61 39.32,-7.73 39.32,-7.73 C36.01,-3.38 30.7,-1.29 25.14,-1.29 C14.1,-1.29 5.88,-9.35 5.88,-20.87 C5.88,-20.87 42.94,-20.87 42.94,-20.87 C42.94,-20.87 42.94,-21.27 42.94,-21.27z M23.61,-40.36 C33.43,-40.36 40.85,-32.71 41.41,-22.4 C41.41,-22.4 5.88,-22.4 5.88,-22.4 C6.45,-32.71 13.78,-40.36 23.61,-40.36z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-189.16000366210938,205)">
#             </path>
#             <path d="" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-143,205)">
#             </path>
#             <path d=" M38.59,-41.65 C38.59,-41.65 20.46,-1.85 20.46,-1.85 C20.46,-1.85 2.34,-41.65 2.34,-41.65 C2.34,-41.65 0.48,-41.65 0.48,-41.65 C0.48,-41.65 19.66,0 19.66,0 C19.66,0 21.27,0 21.27,0 C21.27,0 40.44,-41.65 40.44,-41.65 C40.44,-41.65 38.59,-41.65 38.59,-41.65z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-123.79999542236328,205)">
#             </path>
#             <path d=" M42.94,-21.27 C42.94,-33.35 34.56,-41.89 23.61,-41.89 C12.57,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 25.14,0.24 C31.1,0.24 36.74,-2.09 40.44,-6.61 C40.44,-6.61 39.32,-7.73 39.32,-7.73 C36.01,-3.38 30.7,-1.29 25.14,-1.29 C14.1,-1.29 5.88,-9.35 5.88,-20.87 C5.88,-20.87 42.94,-20.87 42.94,-20.87 C42.94,-20.87 42.94,-21.27 42.94,-21.27z M23.61,-40.36 C33.43,-40.36 40.85,-32.71 41.41,-22.4 C41.41,-22.4 5.88,-22.4 5.88,-22.4 C6.45,-32.71 13.78,-40.36 23.61,-40.36z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-83.95999145507812,205)">
#             </path>
#             <path d=" M10.88,-30.86 C10.88,-30.86 10.88,-41.65 10.88,-41.65 C10.88,-41.65 9.26,-41.65 9.26,-41.65 C9.26,-41.65 9.26,0 9.26,0 C9.26,0 10.88,0 10.88,0 C10.88,0 10.88,-22.4 10.88,-22.4 C10.88,-33.44 16.76,-40.28 26.75,-40.28 C26.75,-40.28 27.23,-40.28 27.23,-40.28 C27.23,-40.28 27.23,-41.89 27.23,-41.89 C18.85,-41.89 13.21,-37.87 10.88,-30.86z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-37.79999542236328,205)">
#             </path>
#             <path d=" M43.18,-59.78 C43.18,-59.78 43.18,-29 43.18,-29 C40.36,-36.82 33.27,-41.89 24.57,-41.89 C13.13,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 24.57,0.24 C33.27,0.24 40.36,-4.83 43.18,-12.73 C43.18,-12.73 43.18,0 43.18,0 C43.18,0 44.8,0 44.8,0 C44.8,0 44.8,-59.78 44.8,-59.78 C44.8,-59.78 43.18,-59.78 43.18,-59.78z M24.57,-1.29 C13.94,-1.29 5.96,-9.35 5.96,-20.87 C5.96,-32.39 13.94,-40.36 24.57,-40.36 C35.21,-40.36 43.18,-32.39 43.18,-20.87 C43.18,-9.35 35.21,-1.29 24.57,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,-8.759998321533203,205)">
#             </path>
#             <path d=" M22.56,-41.89 C16.27,-41.89 10.31,-39.48 6.36,-35.69 C6.36,-35.69 7.49,-34.56 7.49,-34.56 C11.12,-38.03 16.44,-40.36 22.64,-40.36 C31.26,-40.36 35.85,-35.93 35.85,-27.23 C35.85,-27.23 35.85,-22.64 35.85,-22.64 C35.85,-22.64 20.06,-22.64 20.06,-22.64 C8.94,-22.64 5.24,-17.4 5.24,-11.44 C5.24,-4.43 10.64,0.24 19.98,0.24 C27.8,0.24 33.19,-3.3 35.85,-8.86 C35.85,-8.86 35.85,0 35.85,0 C35.85,0 37.46,0 37.46,0 C37.46,0 37.46,-27.31 37.46,-27.31 C37.46,-36.82 32.23,-41.89 22.56,-41.89z M19.98,-1.29 C11.68,-1.29 6.85,-5.24 6.85,-11.52 C6.85,-17.08 10.55,-21.11 19.98,-21.11 C19.98,-21.11 35.85,-21.11 35.85,-21.11 C35.85,-21.11 35.85,-11.92 35.85,-11.92 C33.11,-5.16 28.04,-1.29 19.98,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,44.12001037597656,205)">
#             </path>
#             <path d=" M43.18,-59.78 C43.18,-59.78 43.18,-29 43.18,-29 C40.36,-36.82 33.27,-41.89 24.57,-41.89 C13.13,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 24.57,0.24 C33.27,0.24 40.36,-4.83 43.18,-12.73 C43.18,-12.73 43.18,0 43.18,0 C43.18,0 44.8,0 44.8,0 C44.8,0 44.8,-59.78 44.8,-59.78 C44.8,-59.78 43.18,-59.78 43.18,-59.78z M24.57,-1.29 C13.94,-1.29 5.96,-9.35 5.96,-20.87 C5.96,-32.39 13.94,-40.36 24.57,-40.36 C35.21,-40.36 43.18,-32.39 43.18,-20.87 C43.18,-9.35 35.21,-1.29 24.57,-1.29z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,89.23999786376953,205)">
#             </path>
#             <path d=" M42.94,-21.27 C42.94,-33.35 34.56,-41.89 23.61,-41.89 C12.57,-41.89 4.35,-33.19 4.35,-20.87 C4.35,-8.54 13.13,0.24 25.14,0.24 C31.1,0.24 36.74,-2.09 40.44,-6.61 C40.44,-6.61 39.32,-7.73 39.32,-7.73 C36.01,-3.38 30.7,-1.29 25.14,-1.29 C14.1,-1.29 5.88,-9.35 5.88,-20.87 C5.88,-20.87 42.94,-20.87 42.94,-20.87 C42.94,-20.87 42.94,-21.27 42.94,-21.27z M23.61,-40.36 C33.43,-40.36 40.85,-32.71 41.41,-22.4 C41.41,-22.4 5.88,-22.4 5.88,-22.4 C6.45,-32.71 13.78,-40.36 23.61,-40.36z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,142.1199951171875,205)">
#             </path>
#             <path d=" M7.33,0.24 C8.46,0.24 9.43,-0.72 9.43,-1.85 C9.43,-2.98 8.46,-3.95 7.33,-3.95 C6.2,-3.95 5.24,-2.98 5.24,-1.85 C5.24,-0.72 6.2,0.24 7.33,0.24z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,188.28001403808594,205)">
#             </path>
#             <path d=" M0,1.53 C0,1.53 40.28,1.53 40.28,1.53 C40.28,1.53 40.28,0 40.28,0 C40.28,0 0,0 0,0 C0,0 0,1.53 0,1.53z" fill="rgb(255,255,255)" opacity="0.3999999999999986" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,202.0399932861328,205)">
#             </path>
#            </g>
#           </g>
#          </svg>
#         </div>
#        </div>
#        <div class="headerTitle">
#         Vamos muito além de um diploma,
#         <br/>
#         te preparamos para o mundo real.
#         <br/>
#         Conheça nossas trilhas de
#         <br/>
#         <b>
#          Data Science
#         </b>
#         e
#         <b>
#          Web Full Stack
#         </b>
#         .
#        </div>
#        <div class="styles__Container-sc-1djgj8m-0 hbdcjM">
#         <div>
#          <button class="btn__header btn__primary btn__primary__active">
#           Comece agora
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="homeImage">
#        <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#         <noscript>
#          <img alt="Imagem temática da Let's Code" decoding="async" sizes="100vw" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 640w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 750w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 828w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 1080w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 1200w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 1920w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 2048w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Background/backgroundHeaderHome.webp 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#         </noscript>
#         <img alt="Imagem temática da Let's Code" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#   </div>
#   <div class="homeSliderContainer__Container-sc-150npjf-0 hLalRg">
#    <section id="slider">
#     <div class="styles__Container-jqng2s-0 kvXAYG home-slideshow-desktop">
#      <div class="slide-container">
#       <div class="slideshow" style="width:90%;height:auto">
#        <div class="slideshowSlider" style="transform: translateX(0px);">
#         <div class="slide dupe" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo do Colégio Franciscano PIO XII" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide dupe" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo do Banco Credit Suisse" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Amazon" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Bloomberg" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Stone" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Empiricus" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Salesforce" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Graded" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Móbile" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da XP Investimentos" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Chapel" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo do Bradesco BBI" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Safra" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Dafiti" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#             </div>
#             <noscript>
#             </noscript>
#             <img alt="Logo da Sky" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="slide" style="width: 0px;">
#          <div class="slide-content">
#           <div class="slider__img">
#            <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#             <div style="box-sizing: border-box; display: block; max-width: 100%;">
# ...
#             </div>
#            </div>
#           </div>
#           <div class="slide dupe" style="width: 156px;">
#            <div class="slide-content">
#             <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#              <div style="box-sizing: border-box; display: block; max-width: 100%;">
#               <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#              </div>
#              <noscript>
#              </noscript>
#              <img alt="Infraestrutura - 3" class="sobre-photo" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: fill; object-position: center bottom;"/>
#             </div>
#            </div>
#           </div>
#           <div class="slide dupe" style="width: 156px;">
#            <div class="slide-content">
#             <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#              <div style="box-sizing: border-box; display: block; max-width: 100%;">
#               <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#              </div>
#              <noscript>
#              </noscript>
#              <img alt="Infraestrutura - 4" class="sobre-photo" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: fill; object-position: center bottom;"/>
#             </div>
#            </div>
#           </div>
#           <div class="slide dupe" style="width: 156px;">
#            <div class="slide-content">
#             <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#              <div style="box-sizing: border-box; display: block; max-width: 100%;">
#               <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#              </div>
#              <noscript>
#              </noscript>
#              <img alt="Infraestrutura - 5" class="sobre-photo" decoding="async" src="..." style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: fill; object-position: center bottom;"/>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#   </div>
#   <div class="styles__Container-xnhrx0-0 gFdQpP">
#    <div class="site-map">
#     <div class="site-map-content">
#      <div>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-title">
#         Trilha Python &amp; Dados
#        </div>
#       </div>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-subtitle">
#         Degree
#        </div>
#       </div>
#       <a href="/degree/ds">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          data science
#         </div>
#        </div>
#       </a>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-subtitle">
#         Upskilling
#        </div>
#       </div>
#       <a href="/cursos/python-adulto">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          python
#         </div>
#        </div>
#       </a>
#       <a href="/cursos/ds-ia">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          data science &amp; I.A
#         </div>
#        </div>
#       </a>
#       <a href="/cursos/python-finance">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          python for finance
#         </div>
#        </div>
#       </a>
#       <a href="/cursos/banco-de-dados">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Banco de Dados
#         </div>
#        </div>
#       </a>
#       <a href="/curso-online/python-basics">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Online Python Basics
#         </div>
#        </div>
#       </a>
#       <a href="/curso-online/python-teens">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Python Teens
#         </div>
#        </div>
#       </a>
#      </div>
#      <div>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-title">
#         Trilha Web Full Stack
#        </div>
#       </div>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-subtitle">
#         Degree
#        </div>
#       </div>
#       <a href="/degree/web">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          web full stack
#         </div>
#        </div>
#       </a>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-subtitle">
#         Upskilling
#        </div>
#       </div>
#       <a href="/cursos/web-frontend-react">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Web Front-End &amp; React
#         </div>
#        </div>
#       </a>
#       <a href="/cursos/java">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          java
#         </div>
#        </div>
#       </a>
#       <a href="/curso-online/web-and-react">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Online Web &amp; React
#         </div>
#        </div>
#       </a>
#      </div>
#      <div>
#       <div class="styles__Container-sc-1510a04-0 duKImY">
#        <div class="typography body1 footer-group-title">
#         Institucional
#        </div>
#       </div>
#       <a href="/certificado">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Certificados
#         </div>
#        </div>
#       </a>
#       <a href="/nosso-time">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Nosso Time
#         </div>
#        </div>
#       </a>
#       <a href="/blog">
#        <div class="styles__Container-sc-1510a04-0 duKImY">
#         <div class="typography body1 footer-group-link">
#          Blog
#         </div>
#        </div>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="styles__Container-sc-85gh8u-0 iNTbyI">
#   <footer class="site-footer extended">
#    <a class="footer-container-address" href="https://goo.gl/maps/CB3zVwyTvKfMfZTG8" rel="noreferrer" target="_blank">
#     <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#      <div style="box-sizing:border-box;display:block;max-width:100%">
#       <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#      </div>
#      <noscript>
#       <img alt="Ícone de localização geográfica" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/locationIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#      </noscript>
#      <img alt="Ícone de localização geográfica" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#     </div>
#     <b class="footer-text">
#      Av. Faria Lima, 1306 - 4º Andar - Pinheiros, SP
#     </b>
#    </a>
#    <div class="footer-logo">
#     <div class="footer-logo-container">
#      <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#       <div style="box-sizing:border-box;display:block;max-width:100%">
#        <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#       </div>
#       <noscript>
#        <img alt="Logo da Let's Code" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Logos/logoFooterBranco.webp 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </noscript>
#       <img alt="Logo da Let's Code" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#      </div>
#      <div class="react-logo-wrapper">
#       <b class="footer-text footer-text-small" style="margin-right:6px">
#        Feito em React
#       </b>
#       <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#        <div style="box-sizing:border-box;display:block;max-width:100%">
#         <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#        </div>
#        <noscript>
#         <img alt="Ícone do React" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/reactWhiteIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#        </noscript>
#        <img alt="Ícone do React" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-contato" style="margin:0px">
#    </div>
#    <div>
#     <div class="footer-container-phone">
#      <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#       <div style="box-sizing:border-box;display:block;max-width:100%">
#        <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#       </div>
#       <noscript>
#        <img alt="Ícone de telefone" decoding="async" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg 1x, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/phoneWhiteIcon.svg 2x" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#       </noscript>
#       <img alt="Ícone de telefone" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#      </div>
#      <b class="footer-text">
#       11 2609-3807
#      </b>
#     </div>
#    </div>
#   </footer>
#  </div>
#  <div class="styles__Container-nzozqa-0 exaHbn">
#   <div class="quiz-footer">
#    <div class="quiz-footer-text-container">
#     <a class="quiz-link" href="/descubra-sua-trilha-ideal" target="_blank">
#      <div class="styles__Container-sc-1510a04-0 duKImY">
#       <div class="typography body1">
#        <div class="call-upper">
#         Em dúvida de qual trilha seguir?
#        </div>
#        Faça nosso quiz e descubra sua trilha ideal!
#       </div>
#      </div>
#     </a>
#     <div id="mdiv">
#      <div class="mdiv">
#       <div class="md">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <script id="__NEXT_DATA__" type="application/json">
#  {"props":{"pageProps":{}},"page":"/","query":{},"buildId":"I_EDgVdhbkind1jdpHsgG","nextExport":true,"autoExport":true,"isFallback":false,"dynamicIds":[48520,35058,54899,22914],"scriptLoader":[]}
# </script>
# <next-route-announcer>
#  <p aria-live="assertive" id="__next-route-announcer__" role="alert" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;">
#  </p>
# </next-route-announcer>
# <script id="" type="text/javascript">
#  !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1571403226501915");fbq("track","PageView");
# </script>
# <noscript>
#  <img height="1" src="https://www.facebook.com/tr?id=1571403226501915&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script id="" type="text/javascript">
#  _linkedin_partner_id="429257";window._linkedin_data_partner_ids=window._linkedin_data_partner_ids||[];window._linkedin_data_partner_ids.push(_linkedin_partner_id);
# </script>
# <script id="" type="text/javascript">
#  (function(){var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://snap.licdn.com/li.lms-analytics/insight.min.js";b.parentNode.insertBefore(a,b)})();
# </script>
# <noscript>
#  <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=429257&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-dfc01efbdc94bb0936d9a35a502b0b64.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame">
# </iframe>

# %%
# Out:
# 6

# %%
element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML')
site = bs4.BeautifulSoup(resposta, 'html.parser')
len(site.find_all('a', class_="card__link"))
# Out:
# 11

# %%
# 7

# %% [markdown]
# Agora que temos o objeto do bs criado, podemos usar os métodos especiais deste objeto para extrair a informação que queremos!
#
# Lembrando que já descobrimos que queremos extrair os dados dentro da seguinte tag:
#
# `<a class='card__link'>`
#
# Pra isso, utilizaremos o método `.find()` ou `.find_all()`. Esses métodos suportam diversos argumentos para busca. Os mais comuns são:
#
# - Primeiro argumento posicional: A **tag HTML** que queremos extrair (no nosso caso, é a `a`).
# - O argumento nomeado "class_", que indica qual é a **classe CSS** que queremos extrair (no nosso caso, é a `card__link`)
#
# `.find()` vai retornar **a primeira aparição** da tag no HTML, enquanto `.find_all()` retorna **uma lista com as aparições**:

# %%
site = bs4.BeautifulSoup(resposta, 'html.parser')
len(site.find_all('a', class_="card__link"))

# %% [markdown]
# É possível visualizar a extração de forma mais bonita, usando o método `.prettify()`:

# %%
print(site.prettify())

# %% [markdown]
# Como extraímos agora as informações que queremos (título do curso, pré-requisitos e link)?
#
# O atributo `.text` retorna **apenas os textos** do objeto sopa em forma de string, sem as Tags.
#
# Com isso, é possível selecionar toda a informação que queremos! Mas, com alguns detalhes...

# %%
site.text
# Out:
# "\nHomeZero $Nosso Time CursosPython & DadosDegreeData ScienceUpskillingPythonData Science & I.APython For FinanceBanco De DadosOnline Python BasicsPython TeensWeb Full StackDegreeWeb Full StackUpskillingWeb Front-End & ReactJavaOnline Web & ReactPython & DadosWeb Full StackBlogCertificadosAo navegar pelo nosso site, você concorda com a nossapolítica de privacidade.Ok, entendi.Vamos muito além de um diploma, te preparamos para o mundo real.Conheça nossas trilhas de Data Science e Web Full Stack.Comece agoraTrilhasEncontre seu cursoEncontre seu cursoTrilha Python & DadosDegreeData ScienceUpskillingPythonData Science & I.APython For FinanceBanco De DadosOnline Python BasicsPython TeensTrilha Web Full StackDegreeWeb Full StackUpskillingWeb Front-End & ReactJavaOnline Web & ReactPython & DadosA principal linguagem para análise de dados, Data Science e Machine Learning.Web Full StackFormação completa com as ferramentas mais modernas para o desenvolvimento de Web Apps.Escolha a trilha desejada ou mantenha ao centro e veja todas as opções de cursos.DegreeData Science DegreeFormação Técnica 900hWeb Full Stack DegreeFormação Técnica 1160hUpskillingPythonPré-Requisito: Nenhum |  48hPré-RequisitoNenhumCarga Horária 48hWeb Front-End & ReactPré-Requisito: Nenhum |  72hPré-RequisitoNenhumCarga Horária 72hData Science & I.A.Pré-Requisito: Python |  72hPré-RequisitoPythonCarga Horária 72hJavaPré-Requisito: Nenhum |  72hPré-RequisitoNenhumCarga Horária 72hPython For FinancePré-Requisito: Python |  24hPré-RequisitoPythonCarga Horária 24hBanco De DadosPré-Requisito: Nenhum |  24hPré-RequisitoNenhumCarga Horária 24hOnline Python BasicsPré-Requisito: Nenhum |  10hPré-RequisitoNenhumCarga Horária 10hOnline Web & ReactPré-Requisito: Nenhum |  10hPré-RequisitoNenhumCarga Horária 10hPython TeensPré-Requisito: Nenhum |  20hPré-RequisitoNenhumCarga Horária 20hFale ConoscoEstá em dúvida sobre qual curso e formato seria ideal para você?EnviarSaiba maisCom 4 anos no mercado e mais de 5 mil alunos, a Let's Code é referência como escola de programação. A Edtech é extremamente conectada às últimas tendências e tecnologias do mercado de trabalho@letscodebrletscodebr/school/letscodebrLet's CodeTrilha Python & DadosDegreedata scienceUpskillingpythondata science & I.Apython for financeBanco de DadosOnline Python BasicsPython TeensTrilha Web Full StackDegreeweb full stackUpskillingWeb Front-End & ReactjavaOnline Web & ReactInstitucionalCertificadosNosso TimeBlogAv. Faria Lima, 1306 - 4º Andar - Pinheiros, SPFeito em React11 2609-3807Em dúvida de qual trilha seguir?Faça nosso quiz e descubra sua trilha ideal!\n\n\n\n\n\n"

# %% [markdown]
# Procurando especificamente pelas informações que queremos dentro do card do curso, identificamos as seguintes tags:
#
# - Titulo do curso:
#
# ```html
# <p class="card__text__title">
# ```
#
# - Pré-requisitos
#
# ```html
# <div class="card__text__desktop">
#     <div>
#         <span style="font-weight:500">
#             ...
#             <p style="font-weight:400">
#                 Nenhum
#             </p>
#          </span>
#     </div>
#     ...
# </div>
# ```
#
# - Carga horária:
#
# ```html
# <div class="card__text__desktop__desc">
#     <span style="font-weight:500">
#         ...
#         <p style="font-weight:400">
#             ...
#             48h
#         </p>
#     </span>
# </div>
# ```
#
#
# Vamos criar objetos pra essas tags:

# %%
cards = site.find_all('a', class_="card__link")

# %%
print(cards[1].prettify())
# Out:
# <a class="card__link" href="/degree/web">
#  <div class="card trail__web card__pi" style="opacity: 1; transform: none;">
#   <div class="card__imagem__container">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="Ícone do curso Web Full Stack Degree" decoding="async" name="Web Full Stack Degree" sizes="100vw" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 640w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 750w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 828w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 1080w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 1200w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 1920w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 2048w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/piHomeIcon.svg 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__trail__icon">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="Ícone da trilha Web Full Stack Degree" decoding="async" name="Web Full Stack Degree" sizes="100vw" src="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg" srcset="https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 640w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 750w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 828w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 1080w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 1200w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 1920w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 2048w, https://lc-public-assets.s3.sa-east-1.amazonaws.com/images/Icons/webTrailIcon.svg 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__text__container">
#    <p class="card__text__title">
#     Web Full Stack Degree
#    </p>
#    <p class="card__text__desc" style="font-weight:500">
#     Formação Técnica
#    </p>
#    <p class="card__text__desc">
#     <svg class="card__clock__icon pi" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg">
#      <g transform="translate(8.972 4.512)">
#       <path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)">
#       </path>
#      </g>
#      <path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z">
#      </path>
#     </svg>
#     <!-- -->
#     1160h
#    </p>
#   </div>
#  </div>
# </a>

# %%
cards[4].find('p', class_='card__text__title').text
# Out:
# 'Data Science & I.A.'

# %%
for card in cards:
    href = card['href']
    print(href)
    if 'degree' in href:
        print('Titulo do Degree:', card.find('p', class_='card__text__title').text)
    else:
        print('Titulo do curso:', card.find('p', class_='card__text__title').text)
    print('-'*32)
# Out:
# /degree/ds
# Titulo do Degree: Data Science Degree
# --------------------------------
# /degree/web
# Titulo do Degree: Web Full Stack Degree
# --------------------------------
# /cursos/python-adulto
# Titulo do curso: Python
# --------------------------------
# /cursos/web-frontend-react
# Titulo do curso: Web Front-End & React
# --------------------------------
# /cursos/ds-ia
# Titulo do curso: Data Science & I.A.
# --------------------------------
# /cursos/java
# Titulo do curso: Java
# --------------------------------
# /cursos/python-finance
# Titulo do curso: Python For Finance
# --------------------------------
# /cursos/banco-de-dados
# Titulo do curso: Banco De Dados
# --------------------------------
# /curso-online/python-basics
# Titulo do curso: Online Python Basics
# --------------------------------
# /curso-online/web-and-react
# Titulo do curso: Online Web & React
# --------------------------------
# /curso-online/python-teens
# Titulo do curso: Python Teens
# --------------------------------

# %%
(cards[0]
     .find('div', class_='card__text__desktop__desc')
)

# %%
# Carga horario dos cursos! Falta o degree
for card in cards:
    card = card.find('div', class_='card__text__desktop__desc')
    if card:
        print('Carga horaria:',
              card.span
                  .p
                  .text
                  .strip()
             )
# Out:
# Carga horaria: 48h
# Carga horaria: 72h
# Carga horaria: 72h
# Carga horaria: 72h
# Carga horaria: 24h
# Carga horaria: 24h
# Carga horaria: 10h
# Carga horaria: 10h
# Carga horaria: 20h

# %%
(cards[4]
     .find('div', class_='card__text__desktop')
     .div
     .span
     .p
     .text
)
# Out:
# 'Python'

# %%
for card in cards:
    href = card['href']
    print(href)
    if 'degree' in href:
        print('Titulo do Degree:', card.find('p', class_='card__text__title').text)
    else:
        print('Titulo do curso:', card.find('p', class_='card__text__title').text)
    print('-'*32)
    
# Carga horario dos cursos! Falta o degree
for card in cards:
    card = card.find('div', class_='card__text__desktop__desc')
    if card:
        print('Carga horaria:',
              card.span
                  .p
                  .text
                  .strip()
             )
# Carga horario dos cursos! Falta o degree
for card in cards:
    card = card.find('div', class_='card__text__desktop')
    if card:
        print('Pré-requisitos:',
                (card
                     .div
                     .span
                     .p
                     .text
                ))

# %%
# Carga horario dos cursos! Falta o degree
for card in cards:
    card = card.find('div', class_='card__text__desktop')
    if card:
        print('Pré-requisitos:',
                (card
                     .div
                     .span
                     .p
                     .text
                ))
# Out:
# Pré-requisitos: Nenhum
# Pré-requisitos: Nenhum
# Pré-requisitos: Python
# Pré-requisitos: Nenhum
# Pré-requisitos: Python
# Pré-requisitos: Nenhum
# Pré-requisitos: Nenhum
# Pré-requisitos: Nenhum
# Pré-requisitos: Nenhum

# %% [markdown]
# Vamos pegar o atributo text de cada um:

# %%
# 14

# %% [markdown]
# Agora só falta pegar o link!
#
# Para fazer isso, identificamos que o link é o que já está com a tag `<a class="card__link" href="/cursos/python_adulto">`
#
# Neste caso, o link está dentro da própria tag, com o parâmetro `href`
#
# > Note que o `href` é `/cursos/python_adulto`. Mas o link completo deve conter também o domnínio-base do site, que nada mais é do que o que vem antes da barra: `https://letscode-academy.com`.
#
# > Assim, o link completo é: `https://letscode-academy.com/cursos/python_adulto`
#
# Como o link está dentro da tag, sua extração **não é com o `.text`**, mas sim utilizando uma estrutura de dicionário:

# %%
for card in cards:
    base = "https://letscode.com.br"
    link = base + card['href']
    print(link)
# Out:
# https://letscode.com.br/degree/ds
# https://letscode.com.br/degree/web
# https://letscode.com.br/cursos/python-adulto
# https://letscode.com.br/cursos/web-frontend-react
# https://letscode.com.br/cursos/ds-ia
# https://letscode.com.br/cursos/java
# https://letscode.com.br/cursos/python-finance
# https://letscode.com.br/cursos/banco-de-dados
# https://letscode.com.br/curso-online/python-basics
# https://letscode.com.br/curso-online/web-and-react
# https://letscode.com.br/curso-online/python-teens

# %% [markdown]
# Agora sim! Temos extraídos:

# %% [markdown]
# Vamos juntar tudo agora:

# %%
for card in cards:
    if 'degree' in href:
        titulo = card.find('p', class_='card__text__title').text
    else:
        titulo = card.find('p', class_='card__text__title').text
    
    carga_horaria = card.find('div', class_='card__text__desktop__desc')
    carga_texto = ''
    if carga_horaria:
        carga_texto = (carga_horaria.span
                  .p
                  .text
                  .strip()
             )

    requisitos = card.find('div', class_='card__text__desktop')
    requisito_texto = ''
    if requisitos:
        requisito_texto = (requisitos
                     .div
                     .span
                     .p
                     .text
                )
    base = "https://letscode.com.br"
    link = base + card['href']
    print(titulo)
    print(requisito_texto)
    print(carga_texto)
    print(link)
    print('-'*32)
# Out:
# Data Science Degree
#
#
# https://letscode.com.br/degree/ds
# --------------------------------
# Web Full Stack Degree
#
#
# https://letscode.com.br/degree/web
# --------------------------------
# Python
# Nenhum
# 48h
# https://letscode.com.br/cursos/python-adulto
# --------------------------------
# Web Front-End & React
# Nenhum
# 72h
# https://letscode.com.br/cursos/web-frontend-react
# --------------------------------
# Data Science & I.A.
# Python
# 72h
# https://letscode.com.br/cursos/ds-ia
# --------------------------------
# Java
# Nenhum
# 72h
# https://letscode.com.br/cursos/java
# --------------------------------
# Python For Finance
# Python
# 24h
# https://letscode.com.br/cursos/python-finance
# --------------------------------
# Banco De Dados
# Nenhum
# 24h
# https://letscode.com.br/cursos/banco-de-dados
# --------------------------------
# Online Python Basics
# Nenhum
# 10h
# https://letscode.com.br/curso-online/python-basics
# --------------------------------
# Online Web & React
# Nenhum
# 10h
# https://letscode.com.br/curso-online/web-and-react
# --------------------------------
# Python Teens
# Nenhum
# 20h
# https://letscode.com.br/curso-online/python-teens
# --------------------------------

# %% [markdown]
# Perfeito!
#
# Agora que sabemos exatamente o que queremos extrair, usando a primeira aparição, vamos fazer o mesmo pra **todas as aparições**.
#
# Mas, antes, vamos organizar o nosso código que faz a extração das infomações de 1 curso em uma função para facilitar o nosso trabalho daqui para frente:

# %%
card__text__container

# %%
import re
def extrai_curso(tag):
    titulo = (
        tag
        .find('p', class_='card__text__title')
        .text
    )
    # Tratando a falta de requisito como não disponível
    try:
        requisito = (
            tag
             .find('div', class_='card__text__desktop')
             .div
             .span
             .p
             .text   
        )
    except:
        requisito = 'Não disponível'

    # Extraindo a informação de horário de cards Degree e "Cursos"
    try:
        horario = (
            tag
            .find('div', class_='card__text__desktop__desc')
            .span
            .p
            .text
            .strip()
        )
    except:
        regex = re.compile(r'\d+h')  # regex para pegar n digitos e que termine com h
        for info in (card.find('div', class_='card__text__container').find_all('p')):
            matches = regex.search(info.text)
            if matches:
                horario = (matches.group()).strip()
                
    # extraindo o link
    base = "https://letscode.com.br"
    link = base + card['href']
    
    return (titulo, requisito, horario, link)

# %% [markdown]
# Vamos então adicionar gerenciamento de errors ao nosso código.
#
# Nos casos em que houver um erro, vamos adicionar "Não disponível" ao campo

# %%
for card in cards:
    print(extrai_curso(card))
# Out:
# ('Data Science Degree', 'Não disponível', '900h', 'https://letscode.com.br/degree/ds')
# ('Web Full Stack Degree', 'Não disponível', '1160h', 'https://letscode.com.br/degree/web')
# ('Python', 'Nenhum', '48h', 'https://letscode.com.br/cursos/python-adulto')
# ('Web Front-End & React', 'Nenhum', '72h', 'https://letscode.com.br/cursos/web-frontend-react')
# ('Data Science & I.A.', 'Python', '72h', 'https://letscode.com.br/cursos/ds-ia')
# ('Java', 'Nenhum', '72h', 'https://letscode.com.br/cursos/java')
# ('Python For Finance', 'Python', '24h', 'https://letscode.com.br/cursos/python-finance')
# ('Banco De Dados', 'Nenhum', '24h', 'https://letscode.com.br/cursos/banco-de-dados')
# ('Online Python Basics', 'Nenhum', '10h', 'https://letscode.com.br/curso-online/python-basics')
# ('Online Web & React', 'Nenhum', '10h', 'https://letscode.com.br/curso-online/web-and-react')
# ('Python Teens', 'Nenhum', '20h', 'https://letscode.com.br/curso-online/python-teens')

# %% [markdown]
# Mas espera. Tem muito mais curso oferecido na Let\`s Code! Então qual o problema?
#
# Note que na pagina nem todos os cursos são carregados. Temos que clicar no botão "Mais Cursos" para que eles sejam exibidos.
#
# Vamos clickar usando o Selenium:

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('./chromedriver')  # o arquivo do chromedrive está na mesma pasta do notebook
driver.get('https://letscode.com.br/')  # entrando na pagina
time.sleep(1.)
btn = driver.find_element_by_class_name('btn__maiscursos')
print(btn)
time.sleep(1.)
btn.click()

element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML')

site = bs4.BeautifulSoup(resposta, 'html.parser')

total_todos = site.find_all('a', class_='card__link')
lista_todos = []
for total in total_todos:
    lista_todos.append(extrai_curso(total))
    
lista_todos
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-133-2bc9dfaab114> in <module>
#       5 driver.get('https://letscode.com.br/')  # entrando na pagina
#       6 time.sleep(1.)
# ----> 7 btn = driver.find_element_by_class_name('btn__maiscursos')
#       8 print(btn)
#       9 time.sleep(1.)
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=91.0.4472.77)

# %% [markdown]
# Parece que precisamos rolar a pagina até o botão

# %%
btn.location
# Out:
# {'x': 368, 'y': 3400}

# %%
# Out:
# [-200, -100, 0, 100, 200]

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('./chromedriver')  # o arquivo do chromedrive está na mesma pasta do notebook
driver.get('https://letscode.com.br/')  # entrando na pagina
time.sleep(1.)
lista_posicoes = list(range(-200, 201, 100))
sucesso = False
for posicao in lista_posicoes:
    print('offset', posicao)
    time.sleep(1)
    try:
        btn = driver.find_element_by_class_name('btn__maiscursos')
        driver.execute_script(f"window.scrollTo(0, {btn.location['y'] + (-1*posicao)})")
        time.sleep(1.)
        btn.click()

        element = driver.find_element_by_tag_name('body')
        resposta = element.get_attribute('innerHTML')

        site = bs4.BeautifulSoup(resposta, 'html.parser')

        total_todos = site.find_all('a', class_='card__link')
        lista_todos = []
        for total in total_todos:
            lista_todos.append(extrai_curso(total))

        sucesso = True
    except:
        pass
    if sucesso:
        break
lista_todos
# Out:
# offset -200
# offset -100
# offset 0
# offset 100
# [('Data Science Degree',
#   'Não disponível',
#   '20h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Web Full Stack Degree',
#   'Não disponível',
#   '20h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Python',
#   'Nenhum',
#   '48h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Web Front-End & React',
#   'Nenhum',
#   '72h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Data Science & I.A.',
#   'Python',
#   '72h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Java',
#   'Nenhum',
#   '72h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Python For Finance',
#   'Python',
#   '24h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Banco De Dados',
#   'Nenhum',
#   '24h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Online Python Basics',
#   'Nenhum',
#   '10h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Online Web & React',
#   'Nenhum',
#   '10h',
#   'https://letscode.com.br/curso-online/python-teens'),
#  ('Python Teens',
#   'Nenhum',
#   '20h',
#   'https://letscode.com.br/curso-online/python-teens')]

# %% [markdown]
# Agora que temos nossa lista de listas, podemos escrevê-la pra um arquivo da maneira que quisermos

# %% [markdown]
# # Extraindo informação com requests

# %%
import requests
resposta = requests.get("http://servicos.cptec.inpe.br/XML/listaCidades?city=manaus")

sopa = bs4.BeautifulSoup(resposta.text, 'lxml')

print(sopa.html.prettify())
# Out:
# <html>
#  <body>
#   <cidades>
#    <cidade>
#     <nome>
#      Manaus
#     </nome>
#     <uf>
#      AM
#     </uf>
#     <id>
#      234
#     </id>
#    </cidade>
#   </cidades>
#  </body>
# </html>

# %%
sopa.find_all('id')
# Out:
# [<id>244</id>, <id>5019</id>, <id>5020</id>, <id>5021</id>]

# %%
codigo = 244
url = f'http://servicos.cptec.inpe.br/XML/cidade/{codigo}/previsao.xml'
resposta = requests.get(url)
resposta
# Out:
# <Response [200]>

# %%
resposta.headers
# Out:
# {'Date': 'Thu, 22 Jul 2021 00:23:54 GMT', 'Cache-Control': 'no-cache', 'Content-Type': 'text/xml', 'Access-Control-Allow-Origin': '*', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '220', 'Keep-Alive': 'timeout=10, max=10000', 'Connection': 'Keep-Alive'}

# %%
resposta.text
# Out:
# "<?xml version='1.0' encoding='ISO-8859-1'?><cidade><nome>São Paulo</nome><uf>SP</uf><atualizacao>2021-07-21</atualizacao><previsao><dia>2021-07-22</dia><tempo>ps</tempo><maxima>20</maxima><minima>10</minima><iuv>5.0</iuv></previsao><previsao><dia>2021-07-23</dia><tempo>pn</tempo><maxima>24</maxima><minima>11</minima><iuv>5.0</iuv></previsao><previsao><dia>2021-07-24</dia><tempo>ps</tempo><maxima>25</maxima><minima>9</minima><iuv>6.0</iuv></previsao><previsao><dia>2021-07-25</dia><tempo>ps</tempo><maxima>26</maxima><minima>10</minima><iuv>6.0</iuv></previsao></cidade>"

# %%
site = bs4.BeautifulSoup(resposta.text, 'lxml')

# %%
site.nome
# Out:
# <nome>São Paulo</nome>

# %%
site.nome.text
# Out:
# 'São Paulo'

# %%
site.previsao
# Out:
# <previsao><dia>2021-07-22</dia><tempo>ps</tempo><maxima>20</maxima><minima>10</minima><iuv>5.0</iuv></previsao>

# %%
site.previsao.dia.text
# Out:
# '2021-07-22'

# %%
site.find_all('previsao')
# Out:
# [<previsao><dia>2021-07-22</dia><tempo>ps</tempo><maxima>20</maxima><minima>10</minima><iuv>5.0</iuv></previsao>,
#  <previsao><dia>2021-07-23</dia><tempo>pn</tempo><maxima>24</maxima><minima>11</minima><iuv>5.0</iuv></previsao>,
#  <previsao><dia>2021-07-24</dia><tempo>ps</tempo><maxima>25</maxima><minima>9</minima><iuv>6.0</iuv></previsao>,
#  <previsao><dia>2021-07-25</dia><tempo>ps</tempo><maxima>26</maxima><minima>10</minima><iuv>6.0</iuv></previsao>]

# %%
import datetime as dt

# %%
cidade = site.nome.text
print('Cidade:', cidade)
for previsao in site.find_all('previsao'):
    dia = dt.datetime.strptime(previsao.dia.text, "%Y-%m-%d")
    tempo = previsao.tempo.text
    maxima = previsao.maxima.text
    minima = previsao.minima.text
    iuv = previsao.iuv.text
    print(f"""
Dia: {dia:%d/%m/%Y}
Dia da semana: {dia:%A}
Tempo: {tempo}
Maxima: {maxima}
Minima: {minima}
IUV: {iuv}""")
    print('-'*32)
# Out:
# Cidade: São Paulo
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 20
# Minima: 10
# IUV: 5.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: pn
# Maxima: 24
# Minima: 11
# IUV: 5.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: ps
# Maxima: 25
# Minima: 9
# IUV: 6.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: ps
# Maxima: 26
# Minima: 10
# IUV: 6.0
# --------------------------------

# %%
import requests
import bs4
codigos_cidades = [244, 241, 222, 797, 234]
for codigo in codigos_cidades:
    url = f'http://servicos.cptec.inpe.br/XML/cidade/{codigo}/previsao.xml'
    resposta = requests.get(url)
    site = bs4.BeautifulSoup(resposta.text, 'lxml')

    cidade = site.nome.text
    print('Cidade:', cidade)
    for previsao in site.find_all('previsao'):
        dia = dt.datetime.strptime(previsao.dia.text, "%Y-%m-%d")
        tempo = previsao.tempo.text
        maxima = previsao.maxima.text
        minima = previsao.minima.text
        iuv = previsao.iuv.text
        print(f"""
Dia: {dia:%d/%m/%Y}
Dia da semana: {dia:%A}
Tempo: {tempo}
Maxima: {maxima}
Minima: {minima}
IUV: {iuv}""")
        print('-'*32)
# Out:
# Cidade: São Paulo
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 20
# Minima: 10
# IUV: 5.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: pn
# Maxima: 24
# Minima: 11
# IUV: 5.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: ps
# Maxima: 25
# Minima: 9
# IUV: 6.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: ps
# Maxima: 26
# Minima: 10
# IUV: 6.0
# --------------------------------
# Cidade: Rio de Janeiro
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 22
# Minima: 17
# IUV: 5.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: ps
# Maxima: 23
# Minima: 18
# IUV: 5.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: pn
# Maxima: 24
# Minima: 17
# IUV: 6.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: pn
# Maxima: 25
# Minima: 18
# IUV: 6.0
# --------------------------------
# Cidade: Belo Horizonte
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 23
# Minima: 12
# IUV: 6.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: ps
# Maxima: 23
# Minima: 13
# IUV: 6.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: n
# Maxima: 24
# Minima: 11
# IUV: 6.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: n
# Maxima: 25
# Minima: 11
# IUV: 6.0
# --------------------------------
# Cidade: Barueri
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 22
# Minima: 9
# IUV: 5.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: pn
# Maxima: 25
# Minima: 10
# IUV: 5.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: ps
# Maxima: 26
# Minima: 9
# IUV: 6.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: ps
# Maxima: 26
# Minima: 9
# IUV: 6.0
# --------------------------------
# Cidade: Manaus
#
# Dia: 22/07/2021
# Dia da semana: Thursday
# Tempo: ps
# Maxima: 33
# Minima: 25
# IUV: 10.0
# --------------------------------
#
# Dia: 23/07/2021
# Dia da semana: Friday
# Tempo: ci
# Maxima: 30
# Minima: 23
# IUV: 10.0
# --------------------------------
#
# Dia: 24/07/2021
# Dia da semana: Saturday
# Tempo: ci
# Maxima: 33
# Minima: 25
# IUV: 10.0
# --------------------------------
#
# Dia: 25/07/2021
# Dia da semana: Sunday
# Tempo: n
# Maxima: 32
# Minima: 25
# IUV: 11.0
# --------------------------------

# %%
import requests
import bs4
codigos_cidades = [244, 241, 222, 797, 234]
respostas = []
for codigo in codigos_cidades:
    url = f'http://servicos.cptec.inpe.br/XML/cidade/{codigo}/previsao.xml'
    resposta = requests.get(url)
    site = bs4.BeautifulSoup(resposta.text, 'lxml')

    cidade = site.nome.text
    print('Extraindo informacao da cidade:', cidade)
    for previsao in site.find_all('previsao'):
        dia = dt.datetime.strptime(previsao.dia.text, "%Y-%m-%d")
        tempo = previsao.tempo.text
        maxima = previsao.maxima.text
        minima = previsao.minima.text
        iuv = previsao.iuv.text
        respostas.append([
            cidade,
            f'{dia:%d/%m/%Y}',
            f'{dia:%A}',
            tempo,
            maxima,
            minima,
            iuv
        ])
# Out:
# Extraindo informacao da cidade: São Paulo
# Extraindo informacao da cidade: Rio de Janeiro
# Extraindo informacao da cidade: Belo Horizonte
# Extraindo informacao da cidade: Barueri
# Extraindo informacao da cidade: Manaus

# %%
respostas
# Out:
# [['São Paulo', '22/07/2021', 'Thursday', 'ps', '20', '10', '5.0'],
#  ['São Paulo', '23/07/2021', 'Friday', 'pn', '24', '11', '5.0'],
#  ['São Paulo', '24/07/2021', 'Saturday', 'ps', '25', '9', '6.0'],
#  ['São Paulo', '25/07/2021', 'Sunday', 'ps', '26', '10', '6.0'],
#  ['Rio de Janeiro', '22/07/2021', 'Thursday', 'ps', '22', '17', '5.0'],
#  ['Rio de Janeiro', '23/07/2021', 'Friday', 'ps', '23', '18', '5.0'],
#  ['Rio de Janeiro', '24/07/2021', 'Saturday', 'pn', '24', '17', '6.0'],
#  ['Rio de Janeiro', '25/07/2021', 'Sunday', 'pn', '25', '18', '6.0'],
#  ['Belo Horizonte', '22/07/2021', 'Thursday', 'ps', '23', '12', '6.0'],
#  ['Belo Horizonte', '23/07/2021', 'Friday', 'ps', '23', '13', '6.0'],
#  ['Belo Horizonte', '24/07/2021', 'Saturday', 'n', '24', '11', '6.0'],
#  ['Belo Horizonte', '25/07/2021', 'Sunday', 'n', '25', '11', '6.0'],
#  ['Barueri', '22/07/2021', 'Thursday', 'ps', '22', '9', '5.0'],
#  ['Barueri', '23/07/2021', 'Friday', 'pn', '25', '10', '5.0'],
#  ['Barueri', '24/07/2021', 'Saturday', 'ps', '26', '9', '6.0'],
#  ['Barueri', '25/07/2021', 'Sunday', 'ps', '26', '9', '6.0'],
#  ['Manaus', '22/07/2021', 'Thursday', 'ps', '33', '25', '10.0'],
#  ['Manaus', '23/07/2021', 'Friday', 'ci', '30', '23', '10.0'],
#  ['Manaus', '24/07/2021', 'Saturday', 'ci', '33', '25', '10.0'],
#  ['Manaus', '25/07/2021', 'Sunday', 'n', '32', '25', '11.0']]

# %%
with open('previsao_tempo.csv', 'a') as f:
    f.write(','.join(['cidade','dia', 'dia_da_semana', 'tempo', 'maxima', 'minima', 'iuv']))
    f.write('\n')
    for resposta in respostas:
        f.write(','.join(resposta))
        f.write('\n')
print('Arquivo fechou')

# %%
arquivo = open('previsao_tempo.csv', 'r').read()

# %%
print(arquivo)
# Out:
# cidade,dia,dia_da_semana,tempo,maxima,minima,iuv
# São Paulo,22/07/2021,Thursday,ps,20,10,5.0
# São Paulo,23/07/2021,Friday,pn,24,11,5.0
# São Paulo,24/07/2021,Saturday,ps,25,9,6.0
# São Paulo,25/07/2021,Sunday,ps,26,10,6.0
# Rio de Janeiro,22/07/2021,Thursday,ps,22,17,5.0
# Rio de Janeiro,23/07/2021,Friday,ps,23,18,5.0
# Rio de Janeiro,24/07/2021,Saturday,pn,24,17,6.0
# Rio de Janeiro,25/07/2021,Sunday,pn,25,18,6.0
# Belo Horizonte,22/07/2021,Thursday,ps,23,12,6.0
# Belo Horizonte,23/07/2021,Friday,ps,23,13,6.0
# Belo Horizonte,24/07/2021,Saturday,n,24,11,6.0
# Belo Horizonte,25/07/2021,Sunday,n,25,11,6.0
# Barueri,22/07/2021,Thursday,ps,22,9,5.0
# Barueri,23/07/2021,Friday,pn,25,10,5.0
# Barueri,24/07/2021,Saturday,ps,26,9,6.0
# Barueri,25/07/2021,Sunday,ps,26,9,6.0
# Manaus,22/07/2021,Thursday,ps,33,25,10.0
# Manaus,23/07/2021,Friday,ci,30,23,10.0
# Manaus,24/07/2021,Saturday,ci,33,25,10.0
# Manaus,25/07/2021,Sunday,n,32,25,11.0
