# %% [markdown]
# # Aula 2 - operadores lógicos, estruturas condicionais e loop while
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Operadores lógicos;
# - 2) Estruturas condicionais;
# - 3) Laços de repetição (while).
#
# _______

# %% [markdown]
# ## 1) Operadores lógicos
#
# Em muitos problemas de programação, há necessidade de se fazer **comparações** entre variáveis.
#
# Por exemplo:
#
# - checar se um número é maior que outro;
# - checar se uma variável é igual a outra;
# - checar se há números diferentes; etc.
#
# Para fazer essas comparações, utilizamos os **operadores lógicos de comparação**. Em Python, há 6 desses operadores:
#
# - Maior que: >
# - Maior ou igual: >=
# - Menor que: <
# - Menor ou igual: <=
# - Igual: ==
# - Diferente: !=
#
# O resultado de uma comparação sempre vai ser um booleano, isto é, **True** ou **False**!
#
# Dica: sempre leia as comparações como uma **pergunta**
#
# - Ex: "numero < 100", leia: "o valor na variável numero é menor que 100?"
#
# Os operadores de comparação são destacados em **roxo** no Jupyter

# %%
# definindo a variável "numero" que recebe o inteiro 

numero = 100

# %%
# Como verificar se "numero" é menor que outro número?
numero < 10
# Out:
# False

# %%
# Como verificar se "numero" é igual que outro número?
numero == 100
# Out:
# True

# %%
# Como verificar se "numero" é diferente que outro número?
12 != numero
# Out:
# True

# %%
# Int é igual a um float?
10.0 == 10
# Out:
# True

# %%
10 == 10.0
# Out:
# True

# %%
3.3333333333 == 10/3  # tomar cuidado com igualidade de floats e divisão
# Out:
# False

# %% [markdown]
# A comparação pode ser feita entre duas variáveis, também:

# %%
# definindo uma nova variável

numero2 = 25

# o valor na variavel "numero" é menor que o valor na variavel "numero2"?

numero < numero2
# Out:
# False

# %%
numero != numero2
# Out:
# True

# %%
numero > numero2
# Out:
# True

# %%
numero == numero
# Out:
# True

# %%
numero3 = 10/3

# %%
numero3 == numero3
# Out:
# True

# %% [markdown]
# Podemos também comparar strings!

# %%
cumprimento = 'Olá Pessoal!'

# %%
# pra igualdade existir, tem que haver uma correspondência EXATA entre as strings!

cumprimento == "Olá Pessoal!"
# Out:
# True

# %%
# qualquer diferença, por mínima que seja, torna a igualdade falsa!

cumprimento == "Olá  Pessoal!"
# Out:
# False

# %%
# qualquer diferença, por mínima que seja, torna a igualdade falsa!

cumprimento == "Olá PesSoal!"
# Out:
# False

# %% [markdown]
# Os operadores >, >=, <, <= atuam comparando **ordem alfabética** quando aplicados a strings.
#
# (Mencionar aqui sobre a tabela ASCII e como de fato ocorre a comparação de ordem entre strings)
# [tabela ASCII](https://www.overcoded.net/ascii-table-512119/)

# %%
"abacaxi" > "caju"
# Out:
# False

# %%
"a" > 'A'
# Out:
# True

# %%
'[' > 'A'
# Out:
# True

# %%
"1abacaxi" < "abacaxi"
# Out:
# True

# %%
"9" < "a"
# Out:
# True

# %%
9 >= 'minha_string'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-9d2452cae77f> in <module>
# ----> 1 9 >= 'minha_string'
#
# TypeError: '>=' not supported between instances of 'int' and 'str'

# %%
91 == 'minha_string'
# Out:
# False

# %%
9.0 == 'minha_string'
# Out:
# False

# %%
97 == 'a'
# Out:
# False

# %%
## Como verificar o dec
# Out:
# '0x3d'

# %%
chr(97) == 'a'
# Out:
# 'a'

# %%
ord('a') == 97
# Out:
# True

# %% [markdown]
# Podemos fazer comparação entre **tipos numéricos** diferentes (int e float):

# %%
# definindo dois numeros
num1 = 10
num2 = 20.5

# o num1 é menor que num2?
print(num1 < num2)


# o num1 é maior que num2?
print(num1 > num2)


# as variáveis são diferentes?
print(num1 != num2)
# Out:
# True
# False
# True

# %%
num3 = 10
num4 = 10.0

# %%
num3 == num4
# Out:
# True

# %% [markdown]
# Comparações entre string e tipos numéricos são possíveis **apenas para == e !=**:

# %%
# definindo uma string e um int
nome = "Danilo"
altura = 1.78

# %%
nome == altura
# Out:
# False

# %%
nome != altura
# Out:
# True

# %%
altura > nome
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-99f3b31b9293> in <module>
# ----> 1 altura > nome
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
altura <= nome
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-09f2ea7dd62b> in <module>
# ----> 1 altura <= nome
#
# TypeError: '<=' not supported between instances of 'float' and 'str'

# %%
print(type(altura), altura)
# float -> str
altura_str = str(altura)
print(type(altura_str), altura_str)

# float -> int
altura_int = int(round(altura))
print(type(altura_int), altura_int)
# Out:
# <class 'float'> 1.78
# <class 'str'> 1.78
# <class 'int'> 2

# %%
# Conseguimos transformar string em int ou float?
print(type(nome), nome)

# str -> int
nome_int = int(nome)
print(type(nome_int), nome_int)
# Out:
# <class 'str'> Danilo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-95d3ce01110b> in <module>
#       2
#       3 # str -> int
# ----> 4 nome_int = int(nome)
#       5 print(type(nome_int), nome_int)
#
# ValueError: invalid literal for int() with base 10: 'Danilo'

# %%
# Conseguimos transformar string em int ou float?
print(type(nome), nome)

# str -> float
nome_int = float(nome)
print(type(nome_int), nome_int)
# Out:
# <class 'str'> Danilo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-a4f413894647> in <module>
#       3
#       4 # str -> float
# ----> 5 nome_int = float(nome)
#       6 print(type(nome_int), nome_int)
#
# ValueError: could not convert string to float: 'Danilo'

# %%
altura_str
# Out:
# '1.78'

# %%
print(type(altura_str), altura_str)

altura_int = int(altura_str)
# print(type(altura_str), altura_str)
# Out:
# <class 'str'> 1.78
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-73f20ad7ce5b> in <module>
#       1 print(type(altura_str), altura_str)
#       2
# ----> 3 altura_int = int(altura_str)
#       4 # print(type(altura_str), altura_str)
#
# ValueError: invalid literal for int() with base 10: '1.78'

# %%
print(type(altura_str), altura_str)

altura_float = float(altura_str)
print(type(altura_float), altura_float)

altura_int = int(float(altura_str))
print(type(altura_int), altura_int)
# Out:
# <class 'str'> 1.78
# <class 'float'> 1.78
# <class 'int'> 1

# %%
numero = '10'
int(numero)
# Out:
# 10

# %%
numero2 = '10.'
int(numero2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-1397085bfec7> in <module>
#       1 numero2 = '10.'
# ----> 2 int(numero2)
#
# ValueError: invalid literal for int() with base 10: '10.'

# %%
numero2 = '10.'
float(numero2)
# Out:
# 10.0

# %%
altura
# Out:
# 1.78

# %%
# se transformar uma string em número?
altura_str = str(altura)

# Uma string de número é igual a um número?
altura == altura_str
# Out:
# False

# %%
altura
# Out:
# 1.78

# %%
altura_str
# Out:
# '1.78'

# %%
# Uma string de número é menor do que um número?
altura < altura_str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-b48a78856888> in <module>
#       1 # Uma string de número é menor do que um número?
# ----> 2 altura < altura_str
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
###
int(True)
# Out:
# 1

# %%
float(False)
# Out:
# 0.0

# %%
str(True)
# Out:
# 'True'

# %%
bool(str(True))
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
bool(True)

# %%
bool(False)
# Out:
# False

# %%
# str(False) ==> 'False' => bool('False') :=> retorna True
bool(str(False))
# Out:
# True

# %%
bool(int(False))
# Out:
# False

# %%
bool(int(True))
# Out:
# True

# %%
float(True)
# Out:
# 1.0

# %%
bool('')
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool('false')
# Out:
# True

# %%
bool('true')
# Out:
# True

# %%
bool(None)
# Out:
# False

# %% [markdown]
# O erro acima aconteceu porque **não é possível comparar a ordem (usando >, >=, <, <=)** de variáveis numéricas e strings!

# %% [markdown]
# ___

# %% [markdown]
# Além dos operadores lógicos de comparação, também temos os **operadores lógicos de conjunção**, que são utilizados pra fazer uma **combinação** entre comparações.
#
# Os operadores de conjunção são: **and** e **or**, e eles seguem a seguinte regra:
#
# - **and** só é True se **ambas** as comparações forem True:
#     - False and True resulta em "False"
#     - False and False resulta em "False"
#     - True and True resulta em "True"
# - **or** é True se **pelo menos uma** das comparações for True:
#     - False or True resulta em "True"
#     - True or True resulta em "True"
#     - False or False resulta em "False"
#
# Os operadores de conjunção são destacados em **verde escuro** no Jupyter

# %%
print("Operador and:")
# True and False, resulta em ...
print(True and False)

# False and False, resulta em ...
print(False and False)
# True and True, resulta em ...
print(True and True)
# Out:
# Operador and:
# False
# False
# True

# %%
print("Operador or:")
# True or False, resulta em ...
print(True or False)
# False or False, resulta em ...
print(False or False)

# True or True, resulta em...
print(True or True)
# Out:
# Operador or:
# True
# False
# True

# %% [markdown]
# Se tivermos mais de duas comparações pra fazer conjunção, é melhor usarmos parênteses.
#
# Primeiro a conjunção entre parênteses é feita, e depois o resultado é usado pra avaliar a conjunção total

# %%
# (True or False) and False
(True or False) and False
(1    +  0    ) *   0
# Out:
# False

# %%
True or False and False
# Out:
# True

# %%
True or (False and False)
1    +  (0     *   0    )
# Out:
# True

# %% [markdown]
# __________
# __________
# __________

# %% [markdown]
# ## 2) Estruturas condicionais
#
# O principal uso dos operadores lógicos é em **estruturas condicionais**
#
# Esse tipo de estrutura é utilizada para tratar casos diferentes dentro do código
#
# Os **operadores condicionais** são: **if**, **elif** e **else**
#
# - **if**: Se uma condição for verdadeira, faça determinada operação.
# - **elif**: Se a condição acima for falsa, avalie uma próxima condição, e se essa for verdadeira, faça outra operação
# - **else**: Se nenhuma das condições acima for verdadeira, faça outra coisa
#
# O uso de elif e else **não** é obrigatório! (Mas é muitas vezes conveniente!)
#
# As estruturas de repetição aparecem em **blocos identados (com "tab") após dois pontos**, na seguinte estrutura:
#
# ```python
# if (condicao é True):
#     operacoes
# elif (condicao é True):
#     operacoes
# else:
#     operacoes
# ```
#
# - Se alguma condição no if ou elif for verdadeira, todo o resto é ignorado!
# - Por isso, as condições no if e os diferentes elifs sempre são **excludentes**
#
# Os operadores condicionais são destacados em **verde escuro** no Jupyter

# %% [markdown]
# **Exemplo**: imagine que uma escola tem o seguinte critério de avaliação baseado na média do aluno:
#
# - se a média for maior ou igual a 5, o aluno é aprovado;
# - caso contrário, o aluno é reprovado

# %%
# defina a media
media = 4

# determina a lógica para aprovação ou reprovação
# Se média maior que um número Aluno aprovado
# Caso contrário reprovado
if media >= 5:
    print('Aluno aprovado')
else:
    print('Aluno reprovado')
# Out:
# Aluno reprovado

# %%
media = float(input('Nota do aluno: '))

if media >= 5.0:
    print('Aluno aprovado')
else:
    print('Aluno reprovado')
# Out:
# Nota do aluno:  4.99
# Aluno reprovado

# %% [markdown]
# Também podemos usar o elif, embora não seja necessário, dado que a condição `media >= 5` é única

# %%
# mesmo código usando elif

media = 4

if media >= 5:
    print('Aluno aprovado')
elif media < 5:
    print('Aluno reprovado')
# Out:
# Aluno reprovado

# %%
# mesmo código usando elif

media = float(input('Nota do aluno: '))

if media >= 5.0:
    print('Aluno aprovado')
elif media >= 5:
    print('Aluno reprovado')
# Out:
# Nota do aluno:  4.5
# Aluno recuperação

# %%
media = float(input('Nota do aluno: '))

if media >= 5:
    print('Aluno aprovado')

elif media >= 4:  # 4 a 5 recuperação
    print('Aluno recuperação')

else:
    print('Aluno reprovado')

# %% [markdown]
# **Exemplo**: imagine que uma escola tem o seguinte critério de avaliação baseado na **media** do aluno e em sua **frequência**
#
# - regra 1: se a média for maior ou igal a 9, o aluno é aprovado, independente da frequencia;
# - regra 2: se a média for maior ou igual a 6 e menor que 9, o aluno só é aprovado se a frequencia for maior ou igual a 75%
# - regra 3: se a média estiver entre 6 e 9, mas a frequencia for menor que 75%, ele vai pra recuperação
# - regra 4: se a média for menor que 6 e a frequencia do aluno for maior ou igual a 75%, ele pode fazer recuperação
# - regra 5: se a média for menor que 6 e a frequência do aluno for menor que a 75%, ele é automaticamente reprovado
#
# Como implementamos este algoritmo?

# %%
# vamos perguntar a média pro professor
media = float(input("Qual é a média do aluno? "))

# e também a frequência
frequencia = float(input("Qual é a frequencia do aluno? (digite sem o %) "))

if media >= 9:  # regra 1
    aval = 'Aprovado'

elif media >= 6 and frequencia >= 75:  # regra 2
    aval = 'Aprovado'

elif media >= 6 and frequencia < 75:  # regra 3
    aval = 'Recuperação'
    
elif media < 6 and frequencia >= 75:  # regra 4
    aval = 'Recuperação'

else:  # regra 5
    aval = 'Reprovado'


print(aval)
# Out:
# Qual é a média do aluno?  2
# Qual é a frequencia do aluno? (digite sem o %)  74.99
# Reprovado

# %% [markdown]
# **Exemplo**: imagine que uma escola tem o seguinte critério de avaliação baseado na **media** do aluno e em sua **frequência**
#
# - regra 1: se a média for maior ou igal a 9, o aluno é aprovado, independente da frequencia;
# - regra 2: se a média for maior ou igual a 6 e menor que 9, o aluno só é aprovado se a frequencia for maior ou igual a 75%
# - regra 3: se a média estiver entre 6 e 9, mas a frequencia for menor que 75%, ele vai pra recuperação
# - regra 4: se a média for menor que 6 e a frequencia do aluno for maior ou igual a 75%, ele pode fazer recuperação
# - regra 5: se a média for menor que 6 e a frequência do aluno for menor que a 75%, ele é automaticamente reprovado
#
# Como implementamos este algoritmo?

# %%
# vamos perguntar a média pro professor
media = float(input("Qual é a média do aluno? "))

# e também a frequência
frequencia = float(input("Qual é a frequencia do aluno? (digite sem o %) "))

if media >= 9:  # regra 1
    aval = 'Aprovado'

elif media >= 6:  # regra 2 e 3
    if frequencia >= 75:  # regra 2
        aval = 'Aprovado'
    else:  # regra 3
        aval = 'Recuperação'
        
else:  # regra 4 e 5
    if frequencia >= 75:  # regra 4
        aval = 'Recuperação'
    else:  # regra 5
        aval = 'Reprovado'

print(aval)
# Out:
# Qual é a média do aluno?  8
# Qual é a frequencia do aluno? (digite sem o %)  70
# Recuperação

# %% [markdown]
# __________
# __________
# __________

# %% [markdown]
# ## 3) Laços de repetição (while)
#
# Uma das utilidades de linguagens de programação é a de automatizar tarefas que são repetitivas.
#
# Mas, pra isso ser viável, seria bom se tivéssemos uma estrutura para **repetir comandos**, não é mesmo?
#
# Imagine que eu queira exibir na tela "Olá, mundo!" 5 vezes. Podemos fazer:

# %%
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
# Out:
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!

# %% [markdown]
# Mas, e se eu quiser exibir essa mensagem 1000 vezes? Ou 1 milhão de vezes? Não é ideal escrevermos o mesmo pedaço de código tantas vezes, né?
#
# Para isso, existem os **laços de repetição**, que permitem repetir pedaços de código quantas vezes desejarmos!
#
# O primeiro laço que vamos ver é o **while**. Este laço tem a seguinte estrutura:
#
# ```python
# while (condicao é True):
#     operacao_repetida
# ```
#
# Ou seja, o que tá no bloco do while é repetido **enquanto a condição for verdadeira**

# %% [markdown]
# Isso pode levar a **loops infinitos**

# %%
# Loop infinito
while 10 == 10:
    
    print("Olá, mundo")
# Out:
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# ...

# %% [markdown]
# Para que loops infinitos não aconteçam, temos que fazer uma **atualização da condição** a cada iteração do laço!
#
# Isso é, temos que **atualizar** a variavel que contabiliza as repetições no loop

# %%
# vamos definir uma variável
# "x recebe o valor 2"
x = 2

# podemos redefinir a variável em termos do valor anterior dela
# "x recebe o valor que tinha ANTES na variável, + 3"
x = x + 3

# chamando a variável
x
# Out:
# 5

# %%
x = 2
x += 3 # x = x + 3
print(x)
# Out:
# 5

# %%
x -= 3
x
# Out:
# 2

# %% [markdown]
# Assim, o que fazemos é **definir a condição do while em termos de uma variável que tenha seu valor atualizado!**
#
# Para isso, é comum nos referirmos à variàvel da condição como **variável contadora**.
#
# Para atualizar a variável contadora dentro do while, em geral a atualizamos em +1

# %%
cont = 0

while cont < 20:
    print("Olá mundo")
    cont = cont + 1
# Out:
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo

# %% [markdown]
# Vamos entender um pouco melhor como a variável contadora se comporta?
#
# Pra isso, basta exibi-la a cada iteração:

# %%
cont = 0

while cont < 5:
    print(cont)
    cont = cont + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
cont
# Out:
# 5

# %% [markdown]
# O código acima equivale a:

# %%
# inicialmente, a variavel cont vale 0
cont = 0
print(cont)

# pegamos o valor anterior (0) e somamos 1, ficando 1
cont = cont + 1
print(cont)

# pegamos o valor anterior (1) e somamos 1, ficando 2
cont = cont + 1
print(cont)

# pegamos o valor anterior (2) e somamos 1, ficando 3
cont = cont + 1
print(cont)

# pegamos o valor anterior (3) e somamos 1, ficando 4
cont = cont + 1
print(cont)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
5 != 5
# Out:
# False

# %%
cont = 0
while cont < 5:
    print(cont)
    cont +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Usar a condição com < ao invés de != em geral garante maior segurança ao seu algoritmo, pois evita imprevistos caso você receba números do usuário!

# %% [markdown]
# Podemos também atualizar a condição de repetição segundo informado pelo usuário
#
# Esse uso é bem importante para **garantir que o usuário digitou corretamente o que foi solicitado**
#
# Por exemplo, vamos pedir pro usuário digitar um número maior que 10. **Enquanto ele não fizer o que queremos**, vamos continuar pedindo pra ele digitar um novo valor:

# %%
'Hoje é dia ' + str(14)
# Out:
# 'Hoje é dia 14'

# %%
print('Hoje é dia', 14)
# Out:
# Hoje é dia 14

# %%
print(f'Hoje é dia {14}')  # veremos na aula 4
# Out:
# Hoje é dia 14

# %%
# pedimos um número ao usuário pela primeira vez:
num = float(input('Informe um número maior que 10: '))

# enquanto o número digitado for menor que 10 (note que usamos <= pq queremos numeros MAIORES que 10!) ...
while num <= 10:

    # ...pedimos o número novamente, e atualizamos o valor da variável num    
    # print('O número informado é menor que 10, ' + str(num))
    print('O número informado foi', str(num), 'Informe um número maior que 10!')
    num = float(input('Informe um número válido maior que 10: '))
    
# aqui já é fora do laço (note que não teve indentação!)
print("\nO número digitado foi:", num)
# Out:
# Informe um número maior que 10:  2
# O número informado foi 2.0 Informe um número maior que 10!
# Informe um número válido maior que 10:  3
# O número informado foi 3.0 Informe um número maior que 10!
# Informe um número válido maior que 10:  4
# O número informado foi 4.0 Informe um número maior que 10!
# Informe um número válido maior que 10:  5
# O número informado foi 5.0 Informe um número maior que 10!
# Informe um número válido maior que 10:  10.4
# O número digitado foi: 10.4

# %% [markdown]
# **Outro exemplo, onde pedirmos pro usuário digitar sua nota (para ser um valor válido, tem que estar entre 0 e 10!)**

# %%
nota = float(input('Digite a nota do aluno:'))  # Nota da prova

while nota > 10 or nota < 0:  # caso o usuário insira um valor errado
    print('O valor da nota inserida é', nota)
    print('Insira um valor entre 0 e 10')
    nota = float(input('Digite a nota do aluno:'))  # Nota da prova
    
print("\nA nota digitada foi:", nota)
# Out:
# Digite a nota do aluno: 5
# A nota digitada foi: 5.0

# %% [markdown]
# Outro exemplo...

# %%
nota = float(input('Digite a nota do aluno que é igual a 10:'))  # Nota da prova

while nota != 10:  # caso o usuário insira um valor errado
    print('O valor da nota inserida é', nota)
    nota = float(input('Digite a nota do aluno que é igual a 10:'))  # Nota da prova
    
    # nota = (input('Digite a nota do aluno que é igual a 10:'))  # Loop infinito, comparando string != número (int/float)
    
print("\nA nota digitada foi:", nota)
# Out:
# Digite a nota do aluno que é igual a 10: 1
# O valor da nota inserida é 1.0
# Digite a nota do aluno que é igual a 10: 10
# A nota digitada foi: 10.0

# %%
sexo = input("Digite seu sexo: ")

while sexo != 'm' and sexo != 'f':
    print('Sexo invalido, selecione entre m ou f')
    sexo = input("Digite seu sexo: ")
    
print(sexo)
# Out:
# Digite seu sexo:  m
# m

# %%
max_resposta_invalidas = 3
num_resposta = 0
sexo = input("Digite seu sexo: ")

while sexo != 'm' and sexo != 'f':
    print('Sexo invalido, selecione entre m ou f')
    num_tentativas_restantes = max_resposta_invalidas - num_resposta
    print('Faltam', num_tentativas_restantes, 'tentativas')
    sexo = input("Digite seu sexo: ")
    
    if num_resposta == max_resposta_invalidas:
        print('Número de tentativas esgotou! Execute novamente')
        break
    num_resposta +=1

print('Sexo', sexo)
# Out:
# Digite seu sexo:  m
# Sexo m

# %% [markdown]
# ## Primeiro algoritmo dividir para conquista (divide and conquer)
#
# Imagine que você quer calcular a raiz quadrada de um número sendo esse número maior ou igual a um (1).
#
# Como fazer?
# Uma possibilidade é a força bruta (brute force).
# Por exemplo, podemos solicitar o número e tentar número a número se esse correponde a raiz quadrada do número que estamos interrogando.
#
# Esse algoritmo parece eficiente?

# %%
# Implementar força bruta
numero = float(input('Digite um número'))
count = 0
epsilon = 0.01
resposta = ''
total = 0
while count <= numero:
    total += 1
    
    if abs(count ** 2 - numero) <= epsilon:
        resposta = count
        break
    else:
        count += epsilon
print('A raiz quadrada do número', numero, 'é', resposta)
# Out:
# Digite um número 541239
# A raiz quadrada do número 541239.0 é

# %%
total
# Out:
# 54123900

# %% [markdown]
# Conseguimos fazer de forma eficiente? Há uma área na ciências da computação que estuda o conceito de algoritmos para resolver problemas de diferentes complexidades com o objetivo de reduzir a complexidade computacional.
#
# Um desses algoritmos pode ser aplicado a esse problema que chama-se divide and conquer.
#
# Nesse algoritmo no caso dividimos o problema em sub-problemas que diminuem o espaço de busca e consequentemente a complexidade computacional.
#
# **O algoritmo:**
# Sabemos que a raiz quadrada de um número $x$ está entre $1$ e $x$.
#
# Vamos chamar a média entre o limite inferior ($1$, na primeira iteração) e o limite superior ($x$, na primeira iteração) de resposta
#
# Enquanto a resposta ao quadrado menos $x$ for maior a um erro aceitavél (epsilon), vamos repetir o seguinte loop:
#
# Se a resposta ao quadrado for maior que x:
# - Vamos atualizar o limite superior como sendo resposta
#
# Se a resposta ao quadrado for menor que x:
# - Vamos atualizar o limite inferior como sendo resposta
#
# Atualizamos o valor de resposta com os novos valores de limite superior e inferior.

# %%
# Implementar força bruta
numero = float(input('Digite um número'))
epsilon = 0.0001
inferior = 0
superior = numero
resultado = (inferior + superior) / 2
total = 0


while abs(resultado ** 2 - numero) >= epsilon:
    total += 1
    
    if resultado ** 2 > numero:
        superior = resultado
    else:
        inferior = resultado
    
    resultado = (inferior + superior) / 2
    
print('A raiz quadrada do número', numero, 'é', resultado)
# Out:
# Digite um número 541239
# A raiz quadrada do número 541239.0 é 735.6894725468558

# %% [markdown]
# ## Desafio:
#
# Utilizar a estratégia acima para criar um jogo:
#
# Nesse jogo o usuário irá pensar num número inteiro entre 0 e 100, e vamos desenvolver um programa que adivinhe de forma eficiente o número que o usuário pensou! Fantástico!
#
# O programa deve imprimir uma pergunta:
# `O número que você pensou é: {número}`
# As respostas aceitaveis são `s` ou `n` (sim ou não).  O que fazer se o usuário responder com `si` ou errar e colocar `d` por exemplo?
#
# Caso seja `n` o jogo continua, caso contrário o programa deve imprimir `O número que você pensou é: {número}`
#
# O programa deve perguntar:
# `O número que você pensou é maior ou menor?`
# As respostas aceitaveis são `maior` ou `menor`. Novamente o que fazer caso o usuário cometa um erro tipográfico?

# %%
print('Pense em um número inteiro de 0 a 100')

inferior = 0
superior = 100
resultado = (inferior + superior) // 2
resposta = False

while not resposta:
    while True:
        resposta_usuario = input('O número que você pensou é ' + str(resultado) )
        if resposta_usuario == 's' or resposta_usuario == 'n':
            break
        else:
            print('Selecione uma resposta válida (s ou n)')
            
    if resposta_usuario == 's':
        resposta = True
        
    else:
        while True:
            maior_ou_menor = input('Número maior ou menor')
            if maior_ou_menor == 'maior' or maior_ou_menor == 'menor':
                break
            else:
                print('Selecione uma resposta válida (maior ou menor)')

        if maior_ou_menor == 'maior':
            inferior = resultado
        else:
            superior = resultado
        resultado = (inferior + superior) // 2
        
print('O número que você pensou é', resultado)
# Out:
# Pense em um número inteiro de 0 a 100
# O número que você pensou é 50 dklasjdçlas
# Selecione uma resposta válida (s ou n)
# O número que você pensou é 50 jiçlsaçlas
# Selecione uma resposta válida (s ou n)
# O número que você pensou é 50 n
# Número maior ou menor maior
# O número que você pensou é 75 odsaj
# Selecione uma resposta válida (s ou n)
# O número que você pensou é 75 n
# Número maior ou menor maior
# O número que você pensou é 87 n
# Número maior ou menor menor
# O número que você pensou é 81 sim
# Selecione uma resposta válida (s ou n)
# O número que você pensou é 81 s
# O número que você pensou é 81

# %% [markdown]
# ## Resposta alunos

# %%
inferior = 0
superior = 100
calculo = None
respostas = "n"

while respostas != "s":

    calculo = (inferior + superior) // 2
    
    respostas = input(f"O número que você pensou é:  {calculo} ? (s para sim, n para não)")

    while respostas != "s" and respostas != "n":
        print(f"{respostas} não é válido!")
        respostas = input(f"O número que você pensou é:  {calculo} ? (s para sim, n para não)")

    if(respostas == "n"):
        maior_menor = input("O número que você pensou é maior ou menor? (maior ou menor)")
        while maior_menor != "maior" and maior_menor != "menor":
            print(f"{maior_menor} não é válido!")
            maior_menor = input("O número que você pensou é maior ou menor? (maior ou menor)")
    
        if(maior_menor == "maior"):
            inferior = calculo
        else:
            superior = calculo

print(f"Parabéns pra mim! seu número é {calculo}! Acertei!")

# %%
numero = int(input('Pense em um nro inteiro de 0 a 100:')) # 75
inferior = 0
superior = 100
resultado = (inferior + superior) // 2
total = 0
sim_ou_nao = ""

while (resultado != numero):
    total += 1
    sim_ou_nao = input('O número que você pensou é {0}? (s/n)'.format(resultado))
    
    if (sim_ou_nao == "s"):
        break
    
    nova_pergunta = input('O número que você pensou é maior ou menor do que o número {0} (maior/menor)'.format(resultado))
    
    if nova_pergunta == "menor":
        superior = resultado
    else:
        inferior = resultado
    
    resultado = (inferior + superior) // 2
    
print('O número que você pensou é', resultado)
# Out:
# Pense em um nro inteiro de 0 a 100: 69
# O número que você pensou é 50? (s/n) n
# O número que você pensou é maior ou menor do que o número 50 (maior/menor) maior
# O número que você pensou é 75? (s/n) n
# O número que você pensou é maior ou menor do que o número 75 (maior/menor) sdkla
# O número que você pensou é 87? (s/n) n
# O número que você pensou é maior ou menor do que o número 87 (maior/menor) menor
# O número que você pensou é 81? (s/n) s
# O número que você pensou é 81

# %%
inferior = 0
superior = 100
resultado = (inferior + superior) / 2
total = 0
resposta = "n"
print("Pense em um número de 0 a 100")

while(resposta == "n"):
    total += 1
    resposta = (input("O número que você pensou é: "+str(resultado)+"\n"))
    
    while(resposta != "n" and resposta != "s"):
        resposta = (input("Digite 's' para sim e 'n' para não: "+str(resultado)+"\n"))
    
    if(resposta == "n") :
        maior_ou_menor = input("O número que você pensou é maior ou menor?\n")
        
        while(maior_ou_menor != "menor" and maior_ou_menor != "maior"):
            maior_ou_menor = input("Digite 'maior' se for maior ou 'menor' se for menor?\n")
            
        if(maior_ou_menor == "maior"):
            inferior = resultado     
        if(maior_ou_menor == "menor"):
            superior = resultado
        resultado = ((inferior + superior) // 2)
        
print("O número que você pensou é "+str(resultado))
# Out:
# Pense em um número de 0 a 100
# O número que você pensou é: 50.0
#  n
# O número que você pensou é maior ou menor?
#  maior
# O número que você pensou é: 75
#  n
# O número que você pensou é maior ou menor?
#  ma
# Digite 'maior' se for maior ou 'menor' se for menor?
#  me
# Digite 'maior' se for maior ou 'menor' se for menor?
#  maior
# O número que você pensou é: 87
#  asd
# Digite 's' para sim e 'n' para não: 87
#  n
# O número que você pensou é maior ou menor?
#  maior
# O número que você pensou é: 93
#  ndksa
# Digite 's' para sim e 'n' para não: 93
#  na
# Digite 's' para sim e 'n' para não: 93
#  n
# O número que você pensou é maior ou menor?
#  menor
# O número que você pensou é: 90
#  s
# O número que você pensou é 90
