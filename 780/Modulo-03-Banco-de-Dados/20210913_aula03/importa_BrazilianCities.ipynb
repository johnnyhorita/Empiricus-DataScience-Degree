# %% [markdown]
# ## Importação da planilha BrazilianCities.xlsx
#
# #### Utilizando as bibliotecas pandas e psycopg2

# %%
# importa bibliotecas
import pandas as pd
import psycopg2
import psycopg2.extras as extras

# %%
# Variáveis de conexão
host = ''
dbName = 'bd_cidades_estados'
user = ''
pwd = ''

# %%
# Funcões

# Função para conexão com o banco de dados
def connect_database(host, dbName, user, pwd):
    """
    Função para conectar o banco de dados

    Parametros:
        host   : Instancia PostgreSQL
        dbName : banco de dados
        user   : usuário
        pwd    : senha do usuário
        
    Retornos:
        cur  : Utilize para conectar e executar os comandos SQL.
        conn : Conexão com o banco de dados.
    """
    # connect to default database
    conn = psycopg2.connect(f"host={host} dbname={dbName} user={user} password={pwd}")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    return cur, conn

# Função para criar as tabelas
def create_tables(stmt_create_tables):
    """
    Função para criar tabelas

    Parametros:
        cur  : Utilize para conectar e executar os comandos SQL.
        conn : Conexão com o banco de dados.
    """
    for stmt in stmt_create_tables:
        cur.execute(stmt)
        conn.commit()
    return


# Função genérica para inserir linhas
def insert_rows(df, insert_stmt):
    """
    Função genérica para inserir linhas em tabela
    
    Parametros:
        df          : Dataframe com os valores a serem inseridos
        insert_stmt : Comando de insert 
    """
    # Executa o loop para gerar as tuplas com os valores a serem inseridos
    for row in df.itertuples(index=False):
        # print(tuple(row))
        # Executa o insert
        cur.execute(insert_stmt, tuple(row))
    print("Dados inseridos com sucesso...")
    return

# função usando psycopg2.extras.execute_values() para inserir o dataframe
def insert_tb_cidade(df):    
    """
    Função usando psycopg2.extras.execute_values() para inserir o dataframe
    
    Parametros:
        df    : Dataframe com os valores a serem inseridos
    """   
    # Criação de uma lista de tupples a partir dos valores do dataframe
    tpls = [tuple(row) for row in df.itertuples(index=False)]
    
    # Comando de inserção
    sql = """ INSERT INTO tb_cidade (nome_cidade, id_estado) VALUES %s"""
    try:
        extras.execute_values(cur, sql, tpls)
        print("Dados inseridos usando execute_values() com sucesso...")
    except (Exception, psycopg2.DatabaseError) as err:
        show_psycopg2_exception(err)
        cursor.close()
    return

# %%
# Conexão com o banco de dados Postgre
cur, conn = connect_database(host, dbName, user, pwd)

# %%
# Comandos para criação das tabelas
stmt_create_tables = list()
stmt_create_tables.append('CREATE TABLE IF NOT EXISTS tb_estado (id_estado smallserial not null primary key, nome_estado varchar(100) not null, sigla_estado char(02) not null);')
stmt_create_tables.append('CREATE TABLE IF NOT EXISTS tb_cidade (id_cidade smallserial not null primary key, nome_cidade varchar(300) not null, id_estado smallint not null);')

# %%
# Cria as tabelas no banco de dados
create_tables(stmt_create_tables)

# %%
# Cria datraframe com a planilha principal
df = pd.read_excel('BrazilianCities.xlsx', sheet_name='BrazilianCities')

# %%
# Gera dataframe de estado
df_estado = df[['Estado', 'Sigla']].copy()

# %%
df_estado.shape
# Out:
# (5570, 2)

# %%
# Retira os estados repetidos
df_estado = df_estado.drop_duplicates(keep='last').copy()

# %%
df_estado.shape
# Out:
# (27, 2)

# %%
#Comando para truncar a tabela 
cur.execute('truncate table tb_estado restart identity')  

#Comando para inserir os registros
postgres_insert_query = """ INSERT INTO tb_estado (id_estado, nome_estado, sigla_estado) VALUES (DEFAULT,%s,%s)"""

#Chamada da função para inserção dos dados (linha a linha)
insert_rows(df_estado, postgres_insert_query)
# Out:
# Dados inseridos com sucesso...

# %%
# Select na tabela tb_estado para verificar as linhas inseridas
cur.execute('SELECT * FROM tb_estado')  
rows = cur.fetchall()
rows
# Out:
# [(1, 'DISTRITO FEDERAL', 'DF'),
#  (2, 'RORAIMA', 'RR'),
#  (3, 'SERGIPE', 'SE'),
#  (4, 'AMAZONAS', 'AM'),
#  (5, 'MATO GROSSO DO SUL', 'MS'),
#  (6, 'ALAGOAS', 'AL'),
#  (7, 'CEARÁ', 'CE'),
#  (8, 'RIO GRANDE DO NORTE', 'RN'),
#  (9, 'GOIÁS', 'GO'),
#  (10, 'MATO GROSSO', 'MT'),
#  (11, 'RONDÔNIA', 'RO'),
#  (12, 'ESPÍRITO SANTO', 'ES'),
#  (13, 'AMAPÁ', 'AP'),
#  (14, 'RIO DE JANEIRO', 'RJ'),
#  (15, 'PIAUÍ', 'PI'),
#  (16, 'MINAS GERAIS', 'MG'),
#  (17, 'TOCANTINS', 'TO'),
#  (18, 'PARANÁ', 'PR'),
#  (19, 'RIO GRANDE DO SUL', 'RS'),
#  (20, 'ACRE', 'AC'),
#  (21, 'PERNAMBUCO', 'PE'),
#  (22, 'PARÁ', 'PA'),
#  (23, 'BAHIA', 'BA'),
#  (24, 'PARAÍBA', 'PB'),
#  (25, 'SÃO PAULO', 'SP'),
#  (26, 'MARANHÃO', 'MA'),
#  (27, 'SANTA CATARINA', 'SC')]

# %%
# Cria o Dataframe com os estados a partir da leitura da tabela para carregar o id_estado
df_estadoSQL = pd.read_sql('SELECT * FROM tb_estado', conn);

# %%
df_estadoSQL
# Out:
#     id_estado          nome_estado sigla_estado
# 0           1     DISTRITO FEDERAL           DF
# 1           2              RORAIMA           RR
# 2           3              SERGIPE           SE
# 3           4             AMAZONAS           AM
# 4           5   MATO GROSSO DO SUL           MS
# 5           6              ALAGOAS           AL
# 6           7                CEARÁ           CE
# 7           8  RIO GRANDE DO NORTE           RN
# 8           9                GOIÁS           GO
# 9          10          MATO GROSSO           MT
# 10         11             RONDÔNIA           RO
# 11         12       ESPÍRITO SANTO           ES
# 12         13                AMAPÁ           AP
# 13         14       RIO DE JANEIRO           RJ
# 14         15                PIAUÍ           PI
# 15         16         MINAS GERAIS           MG
# 16         17            TOCANTINS           TO
# 17         18               PARANÁ           PR
# 18         19    RIO GRANDE DO SUL           RS
# 19         20                 ACRE           AC
# 20         21           PERNAMBUCO           PE
# 21         22                 PARÁ           PA
# 22         23                BAHIA           BA
# 23         24              PARAÍBA           PB
# 24         25            SÃO PAULO           SP
# 25         26             MARANHÃO           MA
# 26         27       SANTA CATARINA           SC

# %%
# Cria o dataframe df_cidade com o join do dataframe df (planilha) e dataframe df_estadoSQL 
# para referenciar o id_estado nas cidades
df_cidade = pd.merge(left=df, right=df_estadoSQL, left_on='Sigla', right_on='sigla_estado').copy()

# %%
# Processo incluindo em lote utilizando psycopg2.extras.execute_values() é mais performático
cur.execute('truncate table tb_cidade restart identity')  
insert_tb_cidade(df_cidade[['Cidade', 'id_estado']])
# Out:
# Dados inseridos usando execute_values() com sucesso...

# %%
# Select na tabela tb_cidade para contabilizar as cidades por estado
cur.execute("""
            select 	count(id_cidade) AS "Qtd_Cidades", 
                    e.nome_estado, 
                    e.sigla_estado 
            from 		tb_cidade c 
            inner join 	tb_estado e 
                    on	e.id_estado = c.id_estado  
            group by e.nome_estado, e.sigla_estado
            order by e.sigla_estado
            """)
rows = cur.fetchall()
rows
# Out:
# [(22, 'ACRE', 'AC'),
#  (102, 'ALAGOAS', 'AL'),
#  (62, 'AMAZONAS', 'AM'),
#  (16, 'AMAPÁ', 'AP'),
#  (417, 'BAHIA', 'BA'),
#  (184, 'CEARÁ', 'CE'),
#  (1, 'DISTRITO FEDERAL', 'DF'),
#  (78, 'ESPÍRITO SANTO', 'ES'),
#  (246, 'GOIÁS', 'GO'),
#  (217, 'MARANHÃO', 'MA'),
#  (853, 'MINAS GERAIS', 'MG'),
#  (79, 'MATO GROSSO DO SUL', 'MS'),
#  (141, 'MATO GROSSO', 'MT'),
#  (144, 'PARÁ', 'PA'),
#  (223, 'PARAÍBA', 'PB'),
#  (185, 'PERNAMBUCO', 'PE'),
#  (224, 'PIAUÍ', 'PI'),
#  (399, 'PARANÁ', 'PR'),
#  (92, 'RIO DE JANEIRO', 'RJ'),
#  (167, 'RIO GRANDE DO NORTE', 'RN'),
#  (52, 'RONDÔNIA', 'RO'),
#  (15, 'RORAIMA', 'RR'),
#  (497, 'RIO GRANDE DO SUL', 'RS'),
#  (295, 'SANTA CATARINA', 'SC'),
#  (75, 'SERGIPE', 'SE'),
#  (645, 'SÃO PAULO', 'SP'),
#  (139, 'TOCANTINS', 'TO')]

# %%
# Select na tabela tb_cidade para verificar as linhas inseridas
cur.execute('SELECT * FROM tb_cidade')  
rows = cur.fetchall()
rows
# Out:
# [(1, 'ABADIA DE GOIÁS', 9),
#  (2, 'ABADIÂNIA', 9),
#  (3, 'ACREÚNA', 9),
#  (4, 'ADELÂNDIA', 9),
#  (5, 'ÁGUA FRIA DE GOIÁS', 9),
#  (6, 'ÁGUA LIMPA', 9),
#  (7, 'ÁGUAS LINDAS DE GOIÁS', 9),
#  (8, 'ALEXÂNIA', 9),
#  (9, 'ALOÂNDIA', 9),
#  (10, 'ALTO HORIZONTE', 9),
#  (11, 'ALTO PARAÍSO DE GOIÁS', 9),
#  (12, 'ALVORADA DO NORTE', 9),
#  (13, 'AMARALINA', 9),
#  (14, 'AMERICANO DO BRASIL', 9),
#  (15, 'AMORINÓPOLIS', 9),
#  (16, 'ANÁPOLIS', 9),
#  (17, 'ANHANGUERA', 9),
#  (18, 'ANICUNS', 9),
#  (19, 'APARECIDA DE GOIÂNIA', 9),
#  (20, 'APARECIDA DO RIO DOCE', 9),
#  (21, 'APORÉ', 9),
#  (22, 'ARAÇU', 9),
#  (23, 'ARAGARÇAS', 9),
#  (24, 'ARAGOIÂNIA', 9),
#  (25, 'ARAGUAPAZ', 9),
#  (26, 'ARENÓPOLIS', 9),
#  (27, 'ARUANÃ', 9),
#  (28, 'AURILÂNDIA', 9),
#  (29, 'AVELINÓPOLIS', 9),
#  (30, 'BALIZA', 9),
#  (31, 'BARRO ALTO', 9),
#  (32, 'BELA VISTA DE GOIÁS', 9),
#  (33, 'BOM JARDIM DE GOIÁS', 9),
#  (34, 'BOM JESUS DE GOIÁS', 9),
#  (35, 'BONFINÓPOLIS', 9),
#  (36, 'BONÓPOLIS', 9),
#  (37, 'BRAZABRANTES', 9),
#  (38, 'BRITÂNIA', 9),
#  (39, 'BURITI ALEGRE', 9),
#  (40, 'BURITI DE GOIÁS', 9),
#  (41, 'BURITINÓPOLIS', 9),
#  (42, 'CABECEIRAS', 9),
#  (43, 'CACHOEIRA ALTA', 9),
#  (44, 'CACHOEIRA DE GOIÁS', 9),
#  (45, 'CACHOEIRA DOURADA', 9),
#  (46, 'CAÇU', 9),
#  (47, 'CAIAPÔNIA', 9),
#  (48, 'CALDAS NOVAS', 9),
#  (49, 'CALDAZINHA', 9),
#  (50, 'CAMPESTRE DE GOIÁS', 9),
#  (51, 'CAMPINAÇU', 9),
#  (52, 'CAMPINORTE', 9),
#  (53, 'CAMPO ALEGRE DE GOIÁS', 9),
#  (54, 'CAMPO LIMPO DE GOIÁS', 9),
#  (55, 'CAMPOS BELOS', 9),
#  (56, 'CAMPOS VERDES', 9),
#  (57, 'CARMO DO RIO VERDE', 9),
#  (58, 'CASTELÂNDIA', 9),
#  (59, 'CATALÃO', 9),
#  (60, 'CATURAÍ', 9),
#  (61, 'CAVALCANTE', 9),
#  (62, 'CERES', 9),
#  (63, 'CEZARINA', 9),
#  (64, 'CHAPADÃO DO CÉU', 9),
#  (65, 'CIDADE OCIDENTAL', 9),
#  (66, 'COCALZINHO DE GOIÁS', 9),
#  (67, 'COLINAS DO SUL', 9),
#  (68, 'CÓRREGO DO OURO', 9),
#  (69, 'CORUMBÁ DE GOIÁS', 9),
#  (70, 'CORUMBAÍBA', 9),
#  (71, 'CRISTALINA', 9),
#  (72, 'CRISTIANÓPOLIS', 9),
#  (73, 'CRIXÁS', 9),
#  (74, 'CROMÍNIA', 9),
#  (75, 'CUMARI', 9),
#  (76, 'DAMIANÓPOLIS', 9),
#  (77, 'DAMOLÂNDIA', 9),
#  (78, 'DAVINÓPOLIS', 9),
#  (79, 'DIORAMA', 9),
#  (80, 'DIVINÓPOLIS DE GOIÁS', 9),
#  (81, 'DOVERLÂNDIA', 9),
#  (82, 'EDEALINA', 9),
#  (83, 'EDÉIA', 9),
#  (84, 'ESTRELA DO NORTE', 9),
#  (85, 'FAINA', 9),
#  (86, 'FAZENDA NOVA', 9),
#  (87, 'FIRMINÓPOLIS', 9),
#  (88, 'FLORES DE GOIÁS', 9),
#  (89, 'FORMOSA', 9),
#  (90, 'FORMOSO', 9),
#  (91, 'GAMELEIRA DE GOIÁS', 9),
#  (92, 'GOIANÁPOLIS', 9),
#  (93, 'GOIANDIRA', 9),
#  (94, 'GOIANÉSIA', 9),
#  (95, 'GOIÂNIA', 9),
#  (96, 'GOIANIRA', 9),
#  (97, 'GOIÁS', 9),
#  (98, 'GOIATUBA', 9),
#  (99, 'GOUVELÂNDIA', 9),
#  (100, 'GUAPÓ', 9),
#  (101, 'GUARAÍTA', 9),
#  (102, 'GUARANI DE GOIÁS', 9),
#  (103, 'GUARINOS', 9),
#  (104, 'HEITORAÍ', 9),
#  (105, 'HIDROLÂNDIA', 9),
#  (106, 'HIDROLINA', 9),
#  (107, 'IACIARA', 9),
#  (108, 'INACIOLÂNDIA', 9),
#  (109, 'INDIARA', 9),
#  (110, 'INHUMAS', 9),
#  (111, 'IPAMERI', 9),
#  (112, 'IPIRANGA DE GOIÁS', 9),
#  (113, 'IPORÁ', 9),
#  (114, 'ISRAELÂNDIA', 9),
#  (115, 'ITABERAÍ', 9),
#  (116, 'ITAGUARI', 9),
#  (117, 'ITAGUARU', 9),
#  (118, 'ITAJÁ', 9),
#  (119, 'ITAPACI', 9),
#  (120, 'ITAPIRAPUÃ', 9),
#  (121, 'ITAPURANGA', 9),
#  (122, 'ITARUMÃ', 9),
#  (123, 'ITAUÇU', 9),
#  (124, 'ITUMBIARA', 9),
#  (125, 'IVOLÂNDIA', 9),
#  (126, 'JANDAIA', 9),
#  (127, 'JARAGUÁ', 9),
#  (128, 'JATAÍ', 9),
#  (129, 'JAUPACI', 9),
#  (130, 'JESÚPOLIS', 9),
#  (131, 'JOVIÂNIA', 9),
#  (132, 'JUSSARA', 9),
#  (133, 'LAGOA SANTA', 9),
#  (134, 'LEOPOLDO DE BULHÕES', 9),
#  (135, 'LUZIÂNIA', 9),
#  (136, 'MAIRIPOTABA', 9),
#  (137, 'MAMBAÍ', 9),
#  (138, 'MARA ROSA', 9),
#  (139, 'MARZAGÃO', 9),
#  (140, 'MATRINCHÃ', 9),
#  (141, 'MAURILÂNDIA', 9),
#  (142, 'MIMOSO DE GOIÁS', 9),
#  (143, 'MINAÇU', 9),
#  (144, 'MINEIROS', 9),
#  (145, 'MOIPORÁ', 9),
#  (146, 'MONTE ALEGRE DE GOIÁS', 9),
#  (147, 'MONTES CLAROS DE GOIÁS', 9),
#  (148, 'MONTIVIDIU', 9),
#  (149, 'MONTIVIDIU DO NORTE', 9),
#  (150, 'MORRINHOS', 9),
#  (151, 'MORRO AGUDO DE GOIÁS', 9),
#  (152, 'MOSSÂMEDES', 9),
#  (153, 'MOZARLÂNDIA', 9),
#  (154, 'MUNDO NOVO', 9),
#  (155, 'MUTUNÓPOLIS', 9),
#  (156, 'NAZÁRIO', 9),
#  (157, 'NERÓPOLIS', 9),
#  (158, 'NIQUELÂNDIA', 9),
#  (159, 'NOVA AMÉRICA', 9),
#  (160, 'NOVA AURORA', 9),
#  (161, 'NOVA CRIXÁS', 9),
#  (162, 'NOVA GLÓRIA', 9),
#  (163, 'NOVA IGUAÇU DE GOIÁS', 9),
#  (164, 'NOVA ROMA', 9),
#  (165, 'NOVA VENEZA', 9),
#  (166, 'NOVO BRASIL', 9),
#  (167, 'NOVO GAMA', 9),
#  (168, 'NOVO PLANALTO', 9),
#  (169, 'ORIZONA', 9),
#  (170, 'OURO VERDE DE GOIÁS', 9),
#  (171, 'OUVIDOR', 9),
#  (172, 'PADRE BERNARDO', 9),
#  (173, 'PALESTINA DE GOIÁS', 9),
#  (174, 'PALMEIRAS DE GOIÁS', 9),
#  (175, 'PALMELO', 9),
#  (176, 'PALMINÓPOLIS', 9),
#  (177, 'PANAMÁ', 9),
#  (178, 'PARANAIGUARA', 9),
#  (179, 'PARAÚNA', 9),
#  (180, 'PEROLÂNDIA', 9),
#  (181, 'PETROLINA DE GOIÁS', 9),
#  (182, 'PILAR DE GOIÁS', 9),
#  (183, 'PIRACANJUBA', 9),
#  (184, 'PIRANHAS', 9),
#  (185, 'PIRENÓPOLIS', 9),
#  (186, 'PIRES DO RIO', 9),
#  (187, 'PLANALTINA', 9),
#  (188, 'PONTALINA', 9),
#  (189, 'PORANGATU', 9),
#  (190, 'PORTEIRÃO', 9),
#  (191, 'PORTELÂNDIA', 9),
#  (192, 'POSSE', 9),
#  (193, 'PROFESSOR JAMIL', 9),
#  (194, 'QUIRINÓPOLIS', 9),
#  (195, 'RIALMA', 9),
#  (196, 'RIANÁPOLIS', 9),
#  (197, 'RIO QUENTE', 9),
#  (198, 'RIO VERDE', 9),
#  (199, 'RUBIATABA', 9),
#  (200, 'SANCLERLÂNDIA', 9),
#  (201, 'SANTA BÁRBARA DE GOIÁS', 9),
#  (202, 'SANTA CRUZ DE GOIÁS', 9),
#  (203, 'SANTA FÉ DE GOIÁS', 9),
#  (204, 'SANTA HELENA DE GOIÁS', 9),
#  (205, 'SANTA ISABEL', 9),
#  (206, 'SANTA RITA DO ARAGUAIA', 9),
#  (207, 'SANTA RITA DO NOVO DESTINO', 9),
#  (208, 'SANTA ROSA DE GOIÁS', 9),
#  (209, 'SANTA TEREZA DE GOIÁS', 9),
#  (210, 'SANTA TEREZINHA DE GOIÁS', 9),
#  (211, 'SANTO ANTÔNIO DA BARRA', 9),
#  (212, 'SANTO ANTÔNIO DE GOIÁS', 9),
#  (213, 'SANTO ANTÔNIO DO DESCOBERTO', 9),
#  (214, 'SÃO DOMINGOS', 9),
#  (215, 'SÃO FRANCISCO DE GOIÁS', 9),
#  (216, 'SÃO JOÃO DA PARAÚNA', 9),
#  (217, "SÃO JOÃO D'ALIANÇA", 9),
#  (218, 'SÃO LUÍS DE MONTES BELOS', 9),
#  (219, 'SÃO LUIZ DO NORTE', 9),
#  (220, 'SÃO MIGUEL DO ARAGUAIA', 9),
#  (221, 'SÃO MIGUEL DO PASSA QUATRO', 9),
#  (222, 'SÃO PATRÍCIO', 9),
#  (223, 'SÃO SIMÃO', 9),
#  (224, 'SENADOR CANEDO', 9),
#  (225, 'SERRANÓPOLIS', 9),
#  (226, 'SILVÂNIA', 9),
#  (227, 'SIMOLÂNDIA', 9),
#  (228, "SÍTIO D'ABADIA", 9),
#  (229, 'TAQUARAL DE GOIÁS', 9),
#  (230, 'TERESINA DE GOIÁS', 9),
#  (231, 'TEREZÓPOLIS DE GOIÁS', 9),
#  (232, 'TRÊS RANCHOS', 9),
#  (233, 'TRINDADE', 9),
#  (234, 'TROMBAS', 9),
#  (235, 'TURVÂNIA', 9),
#  (236, 'TURVELÂNDIA', 9),
#  (237, 'UIRAPURU', 9),
#  (238, 'URUAÇU', 9),
#  (239, 'URUANA', 9),
#  (240, 'URUTAÍ', 9),
#  (241, 'VALPARAÍSO DE GOIÁS', 9),
#  (242, 'VARJÃO', 9),
#  (243, 'VIANÓPOLIS', 9),
#  (244, 'VICENTINÓPOLIS', 9),
#  (245, 'VILA BOA', 9),
#  (246, 'VILA PROPÍCIO', 9),
#  (247, 'ABADIA DOS DOURADOS', 16),
#  (248, 'ABAETÉ', 16),
#  (249, 'ABRE CAMPO', 16),
#  (250, 'ACAIACA', 16),
#  (251, 'AÇUCENA', 16),
#  (252, 'ÁGUA BOA', 16),
#  (253, 'ÁGUA COMPRIDA', 16),
#  (254, 'AGUANIL', 16),
#  (255, 'ÁGUAS FORMOSAS', 16),
#  (256, 'ÁGUAS VERMELHAS', 16),
#  (257, 'AIMORÉS', 16),
#  (258, 'AIURUOCA', 16),
#  (259, 'ALAGOA', 16),
#  (260, 'ALBERTINA', 16),
#  (261, 'ALÉM PARAÍBA', 16),
#  (262, 'ALFENAS', 16),
#  (263, 'ALFREDO VASCONCELOS', 16),
#  (264, 'ALMENARA', 16),
#  (265, 'ALPERCATA', 16),
#  (266, 'ALPINÓPOLIS', 16),
#  (267, 'ALTEROSA', 16),
#  (268, 'ALTO CAPARAÓ', 16),
#  (269, 'ALTO JEQUITIBÁ', 16),
#  (270, 'ALTO RIO DOCE', 16),
#  (271, 'ALVARENGA', 16),
#  (272, 'ALVINÓPOLIS', 16),
#  (273, 'ALVORADA DE MINAS', 16),
#  (274, 'AMPARO DO SERRA', 16),
#  (275, 'ANDRADAS', 16),
#  (276, 'ANDRELÂNDIA', 16),
#  (277, 'ANGELÂNDIA', 16),
#  (278, 'ANTÔNIO CARLOS', 16),
#  (279, 'ANTÔNIO DIAS', 16),
#  (280, 'ANTÔNIO PRADO DE MINAS', 16),
#  (281, 'ARAÇAÍ', 16),
#  (282, 'ARACITABA', 16),
#  (283, 'ARAÇUAÍ', 16),
#  (284, 'ARAGUARI', 16),
#  (285, 'ARANTINA', 16),
#  (286, 'ARAPONGA', 16),
#  (287, 'ARAPORÃ', 16),
#  (288, 'ARAPUÁ', 16),
#  (289, 'ARAÚJOS', 16),
#  (290, 'ARAXÁ', 16),
#  (291, 'ARCEBURGO', 16),
#  (292, 'ARCOS', 16),
#  (293, 'AREADO', 16),
#  (294, 'ARGIRITA', 16),
#  (295, 'ARICANDUVA', 16),
#  (296, 'ARINOS', 16),
#  (297, 'ASTOLFO DUTRA', 16),
#  (298, 'ATALÉIA', 16),
#  (299, 'AUGUSTO DE LIMA', 16),
#  (300, 'BAEPENDI', 16),
#  (301, 'BALDIM', 16),
#  (302, 'BAMBUÍ', 16),
#  (303, 'BANDEIRA', 16),
#  (304, 'BANDEIRA DO SUL', 16),
#  (305, 'BARÃO DE COCAIS', 16),
#  (306, 'BARÃO DE MONTE ALTO', 16),
#  (307, 'BARBACENA', 16),
#  (308, 'BARRA LONGA', 16),
#  (309, 'BARROSO', 16),
#  (310, 'BELA VISTA DE MINAS', 16),
#  (311, 'BELMIRO BRAGA', 16),
#  (312, 'BELO HORIZONTE', 16),
#  (313, 'BELO ORIENTE', 16),
#  (314, 'BELO VALE', 16),
#  (315, 'BERILO', 16),
#  (316, 'BERIZAL', 16),
#  (317, 'BERTÓPOLIS', 16),
#  (318, 'BETIM', 16),
#  (319, 'BIAS FORTES', 16),
#  (320, 'BICAS', 16),
#  (321, 'BIQUINHAS', 16),
#  (322, 'BOA ESPERANÇA', 16),
#  (323, 'BOCAINA DE MINAS', 16),
#  (324, 'BOCAIÚVA', 16),
#  (325, 'BOM DESPACHO', 16),
#  (326, 'BOM JARDIM DE MINAS', 16),
#  (327, 'BOM JESUS DA PENHA', 16),
#  (328, 'BOM JESUS DO AMPARO', 16),
#  (329, 'BOM JESUS DO GALHO', 16),
#  (330, 'BOM REPOUSO', 16),
#  (331, 'BOM SUCESSO', 16),
#  (332, 'BONFIM', 16),
#  (333, 'BONFINÓPOLIS DE MINAS', 16),
#  (334, 'BONITO DE MINAS', 16),
#  (335, 'BORDA DA MATA', 16),
#  (336, 'BOTELHOS', 16),
#  (337, 'BOTUMIRIM', 16),
#  (338, 'BRÁS PIRES', 16),
#  (339, 'BRASILÂNDIA DE MINAS', 16),
#  (340, 'BRASÍLIA DE MINAS', 16),
#  (341, 'BRAÚNAS', 16),
#  (342, 'BRAZÓPOLIS', 16),
#  (343, 'BRUMADINHO', 16),
#  (344, 'BUENO BRANDÃO', 16),
#  (345, 'BUENÓPOLIS', 16),
#  (346, 'BUGRE', 16),
#  (347, 'BURITIS', 16),
#  (348, 'BURITIZEIRO', 16),
#  (349, 'CABECEIRA GRANDE', 16),
#  (350, 'CABO VERDE', 16),
#  (351, 'CACHOEIRA DA PRATA', 16),
#  (352, 'CACHOEIRA DE MINAS', 16),
#  (353, 'CACHOEIRA DE PAJEÚ', 16),
#  (354, 'CACHOEIRA DOURADA', 16),
#  (355, 'CAETANÓPOLIS', 16),
#  (356, 'CAETÉ', 16),
#  (357, 'CAIANA', 16),
#  (358, 'CAJURI', 16),
#  (359, 'CALDAS', 16),
#  (360, 'CAMACHO', 16),
#  (361, 'CAMANDUCAIA', 16),
#  (362, 'CAMBUÍ', 16),
#  (363, 'CAMBUQUIRA', 16),
#  (364, 'CAMPANÁRIO', 16),
#  (365, 'CAMPANHA', 16),
#  (366, 'CAMPESTRE', 16),
#  (367, 'CAMPINA VERDE', 16),
#  (368, 'CAMPO AZUL', 16),
#  (369, 'CAMPO BELO', 16),
#  (370, 'CAMPO DO MEIO', 16),
#  (371, 'CAMPO FLORIDO', 16),
#  (372, 'CAMPOS ALTOS', 16),
#  (373, 'CAMPOS GERAIS', 16),
#  (374, 'CANA VERDE', 16),
#  (375, 'CANAÃ', 16),
#  (376, 'CANÁPOLIS', 16),
#  (377, 'CANDEIAS', 16),
#  (378, 'CANTAGALO', 16),
#  (379, 'CAPARAÓ', 16),
#  (380, 'CAPELA NOVA', 16),
#  (381, 'CAPELINHA', 16),
#  (382, 'CAPETINGA', 16),
#  (383, 'CAPIM BRANCO', 16),
#  (384, 'CAPINÓPOLIS', 16),
#  (385, 'CAPITÃO ANDRADE', 16),
#  (386, 'CAPITÃO ENÉAS', 16),
#  (387, 'CAPITÓLIO', 16),
#  (388, 'CAPUTIRA', 16),
#  (389, 'CARAÍ', 16),
#  (390, 'CARANAÍBA', 16),
#  (391, 'CARANDAÍ', 16),
#  (392, 'CARANGOLA', 16),
#  (393, 'CARATINGA', 16),
#  (394, 'CARBONITA', 16),
#  (395, 'CAREAÇU', 16),
#  (396, 'CARLOS CHAGAS', 16),
#  (397, 'CARMÉSIA', 16),
#  (398, 'CARMO DA CACHOEIRA', 16),
#  (399, 'CARMO DA MATA', 16),
#  (400, 'CARMO DE MINAS', 16),
#  (401, 'CARMO DO CAJURU', 16),
#  (402, 'CARMO DO PARANAÍBA', 16),
#  (403, 'CARMO DO RIO CLARO', 16),
#  (404, 'CARMÓPOLIS DE MINAS', 16),
#  (405, 'CARNEIRINHO', 16),
#  (406, 'CARRANCAS', 16),
#  (407, 'CARVALHÓPOLIS', 16),
#  (408, 'CARVALHOS', 16),
#  (409, 'CASA GRANDE', 16),
#  (410, 'CASCALHO RICO', 16),
#  (411, 'CÁSSIA', 16),
#  (412, 'CATAGUASES', 16),
#  (413, 'CATAS ALTAS', 16),
#  (414, 'CATAS ALTAS DA NORUEGA', 16),
#  (415, 'CATUJI', 16),
#  (416, 'CATUTI', 16),
#  (417, 'CAXAMBU', 16),
#  (418, 'CEDRO DO ABAETÉ', 16),
#  (419, 'CENTRAL DE MINAS', 16),
#  (420, 'CENTRALINA', 16),
#  (421, 'CHÁCARA', 16),
#  (422, 'CHALÉ', 16),
#  (423, 'CHAPADA DO NORTE', 16),
#  (424, 'CHAPADA GAÚCHA', 16),
#  (425, 'CHIADOR', 16),
#  (426, 'CIPOTÂNEA', 16),
#  (427, 'CLARAVAL', 16),
#  (428, 'CLARO DOS POÇÕES', 16),
#  (429, 'CLÁUDIO', 16),
#  (430, 'COIMBRA', 16),
#  (431, 'COLUNA', 16),
#  (432, 'COMENDADOR GOMES', 16),
#  (433, 'COMERCINHO', 16),
#  (434, 'CONCEIÇÃO DA APARECIDA', 16),
#  (435, 'CONCEIÇÃO DA BARRA DE MINAS', 16),
#  (436, 'CONCEIÇÃO DAS ALAGOAS', 16),
#  (437, 'CONCEIÇÃO DAS PEDRAS', 16),
#  (438, 'CONCEIÇÃO DE IPANEMA', 16),
#  (439, 'CONCEIÇÃO DO MATO DENTRO', 16),
#  (440, 'CONCEIÇÃO DO PARÁ', 16),
#  (441, 'CONCEIÇÃO DO RIO VERDE', 16),
#  (442, 'CONCEIÇÃO DOS OUROS', 16),
#  (443, 'CÔNEGO MARINHO', 16),
#  (444, 'CONFINS', 16),
#  (445, 'CONGONHAL', 16),
#  (446, 'CONGONHAS', 16),
#  (447, 'CONGONHAS DO NORTE', 16),
#  (448, 'CONQUISTA', 16),
#  (449, 'CONSELHEIRO LAFAIETE', 16),
#  (450, 'CONSELHEIRO PENA', 16),
#  (451, 'CONSOLAÇÃO', 16),
#  (452, 'CONTAGEM', 16),
#  (453, 'COQUEIRAL', 16),
#  (454, 'CORAÇÃO DE JESUS', 16),
#  (455, 'CORDISBURGO', 16),
#  (456, 'CORDISLÂNDIA', 16),
#  (457, 'CORINTO', 16),
#  (458, 'COROACI', 16),
#  (459, 'COROMANDEL', 16),
#  (460, 'CORONEL FABRICIANO', 16),
#  (461, 'CORONEL MURTA', 16),
#  (462, 'CORONEL PACHECO', 16),
#  (463, 'CORONEL XAVIER CHAVES', 16),
#  (464, 'CÓRREGO DANTA', 16),
#  (465, 'CÓRREGO DO BOM JESUS', 16),
#  (466, 'CÓRREGO FUNDO', 16),
#  (467, 'CÓRREGO NOVO', 16),
#  (468, 'COUTO DE MAGALHÃES DE MINAS', 16),
#  (469, 'CRISÓLITA', 16),
#  (470, 'CRISTAIS', 16),
#  (471, 'CRISTÁLIA', 16),
#  (472, 'CRISTIANO OTONI', 16),
#  (473, 'CRISTINA', 16),
#  (474, 'CRUCILÂNDIA', 16),
#  (475, 'CRUZEIRO DA FORTALEZA', 16),
#  (476, 'CRUZÍLIA', 16),
#  (477, 'CUPARAQUE', 16),
#  (478, 'CURRAL DE DENTRO', 16),
#  (479, 'CURVELO', 16),
#  (480, 'DATAS', 16),
#  (481, 'DELFIM MOREIRA', 16),
#  (482, 'DELFINÓPOLIS', 16),
#  (483, 'DELTA', 16),
#  (484, 'DESCOBERTO', 16),
#  (485, 'DESTERRO DE ENTRE RIOS', 16),
#  (486, 'DESTERRO DO MELO', 16),
#  (487, 'DIAMANTINA', 16),
#  (488, 'DIOGO DE VASCONCELOS', 16),
#  (489, 'DIONÍSIO', 16),
#  (490, 'DIVINÉSIA', 16),
#  (491, 'DIVINO', 16),
#  (492, 'DIVINO DAS LARANJEIRAS', 16),
#  (493, 'DIVINOLÂNDIA DE MINAS', 16),
#  (494, 'DIVINÓPOLIS', 16),
#  (495, 'DIVISA ALEGRE', 16),
#  (496, 'DIVISA NOVA', 16),
#  (497, 'DIVISÓPOLIS', 16),
#  (498, 'DOM BOSCO', 16),
#  (499, 'DOM CAVATI', 16),
#  (500, 'DOM JOAQUIM', 16),
#  (501, 'DOM SILVÉRIO', 16),
#  (502, 'DOM VIÇOSO', 16),
#  (503, 'DONA EUSÉBIA', 16),
#  (504, 'DORES DE CAMPOS', 16),
#  (505, 'DORES DE GUANHÃES', 16),
#  (506, 'DORES DO INDAIÁ', 16),
#  (507, 'DORES DO TURVO', 16),
#  (508, 'DORESÓPOLIS', 16),
#  (509, 'DOURADOQUARA', 16),
#  (510, 'DURANDÉ', 16),
#  (511, 'ELÓI MENDES', 16),
#  (512, 'ENGENHEIRO CALDAS', 16),
#  (513, 'ENGENHEIRO NAVARRO', 16),
#  (514, 'ENTRE FOLHAS', 16),
#  (515, 'ENTRE RIOS DE MINAS', 16),
#  (516, 'ERVÁLIA', 16),
#  (517, 'ESMERALDAS', 16),
#  (518, 'ESPERA FELIZ', 16),
#  (519, 'ESPINOSA', 16),
#  (520, 'ESPÍRITO SANTO DO DOURADO', 16),
#  (521, 'ESTIVA', 16),
#  (522, 'ESTRELA DALVA', 16),
#  (523, 'ESTRELA DO INDAIÁ', 16),
#  (524, 'ESTRELA DO SUL', 16),
#  (525, 'EUGENÓPOLIS', 16),
#  (526, 'EWBANK DA CÂMARA', 16),
#  (527, 'EXTREMA', 16),
#  (528, 'FAMA', 16),
#  (529, 'FARIA LEMOS', 16),
#  (530, 'FELÍCIO DOS SANTOS', 16),
#  (531, 'FELISBURGO', 16),
#  (532, 'FELIXLÂNDIA', 16),
#  (533, 'FERNANDES TOURINHO', 16),
#  (534, 'FERROS', 16),
#  (535, 'FERVEDOURO', 16),
#  (536, 'FLORESTAL', 16),
#  (537, 'FORMIGA', 16),
#  (538, 'FORMOSO', 16),
#  (539, 'FORTALEZA DE MINAS', 16),
#  (540, 'FORTUNA DE MINAS', 16),
#  (541, 'FRANCISCO BADARÓ', 16),
#  (542, 'FRANCISCO DUMONT', 16),
#  (543, 'FRANCISCO SÁ', 16),
#  (544, 'FRANCISCÓPOLIS', 16),
#  (545, 'FREI GASPAR', 16),
#  (546, 'FREI INOCÊNCIO', 16),
#  (547, 'FREI LAGONEGRO', 16),
#  (548, 'FRONTEIRA', 16),
#  (549, 'FRONTEIRA DOS VALES', 16),
#  (550, 'FRUTA DE LEITE', 16),
#  (551, 'FRUTAL', 16),
#  (552, 'FUNILÂNDIA', 16),
#  (553, 'GALILÉIA', 16),
#  (554, 'GAMELEIRAS', 16),
#  (555, 'GLAUCILÂNDIA', 16),
#  (556, 'GOIABEIRA', 16),
#  (557, 'GOIANÁ', 16),
#  (558, 'GONÇALVES', 16),
#  (559, 'GONZAGA', 16),
#  (560, 'GOUVEIA', 16),
#  (561, 'GOVERNADOR VALADARES', 16),
#  (562, 'GRÃO MOGOL', 16),
#  (563, 'GRUPIARA', 16),
#  (564, 'GUANHÃES', 16),
#  (565, 'GUAPÉ', 16),
#  (566, 'GUARACIABA', 16),
#  (567, 'GUARACIAMA', 16),
#  (568, 'GUARANÉSIA', 16),
#  (569, 'GUARANI', 16),
#  (570, 'GUARARÁ', 16),
#  (571, 'GUARDA-MOR', 16),
#  (572, 'GUAXUPÉ', 16),
#  (573, 'GUIDOVAL', 16),
#  (574, 'GUIMARÂNIA', 16),
#  (575, 'GUIRICEMA', 16),
#  (576, 'GURINHATÃ', 16),
#  (577, 'HELIODORA', 16),
#  (578, 'IAPU', 16),
#  (579, 'IBERTIOGA', 16),
#  (580, 'IBIÁ', 16),
#  (581, 'IBIAÍ', 16),
#  (582, 'IBIRACATU', 16),
#  (583, 'IBIRACI', 16),
#  (584, 'IBIRITÉ', 16),
#  (585, 'IBITIÚRA DE MINAS', 16),
#  (586, 'IBITURUNA', 16),
#  (587, 'ICARAÍ DE MINAS', 16),
#  (588, 'IGARAPÉ', 16),
#  (589, 'IGARATINGA', 16),
#  (590, 'IGUATAMA', 16),
#  (591, 'IJACI', 16),
#  (592, 'ILICÍNEA', 16),
#  (593, 'IMBÉ DE MINAS', 16),
#  (594, 'INCONFIDENTES', 16),
#  (595, 'INDAIABIRA', 16),
#  (596, 'INDIANÓPOLIS', 16),
#  (597, 'INGAÍ', 16),
#  (598, 'INHAPIM', 16),
#  (599, 'INHAÚMA', 16),
#  (600, 'INIMUTABA', 16),
#  (601, 'IPABA', 16),
#  (602, 'IPANEMA', 16),
#  (603, 'IPATINGA', 16),
#  (604, 'IPIAÇU', 16),
#  (605, 'IPUIÚNA', 16),
#  (606, 'IRAÍ DE MINAS', 16),
#  (607, 'ITABIRA', 16),
#  (608, 'ITABIRINHA', 16),
#  (609, 'ITABIRITO', 16),
#  (610, 'ITACAMBIRA', 16),
#  (611, 'ITACARAMBI', 16),
#  (612, 'ITAGUARA', 16),
#  (613, 'ITAIPÉ', 16),
#  (614, 'ITAJUBÁ', 16),
#  (615, 'ITAMARANDIBA', 16),
#  (616, 'ITAMARATI DE MINAS', 16),
#  (617, 'ITAMBACURI', 16),
#  (618, 'ITAMBÉ DO MATO DENTRO', 16),
#  (619, 'ITAMOGI', 16),
#  (620, 'ITAMONTE', 16),
#  (621, 'ITANHANDU', 16),
#  (622, 'ITANHOMI', 16),
#  (623, 'ITAOBIM', 16),
#  (624, 'ITAPAGIPE', 16),
#  (625, 'ITAPECERICA', 16),
#  (626, 'ITAPEVA', 16),
#  (627, 'ITATIAIUÇU', 16),
#  (628, 'ITAÚ DE MINAS', 16),
#  (629, 'ITAÚNA', 16),
#  (630, 'ITAVERAVA', 16),
#  (631, 'ITINGA', 16),
#  (632, 'ITUETA', 16),
#  (633, 'ITUIUTABA', 16),
#  (634, 'ITUMIRIM', 16),
#  (635, 'ITURAMA', 16),
#  (636, 'ITUTINGA', 16),
#  (637, 'JABOTICATUBAS', 16),
#  (638, 'JACINTO', 16),
#  (639, 'JACUÍ', 16),
#  (640, 'JACUTINGA', 16),
#  (641, 'JAGUARAÇU', 16),
#  (642, 'JAÍBA', 16),
#  (643, 'JAMPRUCA', 16),
#  (644, 'JANAÚBA', 16),
#  (645, 'JANUÁRIA', 16),
#  (646, 'JAPARAÍBA', 16),
#  (647, 'JAPONVAR', 16),
#  (648, 'JECEABA', 16),
#  (649, 'JENIPAPO DE MINAS', 16),
#  (650, 'JEQUERI', 16),
#  (651, 'JEQUITAÍ', 16),
#  (652, 'JEQUITIBÁ', 16),
#  (653, 'JEQUITINHONHA', 16),
#  (654, 'JESUÂNIA', 16),
#  (655, 'JOAÍMA', 16),
#  (656, 'JOANÉSIA', 16),
#  (657, 'JOÃO MONLEVADE', 16),
#  (658, 'JOÃO PINHEIRO', 16),
#  (659, 'JOAQUIM FELÍCIO', 16),
#  (660, 'JORDÂNIA', 16),
#  (661, 'JOSÉ GONÇALVES DE MINAS', 16),
#  (662, 'JOSÉ RAYDAN', 16),
#  (663, 'JOSENÓPOLIS', 16),
#  (664, 'JUATUBA', 16),
#  (665, 'JUIZ DE FORA', 16),
#  (666, 'JURAMENTO', 16),
#  (667, 'JURUAIA', 16),
#  (668, 'JUVENÍLIA', 16),
#  (669, 'LADAINHA', 16),
#  (670, 'LAGAMAR', 16),
#  (671, 'LAGOA DA PRATA', 16),
#  (672, 'LAGOA DOS PATOS', 16),
#  (673, 'LAGOA DOURADA', 16),
#  (674, 'LAGOA FORMOSA', 16),
#  (675, 'LAGOA GRANDE', 16),
#  (676, 'LAGOA SANTA', 16),
#  (677, 'LAJINHA', 16),
#  (678, 'LAMBARI', 16),
#  (679, 'LAMIM', 16),
#  (680, 'LARANJAL', 16),
#  (681, 'LASSANCE', 16),
#  (682, 'LAVRAS', 16),
#  (683, 'LEANDRO FERREIRA', 16),
#  (684, 'LEME DO PRADO', 16),
#  (685, 'LEOPOLDINA', 16),
#  (686, 'LIBERDADE', 16),
#  (687, 'LIMA DUARTE', 16),
#  (688, 'LIMEIRA DO OESTE', 16),
#  (689, 'LONTRA', 16),
#  (690, 'LUISBURGO', 16),
#  (691, 'LUISLÂNDIA', 16),
#  (692, 'LUMINÁRIAS', 16),
#  (693, 'LUZ', 16),
#  (694, 'MACHACALIS', 16),
#  (695, 'MACHADO', 16),
#  (696, 'MADRE DE DEUS DE MINAS', 16),
#  (697, 'MALACACHETA', 16),
#  (698, 'MAMONAS', 16),
#  (699, 'MANGA', 16),
#  (700, 'MANHUAÇU', 16),
#  (701, 'MANHUMIRIM', 16),
#  (702, 'MANTENA', 16),
#  (703, 'MAR DE ESPANHA', 16),
#  (704, 'MARAVILHAS', 16),
#  (705, 'MARIA DA FÉ', 16),
#  (706, 'MARIANA', 16),
#  (707, 'MARILAC', 16),
#  (708, 'MÁRIO CAMPOS', 16),
#  (709, 'MARIPÁ DE MINAS', 16),
#  (710, 'MARLIÉRIA', 16),
#  (711, 'MARMELÓPOLIS', 16),
#  (712, 'MARTINHO CAMPOS', 16),
#  (713, 'MARTINS SOARES', 16),
#  (714, 'MATA VERDE', 16),
#  (715, 'MATERLÂNDIA', 16),
#  (716, 'MATEUS LEME', 16),
#  (717, 'MATHIAS LOBATO', 16),
#  (718, 'MATIAS BARBOSA', 16),
#  (719, 'MATIAS CARDOSO', 16),
#  (720, 'MATIPÓ', 16),
#  (721, 'MATO VERDE', 16),
#  (722, 'MATOZINHOS', 16),
#  (723, 'MATUTINA', 16),
#  (724, 'MEDEIROS', 16),
#  (725, 'MEDINA', 16),
#  (726, 'MENDES PIMENTEL', 16),
#  (727, 'MERCÊS', 16),
#  (728, 'MESQUITA', 16),
#  (729, 'MINAS NOVAS', 16),
#  (730, 'MINDURI', 16),
#  (731, 'MIRABELA', 16),
#  (732, 'MIRADOURO', 16),
#  (733, 'MIRAÍ', 16),
#  (734, 'MIRAVÂNIA', 16),
#  (735, 'MOEDA', 16),
#  (736, 'MOEMA', 16),
#  (737, 'MONJOLOS', 16),
#  (738, 'MONSENHOR PAULO', 16),
#  (739, 'MONTALVÂNIA', 16),
#  (740, 'MONTE ALEGRE DE MINAS', 16),
#  (741, 'MONTE AZUL', 16),
#  (742, 'MONTE BELO', 16),
#  (743, 'MONTE CARMELO', 16),
#  (744, 'MONTE FORMOSO', 16),
#  (745, 'MONTE SANTO DE MINAS', 16),
#  (746, 'MONTE SIÃO', 16),
#  (747, 'MONTES CLAROS', 16),
#  (748, 'MONTEZUMA', 16),
#  (749, 'MORADA NOVA DE MINAS', 16),
#  (750, 'MORRO DA GARÇA', 16),
#  (751, 'MORRO DO PILAR', 16),
#  (752, 'MUNHOZ', 16),
#  (753, 'MURIAÉ', 16),
#  (754, 'MUTUM', 16),
#  (755, 'MUZAMBINHO', 16),
#  (756, 'NACIP RAYDAN', 16),
#  (757, 'NANUQUE', 16),
#  (758, 'NAQUE', 16),
#  (759, 'NATALÂNDIA', 16),
#  (760, 'NATÉRCIA', 16),
#  (761, 'NAZARENO', 16),
#  (762, 'NEPOMUCENO', 16),
#  (763, 'NINHEIRA', 16),
#  (764, 'NOVA BELÉM', 16),
#  (765, 'NOVA ERA', 16),
#  (766, 'NOVA LIMA', 16),
#  (767, 'NOVA MÓDICA', 16),
#  (768, 'NOVA PONTE', 16),
#  (769, 'NOVA PORTEIRINHA', 16),
#  (770, 'NOVA RESENDE', 16),
#  (771, 'NOVA SERRANA', 16),
#  (772, 'NOVA UNIÃO', 16),
#  (773, 'NOVO CRUZEIRO', 16),
#  (774, 'NOVO ORIENTE DE MINAS', 16),
#  (775, 'NOVORIZONTE', 16),
#  (776, 'OLARIA', 16),
#  (777, "OLHOS-D'ÁGUA", 16),
#  (778, 'OLÍMPIO NORONHA', 16),
#  (779, 'OLIVEIRA', 16),
#  (780, 'OLIVEIRA FORTES', 16),
#  (781, 'ONÇA DE PITANGUI', 16),
#  (782, 'ORATÓRIOS', 16),
#  (783, 'ORIZÂNIA', 16),
#  (784, 'OURO BRANCO', 16),
#  (785, 'OURO FINO', 16),
#  (786, 'OURO PRETO', 16),
#  (787, 'OURO VERDE DE MINAS', 16),
#  (788, 'PADRE CARVALHO', 16),
#  (789, 'PADRE PARAÍSO', 16),
#  (790, 'PAI PEDRO', 16),
#  (791, 'PAINEIRAS', 16),
#  (792, 'PAINS', 16),
#  (793, 'PAIVA', 16),
#  (794, 'PALMA', 16),
#  (795, 'PALMÓPOLIS', 16),
#  (796, 'PAPAGAIOS', 16),
#  (797, 'PARÁ DE MINAS', 16),
#  (798, 'PARACATU', 16),
#  (799, 'PARAGUAÇU', 16),
#  (800, 'PARAISÓPOLIS', 16),
#  (801, 'PARAOPEBA', 16),
#  (802, 'PASSA QUATRO', 16),
#  (803, 'PASSA TEMPO', 16),
#  (804, 'PASSA VINTE', 16),
#  (805, 'PASSABÉM', 16),
#  (806, 'PASSOS', 16),
#  (807, 'PATIS', 16),
#  (808, 'PATOS DE MINAS', 16),
#  (809, 'PATROCÍNIO', 16),
#  (810, 'PATROCÍNIO DO MURIAÉ', 16),
#  (811, 'PAULA CÂNDIDO', 16),
#  (812, 'PAULISTAS', 16),
#  (813, 'PAVÃO', 16),
#  (814, 'PEÇANHA', 16),
#  (815, 'PEDRA AZUL', 16),
#  (816, 'PEDRA BONITA', 16),
#  (817, 'PEDRA DO ANTA', 16),
#  (818, 'PEDRA DO INDAIÁ', 16),
#  (819, 'PEDRA DOURADA', 16),
#  (820, 'PEDRALVA', 16),
#  (821, 'PEDRAS DE MARIA DA CRUZ', 16),
#  (822, 'PEDRINÓPOLIS', 16),
#  (823, 'PEDRO LEOPOLDO', 16),
#  (824, 'PEDRO TEIXEIRA', 16),
#  (825, 'PEQUERI', 16),
#  (826, 'PEQUI', 16),
#  (827, 'PERDIGÃO', 16),
#  (828, 'PERDIZES', 16),
#  (829, 'PERDÕES', 16),
#  (830, 'PERIQUITO', 16),
#  (831, 'PESCADOR', 16),
#  (832, 'PIAU', 16),
#  (833, 'PIEDADE DE CARATINGA', 16),
#  (834, 'PIEDADE DE PONTE NOVA', 16),
#  (835, 'PIEDADE DO RIO GRANDE', 16),
#  (836, 'PIEDADE DOS GERAIS', 16),
#  (837, 'PIMENTA', 16),
#  (838, "PINGO D'ÁGUA", 16),
#  (839, 'PINTÓPOLIS', 16),
#  (840, 'PIRACEMA', 16),
#  (841, 'PIRAJUBA', 16),
#  (842, 'PIRANGA', 16),
#  (843, 'PIRANGUÇU', 16),
#  (844, 'PIRANGUINHO', 16),
#  (845, 'PIRAPETINGA', 16),
#  (846, 'PIRAPORA', 16),
#  (847, 'PIRAÚBA', 16),
#  (848, 'PITANGUI', 16),
#  (849, 'PIUMHI', 16),
#  (850, 'PLANURA', 16),
#  (851, 'POÇO FUNDO', 16),
#  (852, 'POÇOS DE CALDAS', 16),
#  (853, 'POCRANE', 16),
#  (854, 'POMPÉU', 16),
#  (855, 'PONTE NOVA', 16),
#  (856, 'PONTO CHIQUE', 16),
#  (857, 'PONTO DOS VOLANTES', 16),
#  (858, 'PORTEIRINHA', 16),
#  (859, 'PORTO FIRME', 16),
#  (860, 'POTÉ', 16),
#  (861, 'POUSO ALEGRE', 16),
#  (862, 'POUSO ALTO', 16),
#  (863, 'PRADOS', 16),
#  (864, 'PRATA', 16),
#  (865, 'PRATÁPOLIS', 16),
#  (866, 'PRATINHA', 16),
#  (867, 'PRESIDENTE BERNARDES', 16),
#  (868, 'PRESIDENTE JUSCELINO', 16),
#  (869, 'PRESIDENTE KUBITSCHEK', 16),
#  (870, 'PRESIDENTE OLEGÁRIO', 16),
#  (871, 'PRUDENTE DE MORAIS', 16),
#  (872, 'QUARTEL GERAL', 16),
#  (873, 'QUELUZITO', 16),
#  (874, 'RAPOSOS', 16),
#  (875, 'RAUL SOARES', 16),
#  (876, 'RECREIO', 16),
#  (877, 'REDUTO', 16),
#  (878, 'RESENDE COSTA', 16),
#  (879, 'RESPLENDOR', 16),
#  (880, 'RESSAQUINHA', 16),
#  (881, 'RIACHINHO', 16),
#  (882, 'RIACHO DOS MACHADOS', 16),
#  (883, 'RIBEIRÃO DAS NEVES', 16),
#  (884, 'RIBEIRÃO VERMELHO', 16),
#  (885, 'RIO ACIMA', 16),
#  (886, 'RIO CASCA', 16),
#  (887, 'RIO DO PRADO', 16),
#  (888, 'RIO DOCE', 16),
#  (889, 'RIO ESPERA', 16),
#  (890, 'RIO MANSO', 16),
#  (891, 'RIO NOVO', 16),
#  (892, 'RIO PARANAÍBA', 16),
#  (893, 'RIO PARDO DE MINAS', 16),
#  (894, 'RIO PIRACICABA', 16),
#  (895, 'RIO POMBA', 16),
#  (896, 'RIO PRETO', 16),
#  (897, 'RIO VERMELHO', 16),
#  (898, 'RITÁPOLIS', 16),
#  (899, 'ROCHEDO DE MINAS', 16),
#  (900, 'RODEIRO', 16),
#  (901, 'ROMARIA', 16),
#  (902, 'ROSÁRIO DA LIMEIRA', 16),
#  (903, 'RUBELITA', 16),
#  (904, 'RUBIM', 16),
#  (905, 'SABARÁ', 16),
#  (906, 'SABINÓPOLIS', 16),
#  (907, 'SACRAMENTO', 16),
#  (908, 'SALINAS', 16),
#  (909, 'SALTO DA DIVISA', 16),
#  (910, 'SANTA BÁRBARA', 16),
#  (911, 'SANTA BÁRBARA DO LESTE', 16),
#  (912, 'SANTA BÁRBARA DO MONTE VERDE', 16),
#  (913, 'SANTA BÁRBARA DO TUGÚRIO', 16),
#  (914, 'SANTA CRUZ DE MINAS', 16),
#  (915, 'SANTA CRUZ DE SALINAS', 16),
#  (916, 'SANTA CRUZ DO ESCALVADO', 16),
#  (917, 'SANTA EFIGÊNIA DE MINAS', 16),
#  (918, 'SANTA FÉ DE MINAS', 16),
#  (919, 'SANTA HELENA DE MINAS', 16),
#  (920, 'SANTA JULIANA', 16),
#  (921, 'SANTA LUZIA', 16),
#  (922, 'SANTA MARGARIDA', 16),
#  (923, 'SANTA MARIA DE ITABIRA', 16),
#  (924, 'SANTA MARIA DO SALTO', 16),
#  (925, 'SANTA MARIA DO SUAÇUÍ', 16),
#  (926, 'SANTA RITA DE CALDAS', 16),
#  (927, 'SANTA RITA DE IBITIPOCA', 16),
#  (928, 'SANTA RITA DE JACUTINGA', 16),
#  (929, 'SANTA RITA DE MINAS', 16),
#  (930, 'SANTA RITA DO ITUETO', 16),
#  (931, 'SANTA RITA DO SAPUCAÍ', 16),
#  (932, 'SANTA ROSA DA SERRA', 16),
#  (933, 'SANTA VITÓRIA', 16),
#  (934, 'SANTANA DA VARGEM', 16),
#  (935, 'SANTANA DE CATAGUASES', 16),
#  (936, 'SANTANA DE PIRAPAMA', 16),
#  (937, 'SANTANA DO DESERTO', 16),
#  (938, 'SANTANA DO GARAMBÉU', 16),
#  (939, 'SANTANA DO JACARÉ', 16),
#  (940, 'SANTANA DO MANHUAÇU', 16),
#  (941, 'SANTANA DO PARAÍSO', 16),
#  (942, 'SANTANA DO RIACHO', 16),
#  (943, 'SANTANA DOS MONTES', 16),
#  (944, 'SANTO ANTÔNIO DO AMPARO', 16),
#  (945, 'SANTO ANTÔNIO DO AVENTUREIRO', 16),
#  (946, 'SANTO ANTÔNIO DO GRAMA', 16),
#  (947, 'SANTO ANTÔNIO DO ITAMBÉ', 16),
#  (948, 'SANTO ANTÔNIO DO JACINTO', 16),
#  (949, 'SANTO ANTÔNIO DO MONTE', 16),
#  (950, 'SANTO ANTÔNIO DO RETIRO', 16),
#  (951, 'SANTO ANTÔNIO DO RIO ABAIXO', 16),
#  (952, 'SANTO HIPÓLITO', 16),
#  (953, 'SANTOS DUMONT', 16),
#  (954, 'SÃO BENTO ABADE', 16),
#  (955, 'SÃO BRÁS DO SUAÇUÍ', 16),
#  (956, 'SÃO DOMINGOS DAS DORES', 16),
#  (957, 'SÃO DOMINGOS DO PRATA', 16),
#  (958, 'SÃO FÉLIX DE MINAS', 16),
#  (959, 'SÃO FRANCISCO', 16),
#  (960, 'SÃO FRANCISCO DE PAULA', 16),
#  (961, 'SÃO FRANCISCO DE SALES', 16),
#  (962, 'SÃO FRANCISCO DO GLÓRIA', 16),
#  (963, 'SÃO GERALDO', 16),
#  (964, 'SÃO GERALDO DA PIEDADE', 16),
#  (965, 'SÃO GERALDO DO BAIXIO', 16),
#  (966, 'SÃO GONÇALO DO ABAETÉ', 16),
#  (967, 'SÃO GONÇALO DO PARÁ', 16),
#  (968, 'SÃO GONÇALO DO RIO ABAIXO', 16),
#  (969, 'SÃO GONÇALO DO RIO PRETO', 16),
#  (970, 'SÃO GONÇALO DO SAPUCAÍ', 16),
#  (971, 'SÃO GOTARDO', 16),
#  (972, 'SÃO JOÃO BATISTA DO GLÓRIA', 16),
#  (973, 'SÃO JOÃO DA LAGOA', 16),
#  (974, 'SÃO JOÃO DA MATA', 16),
#  (975, 'SÃO JOÃO DA PONTE', 16),
#  (976, 'SÃO JOÃO DAS MISSÕES', 16),
#  (977, 'SÃO JOÃO DEL REI', 16),
#  (978, 'SÃO JOÃO DO MANHUAÇU', 16),
#  (979, 'SÃO JOÃO DO MANTENINHA', 16),
#  (980, 'SÃO JOÃO DO ORIENTE', 16),
#  (981, 'SÃO JOÃO DO PACUÍ', 16),
#  (982, 'SÃO JOÃO DO PARAÍSO', 16),
#  (983, 'SÃO JOÃO EVANGELISTA', 16),
#  (984, 'SÃO JOÃO NEPOMUCENO', 16),
#  (985, 'SÃO JOAQUIM DE BICAS', 16),
#  (986, 'SÃO JOSÉ DA BARRA', 16),
#  (987, 'SÃO JOSÉ DA LAPA', 16),
#  (988, 'SÃO JOSÉ DA SAFIRA', 16),
#  (989, 'SÃO JOSÉ DA VARGINHA', 16),
#  (990, 'SÃO JOSÉ DO ALEGRE', 16),
#  (991, 'SÃO JOSÉ DO DIVINO', 16),
#  (992, 'SÃO JOSÉ DO GOIABAL', 16),
#  (993, 'SÃO JOSÉ DO JACURI', 16),
#  (994, 'SÃO JOSÉ DO MANTIMENTO', 16),
#  (995, 'SÃO LOURENÇO', 16),
#  (996, 'SÃO MIGUEL DO ANTA', 16),
#  (997, 'SÃO PEDRO DA UNIÃO', 16),
#  (998, 'SÃO PEDRO DO SUAÇUÍ', 16),
#  (999, 'SÃO PEDRO DOS FERROS', 16),
#  (1000, 'SÃO ROMÃO', 16),
#  ...]

# %%
##############################################################################################
#
# NÃO É NECESSÁRIO EXECUTAR ESSA CÉLULA, POIS O INSERT LINHA A LINHA DESSA É DEMORADO
#
# ESTA AQUI APENAS PARA EXPERIÊNCIA DIDÁTICA
#
##############################################################################################

# Processo incluindo linha a linha - é bem demorado (15 min = 5.000)
postgres_insert_query = """ INSERT INTO tb_cidade (id_cidade, nome_cidade, id_estado) VALUES (DEFAULT,%s,%s)"""
cur.execute('truncate table tb_cidade restart identity')  
insert_rows(df_cidade[['Cidade', 'id_estado']], postgres_insert_query)
