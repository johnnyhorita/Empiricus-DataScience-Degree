# %% [markdown]
# # Módulo de estatística
#
# ## Projeto A - Análise do dataset "Wine Quality"

# %% [markdown]
# ### Grupo
#
# Diego Felipe Alves  Batista
#
# Johnny Hideki Horita
#
# Lucas Rodrigues Cruz
#
# Thalita Regina Gomes de Sa
#
# Vitor Rosa Castro dos Santos

# %% [markdown]
# ### Instruções

# %% [markdown]
# - O projeto deverá ser entregue até dia 22/11 antes do início da aula
# - O projeto poderá ser feito em grupo com até 4 integrantes
# - Serão 2 projetos A e B porém apenas 1 projeto deverá ser entregue e escolhido pelo grupo
#
# - A entrega deve ser feita em jupyter notebook com os códigos explícitos e comentados. Além disso os conceitos, decisões e conclusões usadas devem estar destacadas no notebook

# %% [markdown]
# ### Informações sobre o projeto

# %% [markdown]
# Dataset (conjunto de dados a ser utilizado) está disponível em:
#     https://archive.ics.uci.edu/ml/datasets/Wine+Quality

# %% [markdown]
# Data Set Information:
#
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: [Web Link] or the reference [Cortez et al., 2009]. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
#
# Attribute Information:
#
# Input variables (based on physicochemical tests): <br>
# - 1 - fixed acidity
# - 2 - volatile acidity
# - 3 - citric acid
# - 4 - residual sugar
# - 5 - chlorides
# - 6 - free sulfur dioxide
# - 7 - total sulfur dioxide
# - 8 - density
# - 9 - pH
# - 10 - sulphates
# - 11 - alcohol
#
# Output variable (based on sensory data): <br>
# - 12 - quality (score between 0 and 10)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Etapa 1
#
# **EDA - Análise exploratória de dados**
#
# - Análise das medidas de medidas de posição, dispersão, correlação (análises univaridas e bivariadas) - histograma, boxplot, mapa de calor, etc...
# - Exclusão de outliers, caso necessário (sempre explicando a opção)
#
#
#
# ### Etapa 2
#
# **Regressão Linear**
#
# - Faça um algoritmo que estime a variável “Quality” em função das características físico-químicas dos vinhos
# - Colocar comentários sobre a técnica utilizada e análise sobre as variáveis utilizadas, além dos seus respectivos “achados”. Faça uma interpretação do resultado
#
# ### Etapa 3
#
# **Regressão logística**
#
# - Sabendo que os vinhos com notas >= 6 são considerados vinhos de boa qualidade faça um algoritmo que classifique os vinhos em “Bom” ou “Ruim” em função de suas características físico-químicas;
# - Colocar comentários sobre a técnica utilizada e análise sobre as variáveis utilizadas, além dos seus respectivos “achados”. Faça uma interpretação do resultado

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
from collections import Counter
import warnings

# %%
#Padronizações

sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)          # controls default text sizes
colors = sns.color_palette('pastel')

#sns.color_palette('deep') # deep, pastel, Set1 Set2 Set3

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Etapa 1
#
# **AED - Análise exploratória de dados**

# %% [markdown]
# ### Carregando dataset

# %%
# Carrega os arquivos nos dataframes (arquivos gravados na máquina local)
# Lista o dataset no repositório local
data_folder = ".\\Dataset\\Projeto-A\\"
# !dir /ON /b /a-d $data_folder

# Arquivo de vinhos tintos
#file_r = 'winequality-red.csv'
#df_r = pd.read_csv(data_folder + file_r, sep=";")

# Arquivo de vinhos brancos
#file_w = 'winequality-white.csv'
#df_w = pd.read_csv(data_folder + file_w, sep=";")
# Out:
# winequality.names
# winequality-red.csv
# winequality-white.csv

# %%
# Carrega os arquivos nos dataframes (arquivos da internet)
# Arquivo de vinhos tintos
url_wine = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'
file_r = 'winequality-red.csv'
df_r = pd.read_csv(url_wine + file_r, sep=';', encoding='utf8')

# Arquivo de vinhos brancos
file_w = 'winequality-white.csv'
df_w = pd.read_csv(url_wine + file_w, sep=';', encoding='utf8')

# %% [markdown]
# #### winequality-red.csv

# %%
# Verificando o tamanho do dataframe (Linhas x Colunas)
lin, col = df_r.shape
print(f'Informações do arquivo: {file_r}')
print(f'Linhas.: {lin}\nColunas: {col}')
# Out:
# Informações do arquivo: winequality-red.csv
# Linhas.: 1599
# Colunas: 12

# %%
# Visualizando os primeiros registros do dataframe
df_r.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Obtendo as informações de colunas e tipo das colunas do dataframe
df_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Obtendo informações gerais dos valores que cada coluna numérica contém
df_r.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# Cria novo dataframe
# Seleciona todas as linhas duplicadas no dataframe baseado em todas as colunas
df_r_duplicateRows = df_r[df_r.duplicated(keep=False)].copy()
print("Todas as linhas duplicadas:")
print(df_r_duplicateRows.shape)
# Out:
# Todas as linhas duplicadas:
# (460, 12)

# %%
# Lista o Dataframe com as linhas duplicadas
df_r_duplicateRows.sort_values(by=list(df_r.columns))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 142             5.2             0.340         0.00             1.8      0.050
# 144             5.2             0.340         0.00             1.8      0.050
# 131             5.6             0.500         0.09             2.3      0.049
# 132             5.6             0.500         0.09             2.3      0.049
# 1488            5.6             0.540         0.04             1.7      0.049
# ...             ...               ...          ...             ...        ...
# 391            13.7             0.415         0.68             2.9      0.085
# 243            15.0             0.210         0.44             2.2      0.075
# 244            15.0             0.210         0.44             2.2      0.075
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 142                  27.0                  63.0  0.99160  3.68       0.79
# 144                  27.0                  63.0  0.99160  3.68       0.79
# 131                  17.0                  99.0  0.99370  3.63       0.63
# 132                  17.0                  99.0  0.99370  3.63       0.63
# 1488                  5.0                  13.0  0.99420  3.72       0.58
# ...                   ...                   ...      ...   ...        ...
# 391                  17.0                  43.0  1.00140  3.06       0.80
# 243                  10.0                  24.0  1.00005  3.07       0.84
# 244                  10.0                  24.0  1.00005  3.07       0.84
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
#
#       alcohol  quality
# 142      14.0        6
# 144      14.0        6
# 131      13.0        5
# 132      13.0        5
# 1488     11.4        5
# ...       ...      ...
# 391      10.0        6
# 243       9.2        7
# 244       9.2        7
# 554      11.1        5
# 555      11.1        5
#
# [460 rows x 12 columns]

# %%
# Dataframe sem as linhas duplicadas mantendo a primeira ocorrência do registro
df_r_clean = df_r_duplicateRows[df_r_duplicateRows.duplicated(keep='first')].copy()
print("Dataframe sem duplicidade:")
print(df_r_clean.shape)
# Out:
# Dataset sem linhas duplicadas:
# (240, 12)

# %%
df_r_clean.reset_index(drop=True)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00            1.90      0.076
# 1              7.5             0.500         0.36            6.10      0.071
# 2              7.9             0.430         0.21            1.60      0.106
# 3              7.3             0.450         0.36            5.90      0.074
# 4              7.2             0.725         0.05            4.65      0.086
# ..             ...               ...          ...             ...        ...
# 235            7.2             0.695         0.13            2.00      0.076
# 236            7.2             0.695         0.13            2.00      0.076
# 237            7.2             0.695         0.13            2.00      0.076
# 238            6.2             0.560         0.09            1.70      0.053
# 239            6.3             0.510         0.13            2.30      0.076
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11.0                  34.0  0.99780  3.51       0.56
# 1                   17.0                 102.0  0.99780  3.35       0.80
# 2                   10.0                  37.0  0.99660  3.17       0.91
# 3                   12.0                  87.0  0.99780  3.33       0.83
# 4                    4.0                  11.0  0.99620  3.41       0.39
# ..                   ...                   ...      ...   ...        ...
# 235                 12.0                  20.0  0.99546  3.29       0.54
# 236                 12.0                  20.0  0.99546  3.29       0.54
# 237                 12.0                  20.0  0.99546  3.29       0.54
# 238                 24.0                  32.0  0.99402  3.54       0.60
# 239                 29.0                  40.0  0.99574  3.42       0.75
#
#      alcohol  quality
# 0        9.4        5
# 1       10.5        5
# 2        9.5        5
# 3       10.5        5
# 4       10.9        5
# ..       ...      ...
# 235     10.1        5
# 236     10.1        5
# 237     10.1        5
# 238     11.3        5
# 239     11.0        6
#
# [240 rows x 12 columns]

# %%
# Obtendo informações gerais dos valores que cada coluna numérica contém
df_r_clean.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     240.000000        240.000000   240.000000      240.000000
# mean        8.370833          0.518437     0.263292        2.626042
# std         1.766963          0.154665     0.190802        1.700436
# min         5.200000          0.120000     0.000000        0.900000
# 25%         7.200000          0.410000     0.090000        1.900000
# 50%         7.900000          0.525000     0.250000        2.200000
# 75%         9.300000          0.630000     0.410000        2.500000
# max        15.500000          1.000000     0.740000       15.400000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  240.000000           240.000000            240.000000  240.000000
# mean     0.083746            15.770833             44.439583    0.996960
# std      0.030681            10.554183             29.803813    0.001979
# min      0.012000             1.000000              6.000000    0.990070
# 25%      0.073000             8.000000             22.750000    0.995720
# 50%      0.080000            13.000000             37.000000    0.996900
# 75%      0.089000            21.000000             58.250000    0.998007
# max      0.415000            68.000000            147.000000    1.003690
#
#                pH   sulphates     alcohol     quality
# count  240.000000  240.000000  240.000000  240.000000
# mean     3.318625    0.655000   10.370139    5.708333
# std      0.150751    0.163092    0.967982    0.707353
# min      2.890000    0.390000    8.800000    5.000000
# 25%      3.210000    0.550000    9.500000    5.000000
# 50%      3.320000    0.625000   10.150000    6.000000
# 75%      3.402500    0.740000   11.000000    6.000000
# max      3.720000    1.950000   14.000000    8.000000

# %% [markdown]
# #### winequality-white.csv

# %%
# Verificando o tamanho do dataframe (Linhas x Colunas)
lin, col = df_w.shape
print(f'Informações do arquivo: {file_w}')
print(f'Linhas.: {lin}\nColunas: {col}')
# Out:
# Informações do arquivo: winequality-white.csv
# Linhas.: 4898
# Colunas: 12

# %%
# Visualizando os primeiros registros do dataframe
df_w.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
# Obtendo as informações de colunas e tipo das colunas do dataframe
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# Obtendo informações gerais dos valores que cada coluna numérica contém
df_w.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
# Cria novo dataframe
# Seleciona todas as linhas duplicadas no dataframe baseado em todas as colunas
df_w_duplicateRows = df_w[df_w.duplicated(keep=False)].copy()
print("Todas as linhas duplicadas:")
print(df_w_duplicateRows.shape)
# Out:
# Todas as linhas duplicadas:
# (1709, 12)

# %%
# Lista o Dataframe com as linhas duplicadas
df_w_duplicateRows.sort_values(by=list(df_w.columns))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4671            4.9             0.335         0.14             1.3      0.036
# 4672            4.9             0.335         0.14             1.3      0.036
# 3941            4.9             0.345         0.34             1.0      0.068
# 3950            4.9             0.345         0.34             1.0      0.068
# 2990            5.0             0.270         0.32             4.5      0.032
# ...             ...               ...          ...             ...        ...
# 2312            9.4             0.280         0.30             1.6      0.045
# 3094            9.7             0.240         0.49             4.9      0.032
# 3095            9.7             0.240         0.49             4.9      0.032
# 1372           10.7             0.220         0.56             8.2      0.044
# 1373           10.7             0.220         0.56             8.2      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4671                 69.0                 168.0  0.99212  3.47       0.46
# 4672                 69.0                 168.0  0.99212  3.47       0.46
# 3941                 32.0                 143.0  0.99138  3.24       0.40
# 3950                 32.0                 143.0  0.99138  3.24       0.40
# 2990                 58.0                 178.0  0.98956  3.45       0.31
# ...                   ...                   ...      ...   ...        ...
# 2312                 36.0                 139.0  0.99534  3.11       0.49
# 3094                  3.0                  18.0  0.99368  2.85       0.54
# 3095                  3.0                  18.0  0.99368  2.85       0.54
# 1372                 37.0                 181.0  0.99800  2.87       0.68
# 1373                 37.0                 181.0  0.99800  2.87       0.68
#
#         alcohol  quality
# 4671  10.466667        5
# 4672  10.466667        5
# 3941  10.100000        5
# 3950  10.100000        5
# 2990  12.600000        7
# ...         ...      ...
# 2312   9.300000        5
# 3094  10.000000        6
# 3095  10.000000        6
# 1372   9.500000        6
# 1373   9.500000        6
#
# [1709 rows x 12 columns]

# %%
# Dataframe sem as linhas duplicadas mantendo a primeira ocorrência do registro
df_w_clean = df_w_duplicateRows[df_w_duplicateRows.duplicated(keep='first')].copy()
print("Dataframe sem duplicidade:")
print(df_w_clean.shape)
# Out:
# Dataset sem linhas duplicadas:
# (937, 12)

# %%
df_w_clean.reset_index(drop=True)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.2              0.23         0.32             8.5      0.058
# 1              8.1              0.28         0.40             6.9      0.050
# 2              7.0              0.27         0.36            20.7      0.045
# 3              6.3              0.30         0.34             1.6      0.049
# 4              6.2              0.66         0.48             1.2      0.029
# ..             ...               ...          ...             ...        ...
# 932            6.4              0.23         0.35            10.3      0.042
# 933            7.0              0.36         0.35             2.5      0.048
# 934            6.4              0.33         0.44             8.9      0.055
# 935            7.1              0.23         0.39            13.7      0.058
# 936            6.6              0.34         0.40             8.1      0.046
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   47.0                 186.0  0.99560  3.19       0.40
# 1                   30.0                  97.0  0.99510  3.26       0.44
# 2                   45.0                 170.0  1.00100  3.00       0.45
# 3                   14.0                 132.0  0.99400  3.30       0.49
# 4                   29.0                  75.0  0.98920  3.33       0.39
# ..                   ...                   ...      ...   ...        ...
# 932                 54.0                 140.0  0.99670  3.23       0.47
# 933                 67.0                 161.0  0.99146  3.05       0.56
# 934                 52.0                 164.0  0.99488  3.10       0.48
# 935                 26.0                 172.0  0.99755  2.90       0.46
# 936                 68.0                 170.0  0.99494  3.15       0.50
#
#        alcohol  quality
# 0     9.900000        6
# 1    10.100000        6
# 2     8.800000        6
# 3     9.500000        6
# 4    12.800000        8
# ..         ...      ...
# 932   9.200000        5
# 933  11.100000        6
# 934   9.600000        5
# 935   9.000000        6
# 936   9.533333        6
#
# [937 rows x 12 columns]

# %%
# Obtendo informações gerais dos valores que cada coluna numérica contém
df_w_clean.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     937.000000        937.000000   937.000000      937.000000
# mean        6.920064          0.268533     0.333597        8.406137
# std         0.735659          0.088150     0.114856        5.437977
# min         4.900000          0.080000     0.000000        0.600000
# 25%         6.400000          0.200000     0.270000        2.900000
# 50%         6.900000          0.260000     0.310000        8.000000
# 75%         7.400000          0.320000     0.380000       13.100000
# max        10.700000          0.690000     0.910000       31.600000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  937.000000           937.000000            937.000000  937.000000
# mean     0.045211            37.078975            143.294557    0.995033
# std      0.015454            16.009351             39.361011    0.003140
# min      0.015000             3.000000             18.000000    0.987940
# 25%      0.036000            26.000000            115.000000    0.992400
# 50%      0.044000            36.000000            142.000000    0.995300
# 75%      0.051000            47.000000            171.000000    0.997820
# max      0.201000           108.000000            256.000000    1.010300
#
#                pH   sulphates     alcohol     quality
# count  937.000000  937.000000  937.000000  937.000000
# mean     3.157866    0.487716   10.196834    5.975454
# std      0.144858    0.116678    1.237567    0.857618
# min      2.790000    0.260000    8.400000    4.000000
# 25%      3.060000    0.400000    9.200000    5.000000
# 50%      3.150000    0.470000    9.800000    6.000000
# 75%      3.250000    0.540000   11.100000    7.000000
# max      3.720000    0.980000   13.700000    8.000000

# %%
df = df_w_clean.copy()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr

data1 = df['residual sugar']
data2 = df['density']
# summarize
print('data1: mean=%.3f stdv=%.3f' % (data1.mean(), data1.std()))
print('data2: mean=%.3f stdv=%.3f' % (data2.mean(), data2.std()))

# calculate covariance matrix
covariance = np.cov(data1, data2)
print('\nCovariancia:\n', covariance)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('\nPearsons correlation: %.3f' % corr)

# calculate spearman's correlation
corr, _ = spearmanr(data1, data2)
print('\nSpearmans correlation: %.3f' % corr)

# plot
plt.scatter(data1, data2)
plt.show()
# Out:
# data1: mean=8.406 stdv=5.438
# data2: mean=0.995 stdv=0.003
#
# Covariancia:
#  [[2.95715889e+01 1.50597016e-02]
#  [1.50597016e-02 9.85648654e-06]]
#
# Pearsons correlation: 0.882
#
# Spearmans correlation: 0.881

# %%
df['quality'].unique()
# Out:
# array([6, 8, 5, 7, 4], dtype=int64)

# %%
#count of each target variable
Counter(df['quality'])
# Out:
# Counter({6: 410, 8: 44, 5: 282, 7: 191, 4: 10})

# %%
colors = sns.color_palette('Set2')

g = sns.JointGrid(data=df, x="quality")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %%
plt.figure(figsize=(12,3), tight_layout=True)
ax = sns.boxplot(data=df, x="quality", palette=colors)
ax = sns.swarmplot(data=df, x="quality", color=".25")
plt.show()

# %%
# define the size of figures that I will build
plt.figure(figsize=(16,5))

plt.subplot(1,2,1) # this will create a grid of 1 row and 2 columns; this is the first graphic
g = sns.countplot(x='quality', data=df) # seting the seaborn countplot to known the points distribuition
g.set_title("Distribuição dos vinhos pela Qualidade") # seting title and size of font
g.set_xlabel("Qualidade") # seting xlabel and size of font
g.set_ylabel("Quantidade") # seting ylabel and size of font

plt.subplot(1,2,2)  # this will set the second graphic of our grid
plt.scatter(range(df.shape[0]), np.sort(df.quality.values)) # creating a cumulative distribution
plt.title("Distribuição da Qualidade") # seting title and size of font
plt.xlabel('Vinhos')  # seting xlabel and size of font
plt.ylabel('Qualidade')  # seting ylabel and size of font

plt.show()

# %%
total = len(df)
plt.figure(figsize=(14,6))

g = sns.countplot(x='quality',data=df)
g.set_title("Distribuição dos vinhos pela Qualidade")
g.set_xlabel("Qualidade")
g.set_ylabel("Quantidade")

sizes=[]

for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center", fontsize=14) 
    
g.set_ylim(0, max(sizes) * 1.15)

plt.show()

# %%
# Verificando a correlação entre as variáveis
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.031260     0.240303
# volatile acidity          -0.031260          1.000000    -0.078990
# citric acid                0.240303         -0.078990     1.000000
# residual sugar             0.084915         -0.027251     0.058268
# chlorides                  0.020724         -0.048984    -0.002957
# free sulfur dioxide       -0.014114         -0.054579     0.107115
# total sulfur dioxide       0.126086          0.037066     0.114655
# density                    0.254524         -0.080164     0.119216
# pH                        -0.391774          0.016224    -0.078733
# sulphates                 -0.013972         -0.109390     0.119002
# alcohol                   -0.150044          0.139303    -0.077375
# quality                   -0.071610         -0.204333    -0.084788
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.084915   0.020724            -0.014114
# volatile acidity           -0.027251  -0.048984            -0.054579
# citric acid                 0.058268  -0.002957             0.107115
# residual sugar              1.000000   0.198211             0.252164
# chlorides                   0.198211   1.000000             0.113098
# free sulfur dioxide         0.252164   0.113098             1.000000
# total sulfur dioxide        0.360071   0.269449             0.589442
# density                     0.882100   0.345860             0.274179
# pH                         -0.234400  -0.107435             0.062031
# sulphates                  -0.043442   0.010483             0.156575
# alcohol                    -0.587923  -0.440601            -0.221031
# quality                    -0.082942  -0.168162            -0.018378
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.126086  0.254524 -0.391774  -0.013972
# volatile acidity                  0.037066 -0.080164  0.016224  -0.109390
# citric acid                       0.114655  0.119216 -0.078733   0.119002
# residual sugar                    0.360071  0.882100 -0.234400  -0.043442
# chlorides                         0.269449  0.345860 -0.107435   0.010483
# free sulfur dioxide               0.589442  0.274179  0.062031   0.156575
# total sulfur dioxide              1.000000  0.499250  0.006272   0.130455
# density                           0.499250  1.000000 -0.142074   0.057937
# pH                                0.006272 -0.142074  1.000000   0.214135
# sulphates                         0.130455  0.057937  0.214135   1.000000
# alcohol                          -0.445418 -0.838688  0.186674  -0.002007
# quality                          -0.154187 -0.252655  0.020303   0.058802
#
#                        alcohol   quality
# fixed acidity        -0.150044 -0.071610
# volatile acidity      0.139303 -0.204333
# citric acid          -0.077375 -0.084788
# residual sugar       -0.587923 -0.082942
# chlorides            -0.440601 -0.168162
# free sulfur dioxide  -0.221031 -0.018378
# total sulfur dioxide -0.445418 -0.154187
# density              -0.838688 -0.252655
# pH                    0.186674  0.020303
# sulphates            -0.002007  0.058802
# alcohol               1.000000  0.376097
# quality               0.376097  1.000000

# %%
# Verificando a correlação entre as variáveis com heatmap
sns.heatmap(df, fmt='', cmap='Spectral_r', linewidths=0.30, ax=ax)
plt.show()

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 7               7.0              0.27         0.36            20.7      0.045
# 8               6.3              0.30         0.34             1.6      0.049
# 20              6.2              0.66         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 4828            6.4              0.23         0.35            10.3      0.042
# 4850            7.0              0.36         0.35             2.5      0.048
# 4851            6.4              0.33         0.44             8.9      0.055
# 4856            7.1              0.23         0.39            13.7      0.058
# 4880            6.6              0.34         0.40             8.1      0.046
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    47.0                 186.0  0.99560  3.19       0.40
# 5                    30.0                  97.0  0.99510  3.26       0.44
# 7                    45.0                 170.0  1.00100  3.00       0.45
# 8                    14.0                 132.0  0.99400  3.30       0.49
# 20                   29.0                  75.0  0.98920  3.33       0.39
# ...                   ...                   ...      ...   ...        ...
# 4828                 54.0                 140.0  0.99670  3.23       0.47
# 4850                 67.0                 161.0  0.99146  3.05       0.56
# 4851                 52.0                 164.0  0.99488  3.10       0.48
# 4856                 26.0                 172.0  0.99755  2.90       0.46
# 4880                 68.0                 170.0  0.99494  3.15       0.50
#
#         alcohol  quality
# 4      9.900000        6
# 5     10.100000        6
# 7      8.800000        6
# 8      9.500000        6
# 20    12.800000        8
# ...         ...      ...
# 4828   9.200000        5
# 4850  11.100000        6
# 4851   9.600000        5
# 4856   9.000000        6
# 4880   9.533333        6
#
# [937 rows x 12 columns]

# %%
# Verificando a correlação entre as variáveis usando o parplot do Seaborn. 
sns.pairplot(df)
plt.show()

# %%
# Verificando a correlação entre as variáveis usando o PairGrid do Seaborn. 
g = sns.PairGrid(df)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(df)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 9))
# plot heatmap
sns.heatmap(df, cmap="Blues", vmin= 0.9, vmax=1.65,
           linewidth=0.3, cbar_kws={"shrink": .8})
plt.show()

# %%
# figure
fig, ax = plt.subplots(figsize=(11, 9))
# plot heatmap
sns.heatmap(df, cmap="Blues", vmin= 0.9, vmax=1.65, square=True,
           linewidth=0.3, cbar_kws={"shrink": .8})
# xticks
ax.xaxis.tick_top()
xticks_labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(12) + .5, labels=xticks_labels)
# axis labels
plt.xlabel('')
plt.ylabel('')
# title
title = 'monthly Average exchange rate\nValue of one USD in CAD\n'.upper()
plt.title(title, loc='left')
plt.show()

# %%
import sweetviz as sv

# %%
advert_report = sv.analyze([df_r, "Data"])

# %%
advert_report.show_html('eda.html')

# %%
# Analyzing data
report=sv.analyze(df_r)
# Generating report
report.show_html('eda_report.html')
