# %%
# %pwd
# Out:
# 'D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\Untitled Folder'

# %% [markdown]
# http://akul.me/blog/2016/beautifulsoup-cheatsheet/

# %%
import requests

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
url = "https://br.advfn.com/bolsa-de-valores/bovespa/A"
try:
    page = requests.get(url)
    page.raise_for_status()
    response = page.text
    soup = BeautifulSoup(response, 'html.parser')
    
except Exception as err:
    print('Algo deu errado:', err)

# %%
url = "https://br.advfn.com/bolsa-de-valores/bovespa/A"

try:
    response = requests.get(url)
    print (response)
    print("URL is valid and exists on the internet")
except requests.ConnectionError as exception:
    print("URL does not exist on Internet")
# Out:
# <Response [200]>
# URL is valid and exists on the internet

# %%
c = requests.get(url).content
soup = BeautifulSoup(c)

# %%
codacao = soup.find_all(class_="String Column2 ColumnLast")

# %%
nmacao = soup.find_all(class_="String Column1")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html lang="pt-BR" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.USER_COUNTRY = "BR";
# window.USER_STATE = "SP";
# window.USER_FROM_EU = "";
#   </script>
#   <!-- APS_HEADER_START -->
#   <script type="text/javascript">
#    function AdvfnJsQueueLoader(e){this.check=e,this.queue=[],this.id=!1,this.ready=!1;var t=this;this.id=setInterval(function(){t.tick()},50)}AdvfnJsQueueLoader.prototype.processQueue=function(){var e;if(0<this.queue.length)for(e=0;e<this.queue.length;e++)this.queue[e]()},AdvfnJsQueueLoader.prototype.tick=function(){this.check()&&(clearInterval(this.id),this.ready=!0,this.processQueue())},AdvfnJsQueueLoader.prototype.add=function(e){this.ready?e():this.queue.push(e)};
# var jqueryReady=new AdvfnJsQueueLoader(function(){return'function'==typeof $});
#   </script>
# ...

# %%
# criar uma função para buscar info em cada página:

def pagina_ativos(url):
    page = resquests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    acao = []
    codigo = []
    for nome, ticker in zip( soup.find_all(class_='String Column1'), soup.find_all(class_='String Column2 ColumnLast')):
        acao.append(nome.get_text())
        codigo.append(ticker.get_text())
    
    return acao, codigo

# %%
for href in soup.find_all('div', {'class': 'link_list atoz_list'})[0].find_all('a', href=True):
    print('https://br.advfn.com' + href['href'])
# Out:
# https://br.advfn.com/bolsa-de-valores/bovespa/A
# https://br.advfn.com/bolsa-de-valores/bovespa/B
# https://br.advfn.com/bolsa-de-valores/bovespa/C
# https://br.advfn.com/bolsa-de-valores/bovespa/D
# https://br.advfn.com/bolsa-de-valores/bovespa/E
# https://br.advfn.com/bolsa-de-valores/bovespa/F
# https://br.advfn.com/bolsa-de-valores/bovespa/G
# https://br.advfn.com/bolsa-de-valores/bovespa/H
# https://br.advfn.com/bolsa-de-valores/bovespa/I
# https://br.advfn.com/bolsa-de-valores/bovespa/J
# https://br.advfn.com/bolsa-de-valores/bovespa/K
# https://br.advfn.com/bolsa-de-valores/bovespa/L
# https://br.advfn.com/bolsa-de-valores/bovespa/M
# https://br.advfn.com/bolsa-de-valores/bovespa/N
# https://br.advfn.com/bolsa-de-valores/bovespa/O
# https://br.advfn.com/bolsa-de-valores/bovespa/P
# https://br.advfn.com/bolsa-de-valores/bovespa/Q
# https://br.advfn.com/bolsa-de-valores/bovespa/R
# https://br.advfn.com/bolsa-de-valores/bovespa/S
# https://br.advfn.com/bolsa-de-valores/bovespa/T
# ...

# %%
for ultag in soup.find_all('div', {'class': 'link_list atoz_list'}, {'ul'}):
    print(ultag)
    #for litag in ultag.find_all('ul'):
    #    print (litag.text)
# Out:
# <div align="center" class="link_list atoz_list">
# ...

# %%
soup.find_all('div', {'class': 'link_list atoz_list'})
# Out:
# [<div align="center" class="link_list atoz_list">
# ...

# %%
#soup.find_all('div', {'class': 'link_list atoz_list'})
for ultag in soup.find_all('div', {'class': 'link_list atoz_list'}):
    for litag in ultag.find_all('li'):
        print litag.text
# Out:
#   File "<ipython-input-55-e39bb3a15dec>", line 4
#     print litag.text
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(litag.text)?

# %%
> html = """<ul class='my_class'>
... <li>thing one</li>
... <li>thing two</li>
... </ul>"""
>>> from bs4 import BeautifulSoup as BS
>>> soup = BS(html)
>>> for ultag in soup.find_all('div', {'class': 'link_list atoz_list'}):
...     for litag in ultag.find_all('li'):
...             print litag.text

# %%
table

# %%
<ul><li class="odd first"><a href="/bolsa-de-valores/bovespa/A" title="A-Z : A">A</a></li><li class="even selected"><a href="/bolsa-de-valores/bovespa/B" title="A-Z : B">B</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/C" title="A-Z : C">C</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/D" title="A-Z : D">D</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/E" title="A-Z : E">E</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/F" title="A-Z : F">F</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/G" title="A-Z : G">G</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/H" title="A-Z : H">H</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/I" title="A-Z : I">I</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/J" title="A-Z : J">J</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/K" title="A-Z : K">K</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/L" title="A-Z : L">L</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/M" title="A-Z : M">M</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/N" title="A-Z : N">N</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/O" title="A-Z : O">O</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/P" title="A-Z : P">P</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/Q" title="A-Z : Q">Q</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/R" title="A-Z : R">R</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/S" title="A-Z : S">S</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/T" title="A-Z : T">T</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/U" title="A-Z : U">U</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/V" title="A-Z : V">V</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/W" title="A-Z : W">W</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/X" title="A-Z : X">X</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/Y" title="A-Z : Y">Y</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/Z" title="A-Z : Z">Z</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/0" title="A-Z : 0">0</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/1" title="A-Z : 1">1</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/2" title="A-Z : 2">2</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/3" title="A-Z : 3">3</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/4" title="A-Z : 4">4</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/5" title="A-Z : 5">5</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/6" title="A-Z : 6">6</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/7" title="A-Z : 7">7</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/8" title="A-Z : 8">8</a></li><li class="even last"><a href="/bolsa-de-valores/bovespa/9" title="A-Z : 9">9</a></li></ul>


    
table = bs4.find(lambda tag: tag.name=='table' and tag.has_attr('id') and tag['id']=="Table1") 
rows = table.findAll(lambda tag: tag.name=='tr')

soup.find_all(class_="odd first")

#<ul><li class="odd first"><a href="/bolsa-de-valores/bovespa/A" title="A-Z : A">A</a></li><li class="even selected"><a href="/bolsa-de-valores/bovespa/B" title="A-Z : B">B</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/C" title="A-Z : C">C</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/D" title="A-Z : D">D</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/E" title="A-Z : E">E</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/F" title="A-Z : F">F</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/G" title="A-Z : G">G</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/H" title="A-Z : H">H</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/I" title="A-Z : I">I</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/J" title="A-Z : J">J</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/K" title="A-Z : K">K</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/L" title="A-Z : L">L</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/M" title="A-Z : M">M</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/N" title="A-Z : N">N</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/O" title="A-Z : O">O</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/P" title="A-Z : P">P</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/Q" title="A-Z : Q">Q</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/R" title="A-Z : R">R</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/S" title="A-Z : S">S</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/T" title="A-Z : T">T</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/U" title="A-Z : U">U</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/V" title="A-Z : V">V</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/W" title="A-Z : W">W</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/X" title="A-Z : X">X</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/Y" title="A-Z : Y">Y</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/Z" title="A-Z : Z">Z</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/0" title="A-Z : 0">0</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/1" title="A-Z : 1">1</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/2" title="A-Z : 2">2</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/3" title="A-Z : 3">3</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/4" title="A-Z : 4">4</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/5" title="A-Z : 5">5</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/6" title="A-Z : 6">6</a></li><li class="even"><a href="/bolsa-de-valores/bovespa/7" title="A-Z : 7">7</a></li><li class="odd"><a href="/bolsa-de-valores/bovespa/8" title="A-Z : 8">8</a></li><li class="even last"><a href="/bolsa-de-valores/bovespa/9" title="A-Z : 9">9</a></li></ul>
# Out:
# [<li class="odd first"><a href="/forum">Forum</a></li>]
