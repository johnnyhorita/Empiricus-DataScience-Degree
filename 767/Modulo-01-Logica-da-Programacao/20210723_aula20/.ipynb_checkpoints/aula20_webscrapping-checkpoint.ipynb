# %%
#%env

# %%
# %pwd
# Out:
# 'D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\20210723_aula20'

# %%
# Generated by Selenium IDE
#import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

from bs4 import BeautifulSoup

# %%
class TestSearchclick():
  ##def setup_method(self, method):
    def __init__(self):
        # usando chrome
        #self.driver = webdriver.Chrome("D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\20210723_aula20\\chromedriver.exe")
        
        # usando brave
        driver_path = "D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\20210723_aula20\\chromedriver.exe"
        brave_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
        option = webdriver.ChromeOptions()
        option.binary_location = brave_path
        self.driver = webdriver.Chrome(executable_path=driver_path, options=option)
        self.vars = {}
  
    def teardown_method(self):
        self.driver.quit()

    def test_searchclick(self):
        self.driver.get("https://www.google.com/")
        self.driver.set_window_size(1552, 849)
        self.driver.find_element(By.NAME, "q").click()
        self.driver.find_element(By.NAME, "q").send_keys("python")
        self.driver.find_element(By.NAME, "q").send_keys(Keys.ENTER)

# %%
gt = TestSearchclick()
gt.test_searchclick()

# %%
url = gt.driver.page_source

# %%
soup = BeautifulSoup(url, 'html.parser')

# %%
#print(soup.prettify())
# Out:
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="pt-BR">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="Anb2GUnhMjfTIX0D2a4a6NPAqPI5GaxxRAiF81XTjHJ2qK4E3Hw3VFM4eaJBgRzz45CNPt624audv+wHOJwfAAEAAABieyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1N1YmRvbWFpbiI6dHJ1ZX0=" http-equiv="origin-trial"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    python - Pesquisa Google
#   </title>
#   <script async="" nonce="Yu4qx32FDaMO9cREsPdiSw==" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.2cdKFnNWjuc.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo-rZMnae0kdWLu9CWmKEzOTJj_h7w/cb=gapi.loaded_0">
#   </script>
#   <script nonce="Yu4qx32FDaMO9cREsPdiSw==">
# ...

# %%
for el in soup.find_all(class_="LC20lb DKV0Md"):
    print(el.get_text())
# Out:
# Welcome to Python.org
# Python para que serve: top 5 utilidades | Blog | Harve
# Python Brasil 2019
# Como Começar a Programar em Python: 15 Passos - wikiHow
# Instalação do Python · HonKit
# Python Brasil
# Python – Wikipédia, a enciclopédia livre - Wikipedia
# Guia Completo de Python: Aprenda Python do Básico ao ...
# Python: Aprenda do Básico ao Avançado com os Cursos da ...

# %%
option = webdriver.ChromeOptions()
option.binary_location = r'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
driver = webdriver.Chrome(executable_path=r'D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\20210723_aula20\\chromedriver.exe', options=option)
driver.get("https://www.google.com")

# %%
driver_path = "D:\\sandboxes\\github\\johnnyhorita\\empiricus-datascience-degree\\20210723_aula20\\chromedriver.exe"
brave_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
option = webdriver.ChromeOptions()
option.binary_location = brave_path
browser = webdriver.Chrome(executable_path=driver_path, options=option)
browser.get("https://www.google.es")
